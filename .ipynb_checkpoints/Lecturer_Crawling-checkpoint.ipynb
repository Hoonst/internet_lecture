# %%
from selenium import webdriver
#import gspread
#from oauth2client.service_account import ServiceAccountCredentials
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
import time
import os
from collections import defaultdict
from pathlib import Path
import pandas as pd
import surfer
from bs4 import BeautifulSoup as bs
import requests


from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException

# %%
teacher_dic = {}
teacher_dic['lmh'] = 'http://www.mimacstudy.com/tcher/studyQna/getStudyQnaList.ds?tcd=531&currPage=1'
teacher_dic['jjs'] = 'http://www.megastudy.net/teacher_v2/bbs/bbs_list.asp?tec_cd=rimbaud666&LeftMenuCd=3&brd_kbn=qnabbs&LeftSubCd=1#/teacher_v2/bbs/bbs_list_ax.asp?tec_cd=rimbaud666&tec_type=1&brd_cd=784&brd_tbl=MS_BRD_TEC784&brd_kbn=qnabbs&ans_yn=&smode=1&sword=&GrpTecCd=&chr_cd=&sub_nm=&my_qna=&page=2'
teacher_dic['jhc'] = ' https://skyedu.conects.com/teachers/teacher_qna/?t_id=jhc01&cat1=1&page=1'
teacher_dic['yhk'] = 'https://www.etoos.com/teacher/board/sub04_math/board_list.asp?teacher_id=200386&selSearchType=&txtSearchWD=&BOARD_ID=2007&QUST_TYPE_CD=&GOOD_QUST_YN=&MOV_YN=&MEM_YN=&NTView=&page=1'
teacher_dic['kww'] = 'https://go3.etoos.com/teacher/board/sub04_math/board_list.asp?TEACHER_ID=200245'

# %%
def set_driver():
    global driver, actionChains
    driver = webdriver.Chrome()
    actionChains = ActionChains(driver)
    
def connect_site_with_url(site_url, time):
    driver.get(site_url)
    implicit_wait(time)
    
def username_password_insert(username, password):
    user = driver.find_element_by_id("username")
    pw = driver.find_element_by_id("password")
    user.send_keys(username)
    pw.send_keys(password)

    driver.find_element_by_id("signin_button").click()
    
def implicit_wait(time):
    driver.implicitly_wait(time)

def scroll_very_bottom(very_bottom_element, time):
    driver.execute_script('arguments[0].scrollIntoView(true);', very_bottom_element)
    implicit_wait(time)

# %% [markdown]
# # Etoos (YHK)

# %%
total_df = pd.DataFrame(columns = ['번호', '분류', '제목', '작성자', '작성일'])
total_df
# Out:
# Empty DataFrame
# Columns: [번호, 분류, 제목, 작성자, 작성일]
# Index: []

# %%
set_driver()
connect_site_with_url(teacher_dic['yhk'], 3)

# %%
driver.find_elements_by_class_name('link_page')[-1].text
# Out:
# '244'

# %%
rows = driver.find_elements_by_tag_name('tr')

# %%
from collections import defaultdict as dd

# %%
a = dd(int)

# %%
for row in rows:
    print(row.text.split('\n'))
#     text = row.text.split()
#     index = text[0]
#     category = text[1]
#     title = (' ').join(text[2:-2])
#     writer = text[-2]
#     date = text[-1]
    
#     in_total = {'번호': index,
#                 '분류': category,
#                 '제목': title,
#                 '작성자': writer,
#                 '작성일': date}
    
#     total_df = total_df.append(in_total, ignore_index=True)
#     print(row.text)
# Out:
# ['번호 제목 작성자 작성일']
# ['[공지] 5일 한정 공개! Monthly EBS 이벤트 관련 필독사항! 윤훈관 선생님 2020.02.11']
# ['(윤훈관 수강생 필독) QnA를 적극적으로 활용해야 하는 이유 윤훈관 선생님 2019.12.23']
# ['우리가 QnA 게시판에서 대화하는 방법 윤훈관 선생님 2019.12.22']
# ['4854 [학습방법] 씨알 해석편 김형찬 2020.02.17']
# ['4853 [먼슬리EBS] Monthly EBS 사전 체험 신청합니다 ! 윤영선 2020.02.17']
# ['4852 [교재내용] P94 0245질문 김예린 2020.02.17']
# ['4851 [먼슬리EBS] 먼슬리EBS신청합니다! 이태미 2020.02.17']
# ['4850 [교재내용] 씨알 [해석편] 134쪽 유채은 2020.02.17']
# ['4849 [학습방법] 학습커리 장유성 2020.02.17']
# ['4848 [강좌내용] 해석질문 황수미 2020.02.17']
# ['4847 [학습방법] 학습순서요! 강다은 2020.02.17']
# ['4846 [학습방법] 해석한 거 괜찮은 관점에서 한 건지 질문해두 되나용? 현재원 2020.02.17']
# ['4845 [먼슬리EBS] Monthly EBS 사전체험 신청합니다! 강지원 2020.02.17']
# ['4844 [먼슬리EBS] 자신감만 있다면 뭐든지 가능합니다! 윤훈관 연구실 2020.02.17']
# ['4843 [학습방법] 커리타기 류화영 2020.02.17']
# ['4842 [교재내용] 독해편 질문 차지현 2020.02.17']
# ['4841 [먼슬리EBS] 먼슬리EBS 사전체험 신청합니다 최인혁 2020.02.17']
# ['4840 [먼슬리EBS] 앞으로도 좋은 열정 부탁할께요 >_< 윤훈관 연구실 2020.02.17']
# ['4839 [먼슬리EBS] Monthly EBS사전 체험 신청합니다! 신동은 2020.02.17']
# ['4838 [먼슬리EBS] 먼슬리로 내신까지 씹어먹어봅시다! 윤훈관 연구실 2020.02.17']
# ['4837 [공부법] 수능특강 영어 공부법 이승민 2020.02.17']
# ['4836 [고민상담] 공부방법 질문 장현주 2020.02.17']
# ['4835 [먼슬리EBS] monthly EBS 사전 체험 신청합니다! 김현지 2020.02.17']

# %%
total_df
# Out:
#       번호        분류                                   제목  작성자         작성일
# 0     번호        제목                                       작성자         작성일
# 1   [공지]        5일  한정 공개! Monthly EBS 이벤트 관련 필독사항! 윤훈관  선생님  2020.02.11
# 2   (윤훈관       수강생        필독) QnA를 적극적으로 활용해야 하는 이유 윤훈관  선생님  2019.12.23
# 3    우리가       QnA                    게시판에서 대화하는 방법 윤훈관  선생님  2019.12.22
# 4   4847    [학습방법]                                 학습커리  장유성  2020.02.17
# 5   4846    [강좌내용]                                 해석질문  황수미  2020.02.17
# 6   4845    [학습방법]                               학습순서요!  강다은  2020.02.17
# 7   4844    [학습방법]        해석한 거 괜찮은 관점에서 한 건지 질문해두 되나용?  현재원  2020.02.17
# 8   4843  [먼슬리EBS]              Monthly EBS 사전체험 신청합니다!  강지원  2020.02.17
# 9   4842  [먼슬리EBS]              자신감만 있다면 뭐든지 가능합니다! 윤훈관  연구실  2020.02.17
# 10  4841    [학습방법]                                 커리타기  류화영  2020.02.17
# 11  4840    [교재내용]                               독해편 질문  차지현  2020.02.17
# 12  4839  [먼슬리EBS]                    먼슬리EBS 사전체험 신청합니다  최인혁  2020.02.17
# 13  4838  [먼슬리EBS]             앞으로도 좋은 열정 부탁할께요 >_< 윤훈관  연구실  2020.02.17
# 14  4837  [먼슬리EBS]              Monthly EBS사전 체험 신청합니다!  신동은  2020.02.17
# 15  4836  [먼슬리EBS]               먼슬리로 내신까지 씹어먹어봅시다! 윤훈관  연구실  2020.02.17
# 16  4835     [공부법]                          수능특강 영어 공부법  이승민  2020.02.17
# 17  4834    [고민상담]                              공부방법 질문  장현주  2020.02.17
# 18  4833  [먼슬리EBS]             monthly EBS 사전 체험 신청합니다!  김현지  2020.02.17
# 19  4832  [먼슬리EBS]                       저희도 감자합니다! 윤훈관  연구실  2020.02.17
# 20  4831  [먼슬리EBS]             Monthly EBS 사전 체험 신청합니다!  강주희  2020.02.17
# 21  4830  [먼슬리EBS]         허맛 이제 주희친구도 원.어.민이랄까...? 윤훈관  연구실  2020.02.17
# 22  4829  [먼슬리EBS]                   먼슬리 EBS 사전체험 신청합니다  장유성  2020.02.17
# 23  4828  [먼슬리EBS]                   유성친구 언제나 화이팅!! 윤훈관  연구실  2020.02.17

# %%
html = requests.get(teacher_dic['yhk'])

# %%
soup = bs(html.content, from_encoding='cp949')

# %%
table = soup.find('table')

# %%
rows = table.find_all('tr')

# %%
rows
# Out:
# [<tr>
#  <th>번호</th> <th>제목</th> <th>작성자</th> <th>작성일</th>
#  </tr>,
#  <tr class="notice" style="background:#f6fcfc;">
#  <td><img alt="공지" src="https://img.etoos.com/sub2016/common/ico_notice.png"/></td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="./board_read.asp?MYQ=&amp;GOOD=&amp;selQType=&amp;selSubject=&amp;selLecture=&amp;TEACHER_ID=200386&amp;page=&amp;selSearchType=&amp;txtSearchWD=&amp;BOARD_ID=2007&amp;BOARD_ARTI_ID=26645180">
#  <b>[공지] 5일 한정 공개! Monthly EBS 이벤트 관련 필독사항!</b> <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  </span>
#  </td>
#  <td>
#  								윤훈관 선생님
#  							</td>
#  <td>2020.02.11</td>
#  </tr>,
#  <tr class="notice" style="background:#f6fcfc;">
#  <td><img alt="공지" src="https://img.etoos.com/sub2016/common/ico_notice.png"/></td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="./board_read.asp?MYQ=&amp;GOOD=&amp;selQType=&amp;selSubject=&amp;selLecture=&amp;TEACHER_ID=200386&amp;page=&amp;selSearchType=&amp;txtSearchWD=&amp;BOARD_ID=2007&amp;BOARD_ARTI_ID=26451500">
#  <b>(윤훈관 수강생 필독) QnA를 적극적으로 활용해야 하는 이유</b>
#  </a>
#  </span>
#  </td>
#  <td>
#  								윤훈관 선생님
#  							</td>
#  <td>2019.12.23</td>
#  </tr>,
#  <tr class="notice" style="background:#f6fcfc;">
#  <td><img alt="공지" src="https://img.etoos.com/sub2016/common/ico_notice.png"/></td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="./board_read.asp?MYQ=&amp;GOOD=&amp;selQType=&amp;selSubject=&amp;selLecture=&amp;TEACHER_ID=200386&amp;page=&amp;selSearchType=&amp;txtSearchWD=&amp;BOARD_ID=2007&amp;BOARD_ARTI_ID=26449914">
#  <b>우리가 QnA 게시판에서 대화하는 방법</b>
#  </a>
#  </span>
#  </td>
#  <td>
#  								윤훈관 선생님
#  							</td>
#  <td>2019.12.22</td>
#  </tr>,
#  <tr>
#  <td>4814</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26675121',1);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										Monthly EBS 사전체험 신청합니다! <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									강지원
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4813</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674976',1);">
#  <strong>
#  										[학습방법]
#  										</strong>
#  										커리타기 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									류화영
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4812</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674844',1);">
#  <strong>
#  										[교재내용]
#  										</strong>
#  										독해편 질문 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									차지현
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4811</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674689',0);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										먼슬리EBS 사전체험 신청합니다 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  </span>
#  </td>
#  <td>
#  									최인혁
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4810</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674675',1);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										Monthly EBS사전 체험 신청합니다! <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									신동은
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4809</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674568',1);">
#  <strong>
#  										[공부법]
#  										</strong>
#  										수능특강 영어 공부법 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									이승민
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4808</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674510',1);">
#  <strong>
#  										[고민상담]
#  										</strong>
#  										공부방법 질문 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									장현주
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4807</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674415',1);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										monthly EBS 사전 체험 신청합니다! <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									김현지
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4806</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674402',1);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										Monthly EBS 사전 체험 신청합니다! <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									강주희
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4805</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674399',1);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										먼슬리 EBS 사전체험 신청합니다 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									장유성
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4804</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674350',1);">
#  <strong>
#  										[교재내용]
#  										</strong>
#  										해석질문 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									김세진
#  								</td>
#  <td>2020.02.17</td>
#  </tr>,
#  <tr>
#  <td>4803</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674159',1);">
#  <strong>
#  										[먼슬리EBS]
#  										</strong>
#  										Monthly EBS 사전 체험 신청합니다 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									이서현
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4802</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26674050',1);">
#  <strong>
#  										[공부법]
#  										</strong>
#  										쌤 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									이채원
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4801</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673895',1);">
#  <strong>
#  										[학습방법]
#  										</strong>
#  										EXERCISE 모르는 단어 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									송은성
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4800</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673811',1);">
#  <strong>
#  										[교재내용]
#  										</strong>
#  										cr현장자료 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									허윤아
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4799</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673655',1);">
#  <strong>
#  										[공부법]
#  										</strong>
#  										공부법이요 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									강다은
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4798</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673594',0);">
#  <strong>
#  										[공부법]
#  										</strong>
#  										Ebstore 대략적인 개강날짜 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  </span>
#  </td>
#  <td>
#  									이지민
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4797</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673462',1);">
#  <strong>
#  										[교재내용]
#  										</strong>
#  										이거 오타인가요?? <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									김지연
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4796</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673279',1);">
#  <strong>
#  										[강좌내용]
#  										</strong>
#  										191번 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									김휘찬
#  								</td>
#  <td>2020.02.16</td>
#  </tr>,
#  <tr>
#  <td>4795</td>
#  <td class="tit">
#  <span class="ellip" style="white-space:normal;">
#  <a class="link" href="javascript:;" onclick="fnread('26673237',1);">
#  <strong>
#  										[교재내용]
#  										</strong>
#  										CR독해편 22p 질문이요 <img alt="New" src="https://img.etoos.com/sub2016/common/ico_new.png"/>
#  </a>
#  <img alt="비밀글" src="https://img.etoos.com/sub2016/common/ico_lock.png"/>
#  </span>
#  </td>
#  <td>
#  									김홍창
#  								</td>
#  <td>2020.02.16</td>
#  </tr>]

# %%
header = rows[0].find_all('th')

# %%
total_df = pd.DataFrame(columns = ['번호', '분류', '제목', '작성자', '작성일'])
total_df
# Out:
# Empty DataFrame
# Columns: [번호, 분류, 제목, 작성자, 작성일]
# Index: []

# %%
for row in rows[4:]:
    text = row.text.split()
    index = text[0]
    category = text[1]
    title = (' ').join(text[2:-2])
    writer = text[-2]
    date = text[-1]
    
    in_total = {'번호': index,
                '분류': category,
                '제목': title,
                '작성자': writer,
                '작성일': date}
    
    total_df = total_df.append(in_total, ignore_index=True)

# %%
total_df
# Out:
#       번호        분류                        제목  작성자         작성일
# 0   4814  [먼슬리EBS]   Monthly EBS 사전체험 신청합니다!  강지원  2020.02.17
# 1   4813    [학습방법]                      커리타기  류화영  2020.02.17
# 2   4812    [교재내용]                    독해편 질문  차지현  2020.02.17
# 3   4811  [먼슬리EBS]         먼슬리EBS 사전체험 신청합니다  최인혁  2020.02.17
# 4   4810  [먼슬리EBS]   Monthly EBS사전 체험 신청합니다!  신동은  2020.02.17
# 5   4809     [공부법]               수능특강 영어 공부법  이승민  2020.02.17
# 6   4808    [고민상담]                   공부방법 질문  장현주  2020.02.17
# 7   4807  [먼슬리EBS]  monthly EBS 사전 체험 신청합니다!  김현지  2020.02.17
# 8   4806  [먼슬리EBS]  Monthly EBS 사전 체험 신청합니다!  강주희  2020.02.17
# 9   4805  [먼슬리EBS]        먼슬리 EBS 사전체험 신청합니다  장유성  2020.02.17
# 10  4804    [교재내용]                      해석질문  김세진  2020.02.17
# 11  4803  [먼슬리EBS]   Monthly EBS 사전 체험 신청합니다  이서현  2020.02.16
# 12  4802     [공부법]                         쌤  이채원  2020.02.16
# 13  4801    [학습방법]           EXERCISE 모르는 단어  송은성  2020.02.16
# 14  4800    [교재내용]                    cr현장자료  허윤아  2020.02.16
# 15  4799     [공부법]                     공부법이요  강다은  2020.02.16
# 16  4798     [공부법]         Ebstore 대략적인 개강날짜  이지민  2020.02.16
# 17  4797    [교재내용]                이거 오타인가요??  김지연  2020.02.16
# 18  4796    [강좌내용]                      191번  김휘찬  2020.02.16
# 19  4795    [교재내용]            CR독해편 22p 질문이요  김홍창  2020.02.16

# %% [markdown]
# # DS MyMac

# %%
set_driver()
connect_site_with_url(teacher_dic['lmh'], 3)

# %%
html = requests.get(teacher_dic['lmh'], time.sleep(5)).text

# %%
soup = bs(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- <meta property="og:title"		content="대성마이맥" /> -->
# <!-- <meta property="og:description"	content="전국 고교90%, 서울·경기 고교 99%가 수강! 19패스 하나면 내신부터 수능까지 준비 끝!" /> -->
# <!-- <meta property="og:type"		content="website" /> -->
# <!-- <meta property="og:url"			content="http://www.mimacstudy.com/" /> -->
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <title>대성마이맥 마이맥선생님 &gt; 학습 Q&amp;A</title>
# <meta content="전국 고교90%, 서울·경기 고교 99%가 수강! 19패스 하나면 내신부터 수능까지 준비 끝!" name="description"/>
# <link href="http://img.mimacstudy.com/FRONT/icon/favicon.ico" rel="shortcut icon"/>
# <link href="http://img.mimacstudy.com/FRONT/css/daesung.css?v1" rel="stylesheet" type="text/css"/>
# <link href="http://img.mimacstudy.com/FRONT/css/daesung2.css" rel="stylesheet" type="text/css"/>
# <script src="/js/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="/js/common.js" type="text/javascript"></script>
# <script src="/js/page_util.js" type="text/javascript"></script>
# <script src="/js/jqwidgets/jqxcore.js" type="text/javascript"></script>
# <script src="/js/jqwidgets/jqxscrollview.js" type="text/javascript"></script>
# <script src="/js/jssor.js" type="text/javascript"></script>
# <script src="/js/jssor.slider.js" type="text/javascript"></script>
# <script src="/js/placeholders.min.js" type="text/javascript"></script>
# <script src="/js/zoneplayer/js/app/app.js?171114" type="text/javascript"></script>
# <script src="/js/common_bnr.js" type="text/javascript"></script>
# <link href="http://img.mimacstudy.com/FRONT/css/common.css?v2" rel="stylesheet" type="text/css">
# <link href="http://img.mimacstudy.com/FRONT/css/main.css?v2" rel="stylesheet" type="text/css">
# <script src="/js/jquery.touchFlow.js" type="text/javascript"></script>
# <script src="/js/jquery.event.drag-1.5.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(document).ready(function(event){
# 		$("ul.leftmenu>li").click(function() {
# 			var liName = $(this).attr("name") == undefined ? "" : $(this).attr("name");
#
# 			if(liName == "relmLi") return;
#
# 	       	if ($(this).hasClass("open")){
# 	          		$(this).removeClass("open").addClass("close");
# 	          		//$(this).parent().addClass("open");
# 	        	}else if ($(this).hasClass("close")){
# 	          		$(this).removeClass("close").addClass("open");
# 	          		//$(this).parent().removeClass();
# 	        	}
# 	     	});
#
# 	  	$("ul.leftmenu>li").each(function(event){
# 	      		if ($(this).hasClass("close")){
# 	        			$(this).parent().addClass("open");
# 	      		}
# 	    		});
#
# 	  //스카이배너 가져오기
# 		if("531"){
# 			getSkyBnr_renew('M011','tcd',  "531");
# 	 	}else{
# 	 		 getSkyBnr_renew('M002','',"531");
# 		  	}
#
# 				// 스카이배너 가져오기
# 				/*getSkyBnr(M002, "531");
# 			  	var skyData = {
# 			  			  type : "531" != "" ? "tcd" : ""  //tcd가 있으면 선생님별 스카이배너
# 			  			, relm : "03"
# 			  			, tcd  : "531"
# 			  			, subj : ""
# 			  			, skyBanrDstin : "531" != "" ? "" : "M002"  //마이맥선생님영역 스카이배너
# 			  	};
#
# 			  	// 스카이배너 가져오기
# 				$.ajax({
# 					type : "POST" ,
# 				    async: false,
# 					url : "/common/getSkyBannerList.ds",
# 					data : skyData,
# 					dataType : "json" ,
# 					success : function(data) {
# 						if(data.code == "success") {
# 							var id = "";
# 							var rid = [];
# 							var hid = [];
# 							var htmlCode = '';
# 							var htmlFirstCode = '';
# 							$(data.data).each(function(i, data) {
# 								var banrId		 	= data.banrId;
# 								var imgName 	 	= data.imgName;
# 								var upldImgName 	= data.upldImgName;
# 								var imgPath 	 	= data.imgPath;
# 								var linkInfo	 	= data.linkInfo;
# 								var newWinYn 		= data.newWinYn;
# 								var skyBanrType		= data.skyBanrType;
# 								var banrHegt		= data.banrHegt;
# 								var banrLinkType		= data.banrLinkType;
# 								var linkMid		= data.linkMid;
#
# 								if(skyBanrType == "02"){
# 									if(id != banrId){
# 										if(i > 0) {
# 											htmlCode += '</div></div>'
# 											htmlCode += '</ul>';
# 										}
# 										htmlCode += '<ul id="rolling_'+banrId+'" style="background-color:white;">';
# 										htmlCode += '<div id="scroll_'+banrId+'" style="position: relative; top: 0px; left: 0px; width: 113px; height: 166px; overflow: hidden;">';
# 										htmlCode += '<div u="slides" style="position: absolute; left: 0px; top: 0px; width: 113px; height: 166px; overflow: hidden;">';
# 										rid.push(banrId);
# 										hid.push(banrHegt);
# 									}
# 								} else {
# 									if(i > 0) {
# 										htmlCode += '</ul>';
# 									}
# 									htmlCode += '<ul>';
# 								}
# 								if(skyBanrType == "02"){
# 									htmlCode += '<div><a  onclick="openSkyBannerLink(\'' + linkInfo + '\', \'' + banrId + '\', \'' + newWinYn + '\', \'' + banrLinkType + '\', \'' + linkMid + '\');return false;"><img u=image src="http://img.mimacstudy.com' + imgPath + '/' + imgName + '" style="cursor:pointer;" /></a></div>';
# 								} else {
# 									htmlCode += '<li><a  onclick="openSkyBannerLink(\'' + linkInfo + '\', \'' + banrId + '\', \'' + newWinYn + '\', \'' + banrLinkType + '\', \'' + linkMid + '\');return false;"><img src="http://img.mimacstudy.com' + imgPath + '/' + imgName + '" style="cursor:pointer;" /></a></li>';
# 								}
# 								id = banrId;
# 							});
# 							htmlCode += '</ul>';
# 							$("#rightSkyBannerDiv").append(htmlCode);
# 							for(var j=0;j<rid.length; j++){
# 	//							$("#rolling_"+rid[j]).jqxScrollView({ width: 115, height: hid[j], slideShow: true, moveThreshold: 1, buttonsOffset: [0, 100]});
# 					            jssor_sliderb = new $JssorSlider$($("#scroll_" + rid[j]), skyoptions);
# 							}
# 						} else {
# 							alert("스카이 배너 정보를 가져오는데 실패하였습니다.");
# 						}
# 					}
# 				});*/
#
# 				// 혜택 받았으면 알럿
# 				var memBenefitAlert = "";
# 		if(memBenefitAlert != "") alert(memBenefitAlert);
#
# 	});
#
# 	function menuMover(menuId){
# 	     		location.href="/common/getMenuContainer.ds?requestMenuId="+menuId;
# 	  	}
#
# 	function menuPopMover(menuId){
# 		winPopupOpen("/common/getMenuContainer.ds?requestMenuId="+menuId, null, null, menuId, "scrollbars=1");
# 	}
#
# 	function openSkyBannerLink(linkUrl, banrId, newWinYn,banrLinkType,mid) {
# 		var data = {
# 			  banrId : banrId
# 			, mbrCoType : 'M'
# 		};
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/hi3/regBanrLog.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 					if(banrLinkType == "01") {
# 						if(newWinYn == "Y") $("#skyForm").attr("target", "_blank"); //winPopupOpen(linkUrl, 695, 225, "bannerLinkPopup");
# 						else                $("#skyForm").attr("target", "_self"); //location.href = linkUrl;
#
# 						$("#skyForm").attr("action", linkUrl).submit();
# 	  		    		} else if(banrLinkType == "02") {
# 	  		    			winPopupOpen("/common/aquaplayer/getAquaplayerOpenPop.ds?view=freeView&mode=02&mid="+mid, 807, 530, "_playerPop", "resizable=yes", '', '100');
# 	  		    		} else if(banrLinkType == "03") {
# 	  		    			alert(linkUrl);
# 	  		    		}
# 				} else {
# 					alert("배너클릭 로그정보 저장에 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Digital 大成 관리자" name="description"/>
# <meta content="Digital 大成 관리자" name="keywords"/>
# <meta content="Digital 大成 관리자" name="subject"/>
# <link href="http://img.mimacstudy.com/FRONT/css/daesung.css" rel="stylesheet"/>
# <link href="/css/jqwidgets/styles/jqx.base.css" rel="stylesheet"/>
# <link href="/css/jqwidgets/styles/jqx.arctic.css" rel="stylesheet"/>
# <script src="/js/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="/js/html5shiv.js" type="text/javascript"></script>
# <script src="/js/common.js" type="text/javascript"></script>
# <script src="/js/page_util.js" type="text/javascript"></script>
# <script src="/js/jquery-syaku.rolling.js" type="text/javascript"></script>
# <script src="/js/jqwidgets/jqxcore.js" type="text/javascript"></script>
# <script src="/js/jqwidgets/jqxscrollview.js" type="text/javascript"></script>
# <script src="/js/aquaplayer/embedplayer_setting.js" type="text/javascript"></script>
# <style type="text/css">
# 	/* jqxwidget 롤링배너 사용하기 위한 배너이미지 css */
# 	.photo
# 	{
# 	    width: 880px;
# 	    height: 250px;
# 	    background-color: #000;
# 	    background-position: center;
# 	    background-repeat: no-repeat;
# 	}
# </style>
# <script type="text/javascript">
# $(document).ready(function() {
#
#
#
# 		if("" == "home") {
# 			//선생님 학습Q&A 메인
# 			$("#pageInPut").load("/tcher/studyQna/getStudyQnaProcess.ds"
# 					,{tcd:"531",srchWordType:"",srchWordTxt:"",pdsType:""
# 					  , pid:"", ordType:"", myQna:"N", serverAddr:""
# 					  , banrDstin:"", loDstin:"", qnaStatus:"", questType:""
# 					  ,relm:"03", tcdTabType:"tcdHome", menuIdx:"", relmName:"", tcdName:""
# 					  ,currPage:"1"}
# 					, function(responseTxt, statusTxt, xhr){
# 			});
# 		} else if("" == "detail") {
# 			//선생님 학습Q&A 디테일
# 			$("#pageInPut").load("/tcher/studyQna/getStudyQnaDetailProcess.ds"
# 					,{tcd:"531",srchWordType:"",srchWordTxt:"",pdsType:""
# 					  , pid:"", ordType:"", myQna:"N", serverAddr:""
# 					  , banrDstin:"", loDstin:"", qnaStatus:"", questType:""
# 					  ,relm:"03", tcdTabType:"tcdHome", menuIdx:"", relmName:"", tcdName:""
# 					  ,bNo:"",currPage:"1",myQcurrPage:""}
# 					, function(responseTxt, statusTxt, xhr){
# 			});
# 		} else if("" == "write") {
# 			//선생님 학습Q&A 글쓰기
# 			$("#pageInPut").load("/tcher/studyQna/regStudyQnaProcess.ds"
# 					,{tcd:"531", bNo:"", procType:""
# 					 ,relm:"03", tcdTabType:"tcdHome", menuIdx:"", relmName:"", tcdName:""}
# 					, function(responseTxt, statusTxt, xhr){
# 			});
# 		} else {
# 			//타입을 안넘겼을 경우 선생님 메인
# 			$("#pageInPut").load("/tcher/studyQna/getStudyQnaProcess.ds"
# 					,{tcd:"531",srchWordType:"",srchWordTxt:"",pdsType:""
# 					  , pid:"", ordType:"", myQna:"N", serverAddr:""
# 					  , banrDstin:"", loDstin:"", qnaStatus:"", questType:""
# 					  ,relm:"03", tcdTabType:"tcdHome", menuIdx:"", relmName:"", tcdName:""
# 					  ,currPage:"1"}
# 					, function(responseTxt, statusTxt, xhr){
# 			});
# 		}
# });
#
#
# </script>
# </link></link></head>
# <body><!-- class는 공통 폴더명 -->
# <div id="daesungwrap">
# <!-- S: Header -->
# <div class="skip_nav">
# <a href="#maimacContent">본문 내용 바로가기</a>
# </div>
# <link href="https://fonts.googleapis.com/css?family=Nanum+Gothic:400,700,800&amp;subset=korean" rel="stylesheet" type="text/css"/>
# <script src="/js/jquery.cookie.js" type="text/javascript"></script>
# <script src="/js/rolling_ltw.js" type="text/javascript"></script>
# <script src="/js/jquery.touchFlow.js" type="text/javascript"></script>
# <script src="/js/jquery.event.drag-1.5.1.min.js" type="text/javascript"></script>
# <script src="/js/kakao/kakao.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#
# 	$(document).ready(function(event) {
# 		/* 2017년 수능 D-day */
#
# 		var dday = getDifDayNo(getYearMonthDay(), "2020/11/18");
# 		if(dday < 0) dday = "0";
# 		$("#examDday").html("D-"+dday); // 실제수능일 보다 하루 전날로 셋팅해야 함
# 		//$("#examDday2").html("D-"+dday); // 실제수능일 보다 하루 전날로 셋팅해야 함
#
#
# 		/* 추천검색어 만들기 */
# 		var rcmdSrchwrdList	= $.parseJSON('[]');
# 		var srchRows 		= [];
# 		var srchHtml		= "";
#
# 		$.each(rcmdSrchwrdList, function(i, data) {
# 			srchRows.push({
# 				rcmdSrchwrd : data.rcmdSrchwrd,
# 				urlInfo : data.urlInfo
# 			});
# 		});
#
# 		if(rcmdSrchwrdList.length > 2) {
# 			$.each(srchRows, function(i, data) {
# 				if(i > 0) {
# 					srchHtml = '<li><span><a href="' + srchRows[i-1].urlInfo + '" >' + srchRows[i-1].rcmdSrchwrd+ '</a></span>';
# 					srchHtml += '<span><a href="' + srchRows[i].urlInfo + '" >' + srchRows[i].rcmdSrchwrd+ '</a></span></li>';
# 					$("#srchBannerScroll").append(srchHtml);
# 				}
# 			});
# 		}else {
# 			srchHtml = '<li>';
# 			$.each(srchRows, function(i, data) {
# 				srchHtml += '<span><a href="' + data.urlInfo + '" target="_blank">' + data.rcmdSrchwrd+ '</a></span>';
# 			});
# 			srchHtml += "</li>";
#
# 			$("#srchBannerScroll").append(srchHtml);
# 		}
# 		/* 추천검색어 만들기 */
#
# 		/* 레프트 토글 메뉴 제어 */
# 		var $_meminfo_quick = $('.meminfo_quick'),
# 			header_height = $('.dsm_header').height();;
#
# 		$_meminfo_quick.on('click','.toggle_quick',function(){
# 			$_meminfo_quick.toggleClass('close');
#
# 			if($_meminfo_quick.hasClass("close")) setCookie('login_app', 'hidden', '1');
# 			else setCookie('login_app', '', '-1');
# 		});
#
# 		$(window).scroll(function(){
# 			var topValue = $(window).scrollTop();
# 			if(topValue > header_height){
# 				$_meminfo_quick.addClass('fix_top');
# 			} else{
# 				$_meminfo_quick.removeClass('fix_top');
# 			}
# 		});
#
# 		/* 상단 스크립트 */
# 		$('.top_issue_bn').moveScroll({
# 			delay : 3000, //setting 시간 셋팅
# 			duration : 300, //애니메이션 시간 셋팅
# 			is_dir_button : true, //방향버튼
# 			prev_bt : '.top_bn_prev',// 이전 버튼 클래스명
# 			next_bt : '.top_bn_next',// 다음 버튼 클래스명
# 			current_number : 'random'
# 		});
#
# 		$('.keyword_link').moveScroll({
# 			duration : 300, //애니메이션 시간 셋팅
# 			is_dir_button : true, //방향버튼
# 			prev_bt : '.top_bn_prev',// 이전 버튼 클래스명
# 			next_bt : '.top_bn_next',// 다음 버튼 클래스명
# 		});
#
# 		$('.view_login').click(function(){
#
# 			// sns로그인관련 - 로그인 페이지에서 버튼 아이디 충돌로인해 작동하지 않아서 변경해줌
# 			$(".snsNaverIdchkUp").attr("id", "naverIdLogin_loginButton");
# 			try{
# 				$(".snsNaverIdchkDown").attr("id", "naverIdLogin_loginButton2");
# 			} catch (e){
#
# 			}
# 			//naverLogin.init();
#
# 			$('.login_app').show();
# 		});
#
# 		$('.login_app .close_login').click(function(){
# 			$('.login_app').hide();
# 		});
#
# 		$('.gnb_month_exm .view_list').click(function(){
# 			$('.gnb_month_exm').toggleClass('on')
# 		});
#
# 		$('.gnb_more > a').click(function(){
# 			$('.gnb_more').toggleClass('on');
# 			$('.gnb_academy').removeClass('on');
# 		});
# 		$('.gnb_academy > a').click(function(){
# 			$('.gnb_academy').toggleClass('on');
# 			$('.gnb_more').removeClass('on');
# 		});
#
# 		$('.gnb_academy .close_btn > button').click(function(){
# 			$('.gnb_academy').removeClass('on');
# 		});
#
# 		/* 로그인 */
# 		$("#upperloginBtn").bind("click", upperLoginAction);
#
# 		$("#upperloginpw").bind("keypress", function(event) {
#         	if (event.which == 13) {
#           		upperLoginAction(event);
#         	}
#       	});
#
#       	$("#upperidsave").bind("click", function(event){
#       		$("#upperrememberFlag").val($(this).is(":checked") ? "Y" : "N");
#       	});
#
#       	if(!isNull($.cookie("mbrId"))) {
#         	$("#upperloginid").val($.cookie("mbrId"));
#         	$("#upperidsave").prop("checked", true);
#       		$("#upperrememberFlag").val("Y");
#       	}
#       	/* 로그인 */
#
# 		/* 관심선생님 설정 */
# 		$("#topTcdSetBtn").click(function() {
#
# 			var userId = "";
#
# 			if(userId == "") {
# 				alert("관심선생님 설정은 로그인 한 상태에서 이용하실 수 있습니다.");
# 				location.href = "/mem/callLoginForm.ds?refUrl="+ document.URL.replace(/\?/g, "|@").replace(/&/g, "|");
# 				return;
# 			}
#
# 			$("#bookmarkGuideBlock").show();
# 			$("button[name='topPlusBtn']").show();
# 			$(this).hide();
# 			$("#topTcdSetSpan").show();
#
# 			$.ajax({
# 				type : "POST" ,
# 				url : "/common/topPage/interestTcdInfoByAjax.ds",
# 				data : "type=interTcd",
# 				dataType : "json" ,
# 				success : function(data) {
# 					if(data.code == "success") {
# 						initTopProfileImg();
#
# 						var htmlCode = "";
# 						$.each(data.data, function(i, data) {
# 							var tcd 			= data.tcd;
# 							var subj			= data.subj == undefined ? "" : data.subj;
# 							var relm			= data.relm;
# 							var tcdName	= data.tcdName;
# 							var relmName	= data.relmName;
#
# 							if(i < 8) { // 관심선생님은 최대 8개 까지
# 								$("#interestTcdArea li").last().remove();
#
# 								htmlCode += "<li class='on' id='topProfileLi" + tcd + "' tcd='" + tcd + "'>";
# 								htmlCode += "<a href='/tcher/eachTcherMain.ds?coType=M&relm=" + relm + "&subj=" + subj + "&tcd=" + tcd + "'>";
# 								htmlCode += "<img src='http://img.mimacstudy.com/mimac_sh/images/tzone/" + tcd + "/" + tcd + "_0010.png' /></a>";
# 								htmlCode += "<div class='tchinfo'><span>" + relmName + " " + tcdName + "</span>";
# 								htmlCode += "<button type='button' name='interestTcdDelBtn' onclick='delTopProfileImg(this);' tcd='" + tcd + "'><img src='http://img.mimacstudy.com/FRONT/main/btn_close.png' /></button></div></li>";
#
#
# 							} else {
# 								return false; // 반복문 빠져나오기
# 							}
# 						});
# 						$("#interestTcdArea").prepend(htmlCode);
# 					} else {
# 						alert("관심선생님 정보 가져오기에 실패하였습니다.");
# 					}
# 				}
# 			});
# 		});
# 		/* 관심선생님 설정 */
#
# 		/* 빠른 강좌 찾기 */
# 		$('.quick_find_lec').click(function(){
# 			$('#layerQuickLctrPop').show();
# 		});
#
# 		var isInterestDataLoding = false;
#
# 		$("#topInterestTcdImg, #tcdLayerCloseBtn").click(function(e) {
# 			var display = $("#layerInterestPop").css("display");
#
# 			if(display == "none") {
#
# 				if(isInterestDataLoding == false) {
# 					/* 관심선생님 레이어 팝업 만들기 */
# 					$.ajax({
# 						type : "POST" ,
# 						url : "/common/topPage/interestTcdInfoByAjax.ds",
# 						data : "type=init",
# 						dataType : "json" ,
# 						success : function(data) {
# 							if(data.code == "success") {
#
# 								//isInterestDataLoding = true;
# 								$("#topRelm01,#topRelm02,#topRelm03,#topRelm0409,#topRelm0411,#topRelm0404,#topRelm0401,#topRelm0410,#topRelm0414,#topRelm0402,#topRelm0413,#topRelm0406,#topRelm0503,#topRelm0502").empty();
# 								$("#topRelm0504,#topRelm0501,#topRelm0514,#topRelm10,#topRelm0701,#topRelm0702,#topRelm0703,#topRelm0704,#topRelm0705,#topRelm0706,#topRelm0707,#topRelm0607,#topRelm0609,#topRelm0605").empty();
#
#
# 								$.each(data.data[0], function(i, data) {
# 									var remark		= "null";
# 									var relm		= "null";
# 									var subj		= "null";
# 									var tcd			= "null";
#
# 									if(data.remark!=null && data.remark!="")
# 									{
# 										remark		= data.remark.split('&');
# 										relm		= remark[1].substr(5);
# 										subj		= remark[2] == undefined ? "" : remark[2].substr(5);
# 										tcd			= remark[0].substr(4);
# 									}
# 									var relmName	= data.menuDesc;
# 									var tcdName		= data.menuName; // 선생님 이름
# 									var newYn		= data.newYn;
# 									var htmlCode	= "<li>";
#
# 									if(newYn == "Y") htmlCode += "<img src='http://img.mimacstudy.com/FRONT/common/icon_new.png' class='new' />";
#
# 									htmlCode += "<a href='/tcher/eachTcherMain.ds?coType=M&relm=" + relm + "&subj=" + subj + "&tcd=" + tcd + "&type=" + relm + tcd + "'>" + tcdName + "</a>";
# 									htmlCode += "<button type='button' name='topPlusBtn' onclick='addTopProfileImg(this);' style='display:none;' relm='" + relm + "' subj='" + subj + "' tcd='" + tcd
# 										+ "' relmName='" + relmName + "' tcdName='" + tcdName + "'>";
# 									htmlCode += "<img src='http://img.mimacstudy.com/FRONT/main/icon_splus.png' /></button></li>";
#
# 									if(relm == "01") {
# 										$("#topRelm01").append(htmlCode);
# 									} else if(relm == "02") {
# 										$("#topRelm02").append(htmlCode);
# 									} else if(relm == "03") {
# 										$("#topRelm03").append(htmlCode);
# 									} else if(relm == "04") {
# 										if(subj == "0409") {
# 											$("#topRelm0409").append(htmlCode);
# 										} else if(subj == "0411" || subj == "0412") {
# 											$("#topRelm0411").append(htmlCode);
# 										} else if(subj == "0404") {
# 											$("#topRelm0404").append(htmlCode);
# 										} else if(subj == "0401" || subj == "0403") {
# 											$("#topRelm0401").append(htmlCode);
# 										} else if(subj == "0410") {
# 											$("#topRelm0410").append(htmlCode);
# 										} else if(subj == "0414") {
# 											$("#topRelm0414").append(htmlCode);
# 										} else if(subj == "0413"){
# 											$("#topRelm0413").append(htmlCode);
# 										} else if(subj == "0402"){
# 											$("#topRelm0402").append(htmlCode);
# 										} else if(subj == "0406"){
# 											$("#topRelm0406").append(htmlCode);
# 										}
# 									} else if(relm == "05") {
# 										if(subj == "0503" || subj == "0507" || subj == "0512") {
# 											$("#topRelm0503").append(htmlCode);
# 										} else if(subj == "0502" || subj == "0506" || subj == "0511") {
# 											$("#topRelm0502").append(htmlCode);
# 										} else if(subj == "0504" || subj == "0508" || subj == "0513") {
# 											$("#topRelm0504").append(htmlCode);
# 										} else if(subj == "0501" || subj == "0505" || subj == "0510") {
# 											$("#topRelm0501").append(htmlCode);
# 										} else if(subj == "0514") {
# 											$("#topRelm0514").append(htmlCode);
# 										}
# 									} else if(relm == "10") {
# 										$("#topRelm10").append(htmlCode);
# 									} else if(relm == "07") {
# 										if(subj == "0701") {
# 											$("#topRelm0701").append(htmlCode);
# 										} else if(subj == "0702") {
# 											$("#topRelm0702").append(htmlCode);
# 										} else if(subj == "0703") {
# 											$("#topRelm0703").append(htmlCode);
# 										} else if(subj == "0704") {
# 											$("#topRelm0704").append(htmlCode);
# 										} else if(subj == "0705") {
# 											$("#topRelm0705").append(htmlCode);
# 										} else if(subj == "0706") {
# 											$("#topRelm0706").append(htmlCode);
# 										} else if(subj == "0707") {
# 											$("#topRelm0707").append(htmlCode);
# 										}
# 									} else if(relm == "06") {
# 										if(subj == "0607") {
# 											$("#topRelm0607").append(htmlCode);
# 										} else if(subj == "0609") {
# 											$("#topRelm0609").append(htmlCode);
# 										} else if(subj == "0605") {
# 											$("#topRelm0605").append(htmlCode);
# 										}
# 									}
#
# 								});
#
# 								//alert("gg4");
#
# 								if(data.data[1] != undefined) {
# 									initTopProfileImg();
# 									var htmlCode = "";
# 									$.each(data.data[1], function(i, data) {
# 										var tcd 			= data.tcd;
# 										var subj			= data.subj == undefined ? "" : data.subj;
# 										var relm			= data.relm;
# 										var tcdName	= data.tcdName;
# 										var relmName	= data.relmName;
#
# 										if(i < 8) { // 관심선생님은 최대 8개 까지
# 											$("#interestTcdArea li").last().remove();
#
# 											htmlCode += "<li class='on' id='topProfileLi" + tcd + "' style='cursor:pointer;'>";
# 											htmlCode += "<a href='/tcher/eachTcherMain.ds?coType=M&relm=" + relm + "&subj=" + subj + "&tcd=" + tcd + "'>";
# 											htmlCode += "<img src='http://img.mimacstudy.com/mimac_sh/images/tzone/" + tcd + "/" + tcd + "_0010.png' />";
# 											htmlCode += "<div class='tchinfo'><span>" + relmName + " " + tcdName + "</span></div></a></li>";
#
#
# 										} else {
# 											return false; // 반복문 빠져나오기
# 										}
# 									});
# 									$("#interestTcdArea").prepend(htmlCode);
# 								}
# 							} else {
# 								alert("관심선생님 정보 가져오기에 실패하였습니다.");
# 							}
# 						}
# 					});
# 				}
#
# 				$("#layerInterestPop").show();
# 			} else {
# 				$("#layerInterestPop").hide();
# 				$("button[name='interestTcdDelBtn']").hide();
# 			}
#
# 			e.preventDefault();
#
# 			$("button[name='topPlusBtn']").hide();
# 			$("#topTcdSetBtn").show();
# 			$("#topTcdSetSpan").hide();
# 			$("#bookmarkGuideBlock").hide();
# 		});
#
# 		$("#tcdContentsCloseBtn").click(function(e) {
# 			var display = $("#tcdContentsBottom").css("display");
#
# 			if(display == "none") {
# 				$("#tcdContentsCloseBtn img").prop("src", "http://img.mimacstudy.com/FRONT/main/btn_allsee_on.png");
# 				$("#tcdContentsBottom").show();
# 			} else {
# 				$("#tcdContentsCloseBtn img").prop("src", "http://img.mimacstudy.com/FRONT/main/btn_allsee_off.png");
# 				$("#tcdContentsBottom").hide();
# 			}
# 		});
#
# 		$("#topTcdInitBtn, #topTcdSaveBtn").click(function(e) {
# 			var btnId 	= $(this).prop("id");
# 			var tcds	= "";
# 			var data	= null;
# 			var type 	= "init";
#
# 			if(btnId == "topTcdInitBtn") {
# 				data = {
# 					type : type,
# 					mbrCoType : "M"
# 				};
# 			} else {
# 				$.each($("#interestTcdArea li"), function(i, data) {
# 					if($(this).hasClass("on")) tcds += $(this).attr("tcd") + ",";
# 				});
# 				type = "save";
# 				data = {
# 					type : type,
# 					tcds : tcds,
# 					mbrCoType : "M"
# 				};
# 			}
#
# 			$.ajax({
# 				type : "POST" ,
# 				url : "/common/topPage/interestTcdInfoModifyByAjax.ds",
# 				data : data,
# 				dataType : "json" ,
# 				success : function(data) {
# 					if(data.code == "success") {
# 						$("button[name='interestTcdDelBtn']").hide();
# 						$("button[name='topPlusBtn']").hide();
# 						$("#topTcdSetBtn").show();
# 						$("#topTcdSetSpan").hide();
# 						$("#bookmarkGuideBlock").hide();
#
# 						if(type == "init") initTopProfileImg();
#
# 						alert("관심선생님 변경에 성공하였습니다.");
# 					} else {
# 						alert("관심선생님 변경에 실패하였습니다.");
# 					}
# 				}
# 			});
# 		});
#
# 		$("li[name='stepLi']").click(function(e) {
# 			var dstin 		= $(this).attr("dstin");
# 			var stepUlObj	= $("#topQuickSearchStepUl");
# 			var data = {
# 				type : 'step',
# 				dstin : dstin
# 			};
#
# 			$("li[name='stepLi']").children().removeClass("on");
# 			$(this).children().addClass("on");
#
# 			$.ajax({
# 				type : "POST" ,
# 				url : "/common/topPage/getQuickLctrInfoByAjax.ds",
# 				data : data,
# 				dataType : "json" ,
# 				success : function(data) {
# 					if(data.code == "success") {
# 						stepUlObj.empty();
# 						$("#topQuickSearchRelmUl").empty();
# 						$("#topQuickSearchTcdUl").empty();
# 						$("#topQuickSearchSubjUl").empty();
#
# 						$.each(data.data, function(i, data) {
# 							var dstin			= data.dstin;
# 							var lctrType		= data.lctrType;
# 							var lctrTypeName	= data.lctrTypeName;
# 							var htmlCode		= '<li><a onclick="setSearchRelm(\'';
#
# 							htmlCode += dstin + '\', \'' + lctrType + '\', this);" lctrType=' + lctrType + '>' + lctrTypeName + '</a></li>';
#
# 							stepUlObj.append(htmlCode);
# 						});
# 					} else {
# 						alert("단계 정보를 가져오는데 실패하였습니다.");
# 					}
# 				}
# 			});
# 		});
# 		/* 빠른 강좌 찾기 */
#
# 		/* 통합 검색 */
# 		$("#topSearchBtn").click(function() {
# 			var txtVal 		= $.trim($("#srchTxt").val());
# 			var srchwrd	= "";
# 			var urlInfo		= "";
#
# 			if(txtVal.length < 2) {
# 				alert("검색어는 최소 2자 이상 입력해 주세요.");
# 				return;
# 			}
#
# 			if( !sanctionsStr( '', txtVal, 'search') ) {
# 				return;
# 			}
#
# 			$("#topSearchText").val(txtVal);
#
# 			if(txtVal == srchwrd) {
# 				$("#topPageForm").attr("action", "" + urlInfo).submit();
# 			} else {
# 				$("#topPageForm #srchRmAddr").val("175.214.88.92");
# 				$("#topPageForm").attr("action", "/search/unifiedSearch/resultMain.ds").submit();
# 			}
# 		});
#
# 		$("#srchTxt").focus(function() {
#       		var dbTxt 	= "";
#       		var txtVal	= $(this).val();
#
#       		if(dbTxt == txtVal) $(this).val("");
# 		});
#
# 		$("#srchTxt").blur(function() {
#       		var dbTxt 	= "";
#       		var txtVal	= $(this).val();
#
#       		if(txtVal == "") $(this).val(dbTxt);
# 		});
#
# 		$("#srchTxt").keyup(function(e) {
#       		var txtVal 	= $.trim($(this).val());
# 			var keyCode	= e.keyCode;
#
# 			if(keyCode == 13) {
# 				if(txtVal.length < 2) {
# 					alert("검색어는 최소 2자 이상 입력해 주세요."); return;
# 				}
#
# 				if( !sanctionsStr( '', txtVal, 'search') ) {
# 					return;
# 				}
#
# 				$("#topSearchText").val(txtVal);
# 				$("#topPageForm #srchRmAddr").val("175.214.88.92");
# 				$("#topPageForm").attr("action", "/search/unifiedSearch/resultMain.ds").submit();
# 			}
# 		});
# 		/* 통합 검색 */
#
# 		// sns로그인관련 - 카카오 관련
# 		$("#kakaoIdLogin").click(function() {
# 			Kakao.init("d63f7d48070bef1b0ed755f2119dac95");
# 			Kakao.Auth.login({
# 				persistAccessToken : true,
# 				persistRefreshToken : true,
# 				success : function(authObj) {
# 					getKakaotalkUserProfile();
# 					//createKakaotalkLogout();
# 				},
# 				fail : function(err) {
# 					console.log(err);
# 				}
# 			});
# 		});
# 	});
# 	// sns로그인관련 - 카카오 로그인 정보
# 	function getKakaotalkUserProfile() {
# 		Kakao.API.request({
# 			url : '/v2/user/me',
# 			success : function(res) {
# 				//$("#kakao-data-output").append("==카카오톡==");
# 				//$("#kakao-data-output").append("all : " + JSON.stringify(res)+"</br>");
# 				//$("#kakao-data-output").append("email : "+res.kaccount_email+"</br>");
# 				//$("#kakao-data-output").append("email 인증여부 : "+res.kaccount_email_verified+"</br>");
# 				//$("#kakao-data-output").append("id : "+res.id+"</br>");
# 				//$("#kakao-data-output").append("nickname : "+res.properties.nickname+"</br>");
# 				//$("#kakao-data-output").append("===========");
#
# 				$(location).attr("href","http://www.mimacstudy.com/mem/callKakaoForm.ds");
# 				//$(location).attr("href","http://local.mimacstudy.com:8080/ex/test/snsJoinKakaoRequestfull.ds");
# 			},
# 			fail : function(error) {
# 				console.log(error);
# 			}
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_단계 검색 */
# 	function setSearchRelm(dstin, lctrType, targetObj) {
# 		var relmUlObj	= $("#topQuickSearchRelmUl");
# 		var data = {
# 			type : 'relm',
# 			dstin : dstin,
# 			lctrType : lctrType
# 		};
#
# 		$("#topQuickSearchStepUl li").children().removeClass("on");
# 		$(targetObj).addClass("on");
#
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/common/topPage/getQuickLctrInfoByAjax.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 					relmUlObj.empty();
# 					$("#topQuickSearchTcdUl").empty();
# 					$("#topQuickSearchSubjUl").empty();
#
# 					$.each(data.data, function(i, data) {
# 						var relm			= data.relm;
# 						var dstin		= data.dstin;
# 						var lctrType	= data.lctrType;
# 						var relmName	= data.relmName;
# 						var htmlCode = '<li><a onclick="setSearchTcd(\'';
#
# 						htmlCode += relm + '\', \'' + dstin + '\', \'' + lctrType + '\', this);" relm=' + relm + '>' + relmName + '</a></li>';
#
# 						relmUlObj.append(htmlCode);
# 					});
# 				} else {
# 					alert("영역 정보를 가져오는데 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_영역 검색 */
# 	function setSearchTcd(relm, dstin, lctrType, targetObj) {
# 		var tcdUlObj = $("#topQuickSearchTcdUl");
# 		var data = {
# 			type : 'tcd',
# 			relm : relm,
# 			dstin : dstin,
# 			lctrType : lctrType
# 		};
#
# 		$("#topQuickSearchRelmUl li").children().removeClass("on");
# 		$(targetObj).addClass("on");
#
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/common/topPage/getQuickLctrInfoByAjax.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 					tcdUlObj.empty();
# 					$("#topQuickSearchSubjUl").empty();
#
# 					$.each(data.data, function(i, data) {
# 						var relm			= data.relm;
# 						var dstin		= data.dstin;
# 						var lctrType	= data.lctrType;
# 						var tcd			= data.tcd;
# 						var tchrName	= data.tchrName;
# 						var htmlCode = '<li><a onclick="setSearchSubj(\'';
#
# 						htmlCode += relm + '\', \'' + tcd + '\', \'' + dstin + '\', \'' + lctrType +  '\', this);" tcd=' + tcd + '>' + tchrName + '</a></li>';
#
# 						tcdUlObj.append(htmlCode);
# 					});
# 				} else {
# 					alert("선생님 정보를 가져오는데 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_선생님 검색 */
# 	function setSearchSubj(relm, tcd, dstin, lctrType, targetObj) {
# 		var subjUlObj = $("#topQuickSearchSubjUl");
# 		var data = {
# 			type : 'subj',
# 			relm : relm,
# 			tcd : tcd,
# 			dstin : dstin,
# 			lctrType : lctrType
# 		};
#
# 		$("#topQuickSearchTcdUl li").children().removeClass("on");
# 		$(targetObj).addClass("on");
#
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/common/topPage/getQuickLctrInfoByAjax.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 					subjUlObj.empty();
#
# 					$.each(data.data, function(i, data) {
# 						var relm			= data.relm;
# 						var subj			= data.subj;
# 						var dstin		= data.dstin;
# 						var lctrType	= data.lctrType;
# 						var tcd			= data.tcd;
# 						var subjName	= data.subjName;
# 						var htmlCode = '<li><a onclick="setSearchProd(\'';
#
# 						htmlCode += relm + '\', \'' + subj + '\', \'' + tcd + '\', \'' + dstin + '\', \'' + lctrType +  '\', this);" subj=' + subj + '>' + subjName + '</a></li>';
#
# 						subjUlObj.append(htmlCode);
# 					});
# 				} else {
# 					alert("과목 정보를 가져오는데 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_과목 검색 */
# 	function setSearchProd(relm, subj, tcd, dstin, lctrType, targetObj) {
# 		var prodUlObj = $("#topQuickSearchTargetUl");
# 		var target		= $(":radio[name='topQuickSearchTargetRadio']:checked").val();
#
# 		prodUlObj.empty();	// 강좌부분 초기화
#
# 		var data = {
# 			type : 'prod',
# 			relm : relm,
# 			subj : subj,
# 			tcd : tcd,
# 			dstin : dstin,
# 			lctrType : lctrType,
# 			target : target
# 		};
#
# 		$("#topQuickSearchSubjUl li").children().removeClass("on");
# 		$(targetObj).addClass("on");
#
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/common/topPage/getQuickLctrInfoByAjax.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 						//prodUlObj.empty();
# 					makeTopQuickLctrProd(data.data);
# 				} else {
# 					alert("상품 정보를 가져오는데 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_강좌 목록 만들기 */
# 	function makeTopQuickLctrProd(data) {
# 		var prodUlObj = $("#topQuickSearchTargetUl");
#
# 		$.each(data, function(i, data) {
# 			var prodDstin 			= data.prodDstin;
# 			var prodName 			= data.prodName;
# 			var tchrName				= data.tchrName;
# 			var totLctrCnt				= data.totLctrCnt;
# 			var salePrice				= data.salePrice;
# 			var lctrPerd				= data.lctrPerd;
# 			var textbookSalePrice	= data.textbookSalePrice;
# 			var lctrPerd				= data.lctrPerd;
# 			var relm						= data.relm;
# 			var subj						= data.subj == undefined ? "" : data.subj;
# 			var tcd 						= data.tcd;
# 			var pid 						= data.pid;
# 			var htmlCode = '<li class="ellipsis"><strong><a href="/tcher/lctr/lctrDetail.ds?coType=M&relm=' + relm + '&subj=' + subj;
#
# 			htmlCode += '&tcd=' + tcd + '&pid=' + pid + '">' + prodName + '</a><strong><div class="info">' + tchrName + '선생님';
# 			htmlCode += '<span>l</span>수강료 : <strong>' + formatNumber(salePrice) + '</strong> 원 (' + lctrPerd + '일)';
# 			htmlCode += '<span>l</span>' + totLctrCnt + ' 강<span>l</span>교재 : ' + formatNumber(textbookSalePrice) + '원</div></li>';
#
# 			prodUlObj.append(htmlCode);
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_강좌 검색 버튼 */
# 	function searchTopLctrProd() {
# 		var prodUlObj = $("#topQuickSearchTargetUl");
#
# 		var relm			= $("#topQuickSearchRelmUl li a[class='on']").attr("relm");
# 		var subj			= $("#topQuickSearchSubjUl li a[class='on']").attr("subj");
# 		var tcd			= $("#topQuickSearchTcdUl li a[class='on']").attr("tcd");
# 		var dstin		= $("#topQuickSearchTypeUl li a[class='on']").attr("dstin");
# 		var lctrType	= $("#topQuickSearchStepUl li a[class='on']").attr("lctrtype");
# 		var target		= $(":radio[name='topQuickSearchTargetRadio']:checked").val();
#
# 		if(dstin == undefined) {
# 			alert("유형을 선택해 주세요"); return;
# 		}
#
# 		prodUlObj.empty();	// 강좌부분 초기화
#
# 		var data = {
# 			type : 'prod',
# 			relm : relm,
# 			subj : subj,
# 			tcd : tcd,
# 			dstin : dstin,
# 			lctrType : lctrType,
# 			target : target
# 		};
#
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/common/topPage/getQuickLctrInfoByAjax.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 						//prodUlObj.empty();
# 					makeTopQuickLctrProd(data.data);
# 				} else {
# 					alert("상품 정보를 가져오는데 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
#
# 	/* 빠른 강좌 찾기_초기화 */
# 	function initQuickProdContent() {
# 		$("#topQuickSearchStepUl").empty();
# 		$("#topQuickSearchRelmUl").empty();
# 		$("#topQuickSearchTcdUl").empty();
# 		$("#topQuickSearchSubjUl").empty();
# 		$("#topQuickSearchTargetUl").empty();
#
# 		$("#topQuickSearchTypeUl li").children().removeClass("on");
# 		$(":radio[name=topQuickSearchTargetRadio]").first().prop("checked", "checked");
# 	}
#
# 	/* 배너 로그 */
# 	function setBanrLogTop(banrId,banrLinkType,mid,url,target) {
#    		$.ajax({
#    		    type : "POST",
#    		    async: false,
#    		    dataType : "json",
#    		    data : {banrId : banrId,
#    		    		mbrId : "",
#    		    		mbrCoType : "",
#    		    	  },
#    		    url : "/main/setBanrLog.ds",
#    		    success : function(data){
#    		    	if(data.code == "success") {
#    		    		//01 : 이미지링크타입, 02: 동영상 링크, 03: 알럿
#    		    		if(banrLinkType == "01") {
#    		    			//alert(url);
#    		    			//goPageFunc(url,target);
#    		    			window.open(url,target)
#    		    		} else if(banrLinkType == "02") {
#    		    			winPopupOpen("/common/aquaplayer/getAquaplayerOpenPop.ds?view=freeView&mode=02&mid="+mid, 807, 530, "_playerPop", "resizable=yes", '', '100');
#    		    		} else if(banrLinkType == "03") {
#    		    			alert(url);
#    		    		}
#    		    	}
#    		    }
#    		});
#    	}
#
# 	/* 관심 선생님 설정 */
# 	function initTopProfileImg() {
# 		var interestTcdAreaObj = $("#interestTcdArea");
#
# 		interestTcdAreaObj.empty();
#
# 		for (var i = 0; i < 8; i++) {
# 			interestTcdAreaObj.append("<li><img src='http://img.mimacstudy.com/FRONT/main/img_tch_default.png' /></li>");
# 		}
# 	}
#
# 	function addTopProfileImg(obj) {
# 		var tcdObj 			= $(obj);
# 		var relm				= tcdObj.attr("relm");
# 		var subj				= tcdObj.attr("subj");
# 		var tcd				= tcdObj.attr("tcd");
# 		var relmName		= tcdObj.attr("relmName");
# 		var tcdName		= tcdObj.attr("tcdName");
# 		var insertIndex	= $("#interestTcdArea li[class='on']").length;
# 		var isDuplicate	= false;
# 		var htmlCode		= "<li class='on' id='topProfileLi" + tcd + "' tcd='" + tcd + "'>";
#
# 		if(insertIndex > 7) {
# 			alert("관심선생님 은 최대 8명까지만 설정 가능합니다."); return;
# 		}
#
# 		$.each($("#interestTcdArea li"), function(i, data) {
# 			if($(this).hasClass("on") && tcd == $(this).attr("tcd")){
# 				isDuplicate = true;
# 			}
# 		});
#
# 		if(isDuplicate) {
# 			alert("이미 관심선생님으로 등록한 선생님 입니다."); return;
# 		}
#
# 		htmlCode += "<a href='/tcher/eachTcherMain.ds?coType=M&relm=" + relm + "&subj=" + subj + "&tcd=" + tcd + "'>";
# 		htmlCode += "<img src='http://img.mimacstudy.com/mimac_sh/images/tzone/" + tcd + "/" + tcd + "_0010.png' /></a>";
# 		htmlCode += "<div class='tchinfo'><span>" + relmName + " " + tcdName + "</span>";
# 		htmlCode += "<button type='button' name='interestTcdDelBtn' onclick='delTopProfileImg(this);' tcd='" + tcd + "'><img src='http://img.mimacstudy.com/FRONT/main/btn_close.png' /></button></div></li>";
#
# 		if(insertIndex == 0) $("#interestTcdArea").prepend(htmlCode);
# 		else						 $("#interestTcdArea li").eq(insertIndex-1).after(htmlCode);
#
# 		$("#interestTcdArea li").last().remove();
# 	}
#
# 	function delTopProfileImg(obj) {
# 		var tcd = $(obj).attr("tcd");
#
# 		$("#topProfileLi" + tcd).remove();
# 		$("#interestTcdArea").append("<li><img src='http://img.mimacstudy.com/FRONT/main/img_tch_default.png' /></li>");
# 	}
# 	/* 관심 선생님 설정 */
#
# 	/* 로그인 */
# 	function upperLoginAction(event){
# 		$("#refUrl").val(document.URL.replace(/\?/g, "|@").replace(/&/g, "|"));
# 		$("#upperloginForm").submit();
# 	}
#
# 	/* 쿠키생성 */
# 	function autoCompleteCookie(cValue){
# 		var todayDate = new Date();
# 		var expiredays = 365;
# 		var cookie_name = "mimacAutoCompleteChk";
# 		todayDate.setDate( todayDate.getDate() + expiredays );
# 		document.cookie = cookie_name + "=" + escape( cValue ) + "; path=/; expires=" + todayDate.toGMTString() +";"
# 	}
#
# 	/* 쿠키가져오기 */
# 	function getCookieAC(cName){
# 		cName = cName + '=';
# 		var cookieData = document.cookie;
# 		var start = cookieData.indexOf(cName);
# 		var cValue = '';
# 		if(start != -1){
# 			start += cName.length;
# 			var end = cookieData.indexOf(';', start);
# 			if(end == -1) end = cookieData.length;
# 			cValue = cookieData.substring(start, end);
# 		}
# 		return unescape(cValue);
# 	}
#
# 	/* 로그아웃 */
# 	function logout(event){
# 		location.href = "/mem/setLogoutProcess.ds";
# 	}
#
# 	/* 정보수정 */
# 	function modInfo(event){
# 		location.href = "/mem/confirmPwdForm.ds?leftMenuId=MNMN_M002";
# 	}
#
# 	/* 수강중인 강좌 이동 */
# 	function goLctrStudy(pAuthNo, openableYn, sdate) {
#         if( openableYn == 'N' ) {
#             alert(sdate + '부터 수강 가능합니다.');
#             return;
#         }
#     	$("#lctrStudyForm #authNo").val(pAuthNo);
#
#     	$("#lctrStudyForm").attr("action", "/myzone/mypage/mylctr/detail/myStudyingCourseDetail.ds");
#         $("#lctrStudyForm").submit();
#     }
#
#
# 	//팝업에서의 링크 처리 & 로그 (pr페이지에서 해당함수가 없어서 작동을 안함 popupGoLink를 그대로 가져와서 이름만 변경 mis작업번호 #617780 2018.07.23 전창수 )
# 	function popupGoLinkTop(id,url,target,closeAc,alertAc,videoYn,flag) {
#
# 		var data = { popId : id, mbrCoType : 'M'};
# 		$.ajax({
# 			type : "POST" ,
# 			url : "/common/regPopupLog.ds",
# 			data : data,
# 			dataType : "json" ,
# 			success : function(data) {
# 				if(data.code == "success") {
# 					if((target=="Y" ||  target == "N" ) && closeAc == "N" && alertAc == "N" && videoYn == "N" ){
# 						window.open(url, target=="Y" ? "_blank" : "_self")
# 					}else if(closeAc == "Y"){
# 						var urlArray = url.split('|');
# 						if(urlArray[0] == "#closeToday") {
# 							if (typeof urlArray[1] == 'undefined'){
# 								urlArray[1] = 1;
# 							}
# 							closeLayer("mainPop"+id,urlArray[1]);
# 						} else {
# 							closeLayer("mainPop"+id);
# 						}
# 					}else if(alertAc == "Y"){
# 					  alert(url);
# 					  return false;
# 					}else if(videoYn == "Y"){
# 						winPopupOpen("/common/aquaplayer/getAquaplayerOpenPop.ds?view=freeView&mode=02&mid="+url, 1055, 563, "_playerPop", "resizable=yes", '', '100');
# 					}
# 				} else {
# 					//alert("메인팝업 클릭 로그정보 저장에 실패하였습니다.");
# 				}
# 			}
# 		});
# 	}
#
#
# 	/* gnb_rolling_선생님 */
# 	$(document).ready(function(){
# 		/*
# 		var $_roll =  $('.tch_evt .roll');
#
# 		setInterval(function(){
# 			$_roll.toggleClass('on');
# 		}, 2000);
# 		*/
# 	});
# </script>
# <header class="dsm_header">
# <div class="top_divison">
# <h1 class="dsm_logo"><a href="/main/main.ds"><img alt="슬로건 대성마이맥" src="http://img.mimacstudy.com/FRONT/main/renew2017/dsm_logo.gif"/></a></h1>
# <div class="top_member">
# <h2 class="hidden">회원 정보및 로그인</h2>
# <ul>
# <li><a class="view_login" href="#">로그인</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=M000000008">회원가입</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M003">마이페이지</a></li>
# </ul>
# </div>
# <ul class="sns_quick">
# <li><a href="https://www.facebook.com/mimac88/" target="_blank"><img alt="페이스북 바로가기" src="http://img.mimacstudy.com/FRONT/icon/icon_facebook.png"/></a></li>
# <li><a href="https://www.instagram.com/mimacstudy/" target="_blank"><img alt="인스타그램 바로가기" src="http://img.mimacstudy.com/FRONT/icon/icon_instagram.png"/></a></li>
# <li><a href="https://www.youtube.com/channel/UCKziRqbw2AvmAJ5wcYXRaMw?view_as=subscriber" target="_blank"><img alt="유튜브 바로가기" src="http://img.mimacstudy.com/FRONT/icon/icon_youtube.png"/></a></li>
# <li><a href="https://blog.naver.com/mktmimac11" target="_blank"><img alt="네이버 블로그 바로가기" src="http://img.mimacstudy.com/FRONT/icon/icon_naver.png"/></a></li>
# <li><a href="https://post.naver.com/mktmimac22" target="_blank"><img alt="네이버 포스트 바로가기" src="http://img.mimacstudy.com/FRONT/icon/icon_naverpost.jpg"/></a></li>
# </ul>
# <!--// 상단 검색-->
# <div class="top_search">
# <h2 class="hidden">검색관련</h2>
# <div class="sch_area">
# <form onsubmit="return false;">
# <fieldset>
# <legend>검색하기</legend>
# <label class="hidden" for="srchTxt">검색 키워드 입력</label>
# <div class="search_input">
# <input id="srchTxt" name="srchTxt" type="text" value=""/>
# <button id="topSearchBtn" type="button">검색하기</button>
# </div>
# </fieldset>
# </form>
# <a class="quick_find_lec" href="#" type="button">빠른강좌찾기</a>
# </div>
# <!--// 추천어 -->
# <div class="keyword_link">
# <ul class="scroll_wrap" id="srchBannerScroll">
# </ul>
# <button class="top_bn_prev" type="button">이전</button>
# <button class="top_bn_next" type="button">다음</button>
# </div>
# <!--// 추천어-->
# </div>
# <!--// 상단 검색-->
# <!--// 상단 배너(RE02) -->
# <div class="top_issue_bn">
# <ul class="scroll_wrap" id="topMainBnr">
# <li><a href="#" onclick="setBanrLog('CB00010104','01','','/ex/prod/2020/feb0128/258852_indexfull.ds','_self');return false;"><img alt="2월 특강" src="http://img.mimacstudy.com/admin_sh/images/site/banner/sfHqVb158018819236300074" usemap="#RE02_1_CB00010104"/></a></li>
# <li><a href="#" onclick="setBanrLog('CB00009820','01','','/ex/prod/2020/nLctr0110/231233_indexfull.ds','_self');return false;"><img alt="N수 특강" src="http://img.mimacstudy.com/admin_sh/images/site/banner/QDdkiP157863002042400010" usemap="#RE02_2_CB00009820"/></a></li>
# </ul>
# <button class="top_bn_prev" type="button">이전</button>
# <button class="top_bn_next" type="button">다음</button>
# </div>
# <!--// 상단 배너(RE02) -->
# <div id="lay2"></div>
# </div>
# <!--// 메인 메뉴-->
# <div class="global_gnb">
# <h2 class="hidden">메인메뉴</h2>
# <nav class="main_menu">
# <ul>
# <li class="gnb_teacher">
# <a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M004">마이맥선생님</a>
# <a class="tcher_all_view" href="#" id="topInterestTcdImg">선생님 전체보기</a>
# </li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M005">예비 고3·N수</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M006">예비 고2·1</a> </li>
# <!--
# 				<li class="gnb_month_exm">
# 					<a href="/ex/ipsi/tchrMock/2017/0712/757963_indexfull.ds">월간실모</a>
# 					<a href="#" class="view_list">월간실모 더보기</a>
# 					<div class="month_wrap">
# 						<ul>
# 							<li class="kor"><a href="/ex/ipsi/sangsang/2017/0206/741852_indexfull.ds"><em>상상국어 모의고사</em> 국어, 14번의 수능을 체험하다!</a></li>
# 							<li class="math"><a href="/ex/t279/2017/0824/145365_indexfull.ds"><em>한석만 실전모의고사</em> 수학, 아홉 번의 수능 실전훈련</a></li>
# 							<li class="sci"><a href="/ex/t454/2017/0712/236636_indexfull.ds"><em>월간 한종철</em> 생명과학, 만점 그 이상의 전략</a></li>
# 						</ul>
# 					</div>
# 				</li> -->
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M008">입시정보</a>
# </li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M009">모의고사 </a></li>
# <li class="afp_evt">
# <a class="pass19" href="#" onclick="setBanrLog('CB00010034','01','','/ex/prod/2019/afp1231/094212_indexfull.ds','_self');return false;">
# <span>19</span> 패스
# 		         	 			</a>
# </li>
# <script type="text/javascript">
# 						var pass_ico = $('.pass_ico > span');
#
# 						if(pass_ico.length > 1){
# 							var widthArr = []
# 							pass_ico.each(function(){
# 								var ico_width = $(this).width();
# 								widthArr.push(ico_width);
# 							});
#
# 							widthArr.sort(function(a,b){
# 								return b - a;
# 							});
# 							$('.pass_ico').width((widthArr[0]+10)+'px');
# 							pass_ico.eq(1).hide();
# 							if(pass_ico.length > 1){
# 								curnum = 1;
# 								setInterval(function(){
# 									curnum = (curnum+1) % 2;
# 									pass_ico.hide().eq(curnum).show();
# 								},2000);
# 							}
# 						}
# 				</script>
# <!-- 				<li> -->
# <!-- 					<a href="/ex/prod/2019/afp2021/292131_indexfull.ds" class="pass19"><span>19</span> 패스 -->
# <!-- 							<b class="pass_ico">오늘마감</b></a> -->
# <!-- 				</li> -->
# <li class="gnb_ex_wrap">
# <a class="gnb_ex" href="/ex/prod/2020/ebs0121/466133_indexfull.ds">EBS 수능특강</a>
# </li>
# <li class="gnb_more">
# <a href="#">더보기</a>
# <ul class="gnb_more_view">
# <li><a href="/acdex/acdexMain.ds?requestMenuId=MNMN_M007">대학별고사</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M012">이벤트</a></li>
# <!-- <li><a href="/off/icHome.ds?leftMenuId=MNMN_M010">대성IC</a></li> -->
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M011">스마트존</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M013">고객센터</a></li>
# </ul>
# </li>
# <li class="gnb_academy">
# <a href="#">대성학원</a>
# <div class="gnb_academy_wrap">
# <p class="go_ac_service">
# <a href="/off/dsHome.ds?leftMenuId=MNMN_M010">대성학원생 전용</a>
# </p>
# <ul class="ac_link">
# <li><a href="http://www.dshw.co.kr" target="_blank">대성학원 소개</a></li>
# <li><a href="http://noryangjin.dshw.co.kr/" target="_blank">대성학원(노량진)</a></li>
# <li><a href="http://kangnam.dshw.co.kr/" target="_blank">강남대성학원</a></li>
# <li><a href="http://kangnamin.dshw.co.kr/" target="_blank">강남대성학원인문별관</a></li>
# <li><a href="http://kangnamja.dshw.co.kr/" target="_blank">강남대성학원자연별관</a></li>
# <li><a href="http://songpa.dshw.co.kr/" target="_blank">강남대성(송파)학원</a></li>
# <li><a href="http://campuskangnam.dshw.co.kr/" target="_blank">강남대성기숙학원(본관)</a></li>
# <li><a href="http://campusm.dshw.co.kr/" target="_blank">강남대성기숙학원(의대관)</a></li>
# <li><a href="http://busan.dshw.co.kr/" target="_blank">부산대성학원</a></li>
# <li><a href="http://mimac.dshw.co.kr/" target="_blank">강대마이맥학원</a></li>
# <li><a href="http://kndsdn.dshw.co.kr/" target="_blank">강남대성단과 · 논술학원</a></li>
# <li><a href="http://www.namyangjuds.co.kr/" target="_blank">남양주기숙학원</a></li>
# <li><a href="http://dsbusan.cafe24.com/" target="_blank">부산대성기숙학원</a></li>
# </ul>
# <p class="close_btn">
# <button type="button">닫기X</button>
# </p>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <!--// 메인 메뉴-->
# <!--// 외부 광고 스크립트 -->
# <div class="google_ad">
# <script src="/js/adscript.js" type="text/javascript"></script>
# <!--
# 		테스트 단계 : 로컬에서만 막는다.
# 		테스트 끝나면 wdev, local 막고 실서버에서만 적용 할 것!
# 	-->
# <!--// 네이버 스크립트_20180221 -->
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <!-- 네이버 스크립트_20180221 //-->
# <!--// 카카오 180418 -->
# <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
# <!--// 카카오 180418 -->
# <!-- //크리테오 공통 스크립트 191106 -->
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <!-- //크리테오 공통 스크립트 191106 -->
# <!--// twitter_website_tag_code_snippet 190710  -->
# <script src="//platform.twitter.com/oct.js" type="text/javascript"></script>
# <!-- twitter_website_tag_code_snippet 190710  //-->
# <script type="text/javascript">
# 		// 타게팅게이츠 공통 변수 선언
# 		var loginUniqueId = "";
# 		var loginMbrId = "";
# 		var user_email = "";
#
# 		if(""!=""){
# ...
# 				var tchLeftBanrList = $.parseJSON('[{"menuId":"TM00000803","imgName":"vkXEXL158157903094100037","imgPath":"/admin_sh/images/tzone/banner","upldImgName":"bn_left_200x120_200213.gif","linkInfo":"http://www.mimacstudy.com/ex/t531/2020/0213/958211_indexfull.ds","sortOrd":0,"banrName":"아무단어챌린지","banrType":"I","newWinYn":"N","newYn":"Y","useYn":"Y","openYn":"Y"}]');
# 				var tchLctrCnt			= "33";
#
# 				//선생님별 레프트 메뉴 만들기
# 				$.each(tchLeftMenuList, function(i, data) {
# 					menuName 	= data.menuName;
# 					scrnUrl		= data.scrnUrl;
# 					newYn		= data.newYn;
# 					newWinYn	= data.newWinYn;
# 					boldYn		= data.boldYn;
# 					tcd			= data.tcd;
# 					menuDepth	= data.menuDepth;
# 					menuLevel   = data.lv;
# 					menuId		= data.menuId;
# 					upMenuId	= data.upMenuId;
# 					linkUrl		= data.linkUrl;
# 					childNum	= data.childNum;
# 					htmlCode	= "";
# 					if(i == menuIdx)
# 					{
# 						htmlCode = "<li" + (i == menuIdx ? " class=on" : "") + ">";
# 					}else
# 					{
# 						if(boldYn=="Y")
# 						{
# 							htmlCode = "<li class=emph>";
# 						}else
# 						{
# 							htmlCode = "<li>";
# 						}
# 					}
#
# 					if(upMenuId != "ROOT")
# 					{   // 일반 레프트 메뉴
# 						if(menuName == "개설강좌") menuName = menuName + "(" + tchLctrCnt + ")";
# 						else					menuName = menuName + (childNum == 0 ? "" : "(" + childNum + ")");
#
# 						if(scrnUrl != null && scrnUrl != "")
# 							htmlCode += "<a href=javascript:goTchHomeMenu('"+scrnUrl+"','"+data.remark+"','"+paramRelm+"','"+paramTcd+"','"+i+"','"+newWinYn+"')>" + menuName;
# 						else
# 							htmlCode += "<a href=javascript:goTchHomeMenu('"+linkUrl+"','"+data.remark+"','"+paramRelm+"','"+paramTcd+"','"+i+"','"+newWinYn+"')>" + menuName;
#
# 						if(newYn == "Y") htmlCode += "<img src=\"http://img.mimacstudy.com/FRONT/common/icon_new.png\" class='icon_new' />";
#
# 						htmlCode +=   "</a>";
#
# 						htmlCode += "<div id='div_" + menuId + "'><ul id='" + menuId + "'></ul></div></li>";
#
# 						if(menuLevel == "1" || menuLevel == "2")
# 						{
# 							$("#tcdLeftMenuUl").append(htmlCode);
# 						}
# 						else
# 						{
# 							if(!$("#div_" + upMenuId).hasClass("submenu")) $("#div_" + upMenuId).addClass("submenu");
# 							$("#" + upMenuId).append(htmlCode);
# 						}
# 					}
# 				});
# 				//선생님별 레프트 배너 만들기
# 				htmlCode = "";
# 				$.each(tchLeftBanrList, function(i, data) {
# 					banrId	 	= data.banrId;
# 					banrName	= data.banrName;
# 					banrType 	= data.banrType;
# 					imgName		= data.imgName;
# 					imgPath		= data.imgPath;
# 					linkInfo	= data.linkInfo == undefined ? "" : data.linkInfo;
# 					newWinYn	= data.newWinYn;
# 					newYn		= data.newYn;
# 					useYn		= data.useYn;
# 					openYn		= data.openYn;
#
# 					if(imgName != undefined || linkInfo != undefined)
# 					{
# 						if(linkInfo.substring(0, 3) == "MOV") {
# 							bannerLink = "VOD";
# 							linkInfo = linkInfo.substring(4, 15);
# 						} else {
# 							bannerLink = "BannerLink";
# 						}
#
# 						if(openYn == "Y") {
#
# 							if(banrType == "T")	htmlCode += '<p class="btnbanner"><a href="javascript:open'+bannerLink+'(\'' + linkInfo + '\', \'' + banrId + '\', \'' + newWinYn + '\');" class="btnbanner txtbanner">' + banrName + '</a></p>';
# 							else				htmlCode += '<a href="javascript:open'+bannerLink+'(\'' + linkInfo + '\', \'' + banrId + '\', \'' + newWinYn + '\');" class="btnbanner"><img src="http://img.mimacstudy.com/admin_sh/images/tzone/banner/' + imgName + '" /></a>';
#
# 						} else if(openYn == "R") {	//준비중
# 							if(banrType == "T")	htmlCode += '<p class="btnbanner"><a href="javascript:alert(\'' + linkInfo + '\');" class="btnbanner txtbanner">' + banrName + '</a></p>';
# 							else				htmlCode += '<a href="javascript:alert(\'' + linkInfo + '\');" class="btnbanner"><img src="http://img.mimacstudy.com/admin_sh/images/tzone/banner/' + imgName + '" /></a>';
# 						}
#
# 					}
# 				});
# 				$("#tcdHome .bannerarea").html(htmlCode);
# 			}
#
# 			var eventCallYn = "N";
#
# 			$("li[name='relmLi']").click(function() {
# 				if(eventCallYn == "Y") {
# 					eventCallYn = "N"; return;
# 				}
#
# 				if ($(this).hasClass("open")) {
# 					$(this).removeClass("open").removeClass("on").addClass("close");
# 	         	}else if ($(this).hasClass("close")) {
# 	         		$("li[name='relmLi']").removeClass("open").removeClass("on").removeClass("close").addClass("close");
# 	           		$(this).removeClass("close").addClass("open").addClass("on");
# 	         	}
# 		   	});
#
# 			$("a[name='childA']").click(function(event) {
# 				eventCallYn = "Y";
# 		   	});
#
# 			$("#tcdTypeDiv a").click(function(event) {
# 				var aId = $(this).attr("id");
#
# 				$("#tcdTypeDiv a").removeClass("on");
# 				$(this).addClass("on");
#
# 				if(aId == "tcdAlla") {
# 					$("#mimacTcdHome").show();
# 					$("#tcdHome").hide();
# 				} else {
# 					$("#tcdHome").show();
# 					$("#mimacTcdHome").hide();
# 				}
# 		   	});
# 		});
#
# 		function goTchHomeMenu(scrnUrl, remark, relm, tcd, menuIdx,newWinYn)
# 		{
# 			if(scrnUrl == 'undefined' || scrnUrl == undefined) return;
#
# 			$("#relm").val(relm);
# 			$("#tcd").val(tcd);
# 			$("#type").val(relm + tcd);
# 			$("#menuIdx").val(menuIdx);
# 			$("#tcdTabType").val("tcdHome");
# 			if(newWinYn == "Y")
# 			{$("#leftFrm").attr("target", "_blank");}
# 			else{$("#leftFrm").attr("target", "_self");}
# 			$("#leftFrm").attr("action", scrnUrl + (remark == 'undefined' || remark == undefined ? "" : "?"+remark));
# 			$("#leftFrm").submit();
# 		}
#
# 		function openBannerLink(linkUrl, banrId, newWinYn) {
#
#
# 			var data = {
# 				  banrId : banrId
# 				, mbrCoType : 'M'
# 			};
#
# 			$.ajax({
# 				type : "POST" ,
# 				url : "/hi3/regBanrLog.ds",
# 				data : data,
# 				dataType : "json" ,
# 				success : function(data) {
# 					if(data.code == "success") {
# 						if(linkUrl.charAt(0) == '/') linkUrl = "" + linkUrl;
#
# 						if(newWinYn == "Y") {
# // 							winPopupOpen(linkUrl, 695, 225, "bannerLinkPopup");
# 							window.open(encodeURI(linkUrl),"bannerLinkPopup");
# 							return;
# // 							$("#skyForm").attr("target", "_blank"); //winPopupOpen(linkUrl, 695, 225, "bannerLinkPopup");
# 						}else{
# 							$("#skyForm").attr("target", "_self"); //location.href = linkUrl;
# 						}
#
# 						$("#skyForm").attr("action", linkUrl).submit();
# 					} else {
# 						alert("배너클릭 로그정보 저장에 실패하였습니다.");
# 					}
# 				}
# 			});
# 		}
# 	</script>
# </meta></head>
# <body id="mteacher">
# <form id="leftFrm" method="post" name="leftFrm">
# <input id="relm" name="relm" type="hidden" value=""/>
# <input id="tcd" name="tcd" type="hidden" value=""/>
# <input id="type" name="type" type="hidden" value=""/>
# <input id="tcdTabType" name="tcdTabType" type="hidden" value=""/>
# <input id="menuIdx" name="menuIdx" type="hidden" value=""/>
# <input id="relmName" name="relmName" type="hidden" value="영어"/>
# <input id="tcdName" name="tcdName" type="hidden" value="이명학"/>
# </form>
# <div class="leftarea mthome">
# <div class="tabmenu" id="tcdTypeDiv" style="display: none;">
# <a href="#" id="tcdAlla" style="text-decoration:none;">선생님 전체</a>
# <a class="on" href="#" id="tcdHomea" style="text-decoration:none;">선생님 홈</a>
# </div>
# <div class="" id="mimacTcdHome">
# <h2><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M004" style="text-decoration:none;">마이맥선생님</a></h2>
# <ul class="leftmenu" id="ulLeftmenu"></ul>
# <div class="bannerarea"></div>
# </div>
# <div id="tcdHome">
# <h2>영어<span style="font-size: 14px;"><a href="/tcher/eachTcherMain.ds?tcd=531&amp;relm=03&amp;subj=&amp;type=" style="text-decoration:none;">이명학 선생님</a></span></h2>
# <ul class="leftmenu" id="tcdLeftMenuUl"></ul>
# <div class="bannerarea"></div>
# </div>
# </div>
# </body>
# </html><!-- //E: leftarea -->
# <!-- S: contentsarea -->
# <div class="contentsarea">
# <div id="pageInPut">
# <div style="position:absolute;left:50%;margin:20px 0;z-index:100;">
# <img alt="로딩중" src="http://img.mimacstudy.com/FRONT/common/img_loading_check.gif"/>
# </div>
# </div>
# <!--// 왼쪽 스카이배너 -->
# <div class="left_sky_bnr">
# <ul id="indexLeftBannerDiv">
# </ul>
# </div>
# <!-- 왼쪽 스카이배너 //-->
# <!--// 오른쪽 스카이 배너 -->
# <div class="right_sky_bnr">
# <div id="rightSkyBannerDiv"></div>
# </div>
# <!-- 오른쪽 스카이 배너 //-->
# </div>
# <!-- //E: contentsarea -->
# </div>
# <div id="passLay"></div>
# <!-- S: Footer -->
# <style type="text/css">
#  .foot_fix_bn .botBanCloseBtn{position:absolute; width:30px; height:30px; top:16px; right:50%; margin-right:-710px; z-index:5;}
# </style>
# <script type="text/javascript">
# 	$(document).ready(function(event){
# 	    $("#familySiteMoveBtn").bind("click", linkFamilySite);
#
# 	    // 모바일 버전 바로가기
# 	    var currentOS = getOS();
#
# 	    if( currentOS != 'ETC') {
# 	     	$(".bottomarea").append("<div class='go_mobile'></div>");
# 	     	$(".bottomarea .go_mobile").append("<a href='http://m.mimacstudy.com/mobile/main/main.ds'>모바일버전 이동하기</a>");
#
# 	        return;
#
# 	    }
#
# 	});
#
# 	function linkFamilySite(event){
# 		if($("#familySiteCombo").val() != ""){
# 			window.open($("#familySiteCombo").val(), "_blank");
# 		}
# 	}
#
# 	function getOS() {
#         var currentOS;
#         var mobile = (/iphone|ipad|ipod|android/i.test(navigator.userAgent.toLowerCase()));
#
#         if (mobile) {
#             // 유저에이전트를 불러와서 OS를 구분합니다.
#             var userAgent = navigator.userAgent.toLowerCase();
#             if (userAgent.search("android") > -1)
#                 currentOS = "A";  //android
#             else if ((userAgent.search("iphone") > -1) || (userAgent.search("ipod") > -1)
#                         || (userAgent.search("ipad") > -1))
#                 currentOS = "N";  // iPhone
#             else
#                 currentOS = "ETC";
#         } else {
#             // 모바일이 아닐 때
#             currentOS = "ETC";
#         }
#
#         return currentOS;
#     }
#
#
# </script>
# <footer class="bottomarea">
# <!-- S: Link용 Form -->
# <form id="lctrStudyForm" method="post" name="lctrStudyForm">
# <input id="requestMenuId2" name="requestMenuId2" type="hidden" value="MNMN_M003"/>
# <input id="authNo" name="authNo" type="hidden" value=""/>
# </form>
# <!-- //E: Link용 Form -->
# <div class="footercont">
# <ul class="footermenu">
# <li><a href="http://www.digitaldaesung.co.kr/COM/" target="_blank">회사소개</a></li>
# <li><a href="/mimac/recruitMain.ds">강사모집</a></li>
# <!--       <li><a href="#" onclick="window.open('/mobile/mem/callMemberInfoPolicy.ds','memInfoPolicyPop','width=680px, height=720px, scrollbars=yes');return false;"  class="point">개인정보처리방침</a></li> -->
# <!--       <li><a href="#" onclick="window.open('/mobile/mem/callSiteTermOfUse.ds','memInfoPolicyPop','width=680px, height=720px, scrollbars=yes');return false;">이용약관</a></li> -->
# <li><a class="point" href="/mem/callMemberInfoPolicy.ds">개인정보처리방침</a></li>
# <li><a href="/mem/callSiteTermOfUse.ds">이용약관</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=MNMN_M013">고객센터</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=M000000077">사이트맵</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=M000000076">찾아오시는길</a></li>
# <li><a href="/common/getMenuContainer.ds?requestMenuId=M000000078">제휴문의</a></li>
# </ul>
# <p class="footerlogo">
# <img alt="大成마이맥" src="http://img.mimacstudy.com/FRONT/common/img_logofooter.png"/>
# <p>
# <div class="address">
# <address>
#         서울시 서초구 방배로 181 (방배동. 단우빌딩 6,7,8층) (주)디지털대성 고객센터 : 02-5252-110 <a href="mailto:help@mimacstudy.com">help@mimacstudy.com</a><br/>
#         사업자 등록번호 : 114-81-96124 대표이사 : 김희선 통신판매업 신고증 : 2011-서울 서초 - 0170호 <a class="btn" href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=1148196124" target="_blank"><img alt="정보조회" src="http://img.mimacstudy.com/FRONT/common/txt_infosearch.png"/></a> 개인정보보호 책임자  : 양세현<br/>
# 		학원설립·운영등록번호 : 제10281호 디지털대성원격학원  <a class="btn" href="#" onclick='window.open("/ex/common/img_pop.ds?img_name=/common/img_edudoc.jpg", "_blank", "width=531, height=767, scrollbars=no, left=0, top=0"); return false;' target="_blank"><img alt="정보조회" src="http://img.mimacstudy.com/FRONT/common/txt_infosearch.png"/></a>
# 		호스팅서비스 사업자 : ㈜디지털대성
#       </address>
# <p class="copyright">
#         copyright since2012 <b>(주)디지털대성</b> All rights reserved.
#       </p>
# </div>
# <p class="escrow">
# <a href="https://pgweb.uplus.co.kr/ms/escrow/s_escrowYn.do?mertid=dsmimac1" onclick="window.open('https://pgweb.uplus.co.kr/ms/escrow/s_escrowYn.do?mertid=dsmimac1', '_blank', 'width=474, height=533, scrollbars=no, left=0, top=0'); return false;"><img alt="LG U+ escrow 안전거래" src="http://img.mimacstudy.com/FRONT/common/img_escrowlogo.png"/></a>
# </p>
# <p class="isms"><a href="#" onclick='window.open("/ex/common/img_pop.ds?img_name=/common/img_isms.jpg", "_blank", "width=337, height=483, scrollbars=no, left=0, top=0"); return false;'><img alt="isms인증" src="http://img.mimacstudy.com/FRONT/common/img_isms_logo.png"/></a></p>
# </p></p></div>
# </footer>
# <!-- 올프리패스 이벤트 배너  -->
# <script type="text/javascript">
#
# //메인팝업에서 쓰이는 합수 START
# function setCookie(name, value, expiredays) {
# 	var today = new Date();
# 	today.setDate(today.getDate() + expiredays);
# 	document.cookie = name + '=' + escape(value) + '; path=/; expires=' + today.toGMTString() + ';'
# }
#
# function getCookie(name){
# 	var wcname = name + '=';
# 	var wcstart, wcend, end;
# 	var i = 0;
# 	while(i <= document.cookie.length) {
# 		wcstart = i;
# 	 	wcend   = (i + wcname.length);
# 		if(document.cookie.substring(wcstart, wcend) == wcname) {
# 		  	if((end = document.cookie.indexOf(';', wcend)) == -1)
# 		   		end = document.cookie.length;
# 		  	return document.cookie.substring(wcend, end);
# 	    }
# 		i = document.cookie.indexOf('', i) + 1;
#
# 		if(i == 0)
# 	  		break;
# 	}
#   return '';
# }
#
# //layer 창닫기
# function botCloseLayer(idx, exp) {
#    if(exp != undefined){
# 	   setCookie(idx, "hidden", exp);
#    }
#
#    $("#"+idx).hide();
# }
#
# function botClossPassLayer(todayChk, obj) {
# 	//오늘은 이창열지않음 클릭시에는 쿠키굽는다.
# 	if(todayChk == "Y") {
# 		botCloseLayer(obj,7);
# 	} else {
# 		botCloseLayer(obj);
# 	}
# }
#
# //2018.03.12 박진영 추가(올패스 이용중인지 체크)
# function getPassAuthCheck() {
#
# 	var bnPassAuthYn = "N";
#
# 	$.ajax({
#         type : "POST",
#         async: false,
#         dataType : "html",
#         data :  "" ,
#         url : "/ex/common/getPassAuthCheckAjax.ds",
#         success : function(data){
#         	bnPassAuthYn = data;
#         },
#         error: function(xhr,  Status, error) {
#             //console.log("통신중 장애 발생");
#             //console.log(error);
#         }
#     });
#
# 	return bnPassAuthYn;
# }
#
# </script>
# <div id="mainSubBottomBannerDiv">
# <div class="foot_fix_bn" style="background:url(http://img.mimacstudy.com/admin_sh/images/site/banner/rmZerE158191254252000258)">
# <div class="foot_fix_bn_wrap half_bn_wrap">
# <a href="#" onclick="setBanrLog('CB00010310','01','','/ex/prod/2019/afp1231/094212_indexfull.ds','_self');return false;">
# <img alt="0224" src="http://img.mimacstudy.com/admin_sh/images/site/banner/myGURW158191254251700257" usemap="#RE22_1_CB00010310"/>
# </a>
# </div>
# <a class="botBanCloseBtn" href="#" onclick="botCloseLayer('mainSubBottomBannerDiv');return false;"><img id="" src="http://img.mimacstudy.com/FRONT/main/img_close.png"/></a>
# <div class="right_bg" style="background:url(http://img.mimacstudy.com/admin_sh/images/site/banner/QeabqW158191254252100259)"></div>
# </div>
# </div>
# <!-- E: Footer -->
# <form action="" id="skyForm" method="post" name="skyForm"></form>
# </div>
# <script src="/js/customSelect_ui.js" type="text/javascript"></script>
# </body>
# </html>

# %%
soup.find('tr')

# %%
rows = driver.find_elements_by_tag_name('tr')

# %%
for row in rows:
    print(row.text)
# Out:
# 번호 유형 제목 조회수 등록일 글쓴이
# ★ 공지 [자주 묻는 질문 3] 커리큘럼 65747 2018/11/16 운영자
# ★ 공지 [자주 묻는 질문 2] 학습법 51582 2018/11/16 운영자
# ★ 공지 [자주 묻는 질문 1] 일반 34369 2018/11/16 운영자
# 639330 강좌
# 일리
# 의문대명사 관련 질문 0 2020/02/17 장건민
# 639329 기타
# 교재 0 2020/02/17 김종성
# 639328 강좌
# Syntax 1.0 [평가원 구문독해]
# 가정법 과거완료 2 2020/02/17 공진표
# 639327 강좌
# Syntax 1.0 [평가원 구문독해]
# Syntax 271번 0 2020/02/17 구본진
# 639326 강좌
# Syntax 1.0 [평가원 구문독해]
# 13쪽 7번 문장에 help 질문 0 2020/02/17 김형우
# 639325 강좌
# 일리
# 관계부사 0 2020/02/17 구나경
# 639324 기타
# 영어해석 1 2020/02/17 윤강준
# 639323 강좌
# Syntax 1.0 [평가원 구문독해]
# Syntax 252번 1 2020/02/17 구본진
# 639322 학습법
# [재질문] 고2 3 2020/02/17 박재형
# 639321 교재
# 일리
# 전치사구의 역할 3 2020/02/17 정서영
# 639320 강좌
# [2021] R`gorithm[독해 알고리즘]
# keywording 1 2020/02/17 정인빈
# 639319 강좌
# 공감! 어법 1.0
# 공감어법 지금 0 2020/02/17 서정현
# 639318 강좌
# Syntax 1.0 [평가원 구문독해]
# Syntax 241번 0 2020/02/17 구본진
# 639317 교재
# 일리
# 동명사 타동사 0 2020/02/17 구나경
# 639316 강좌
# [2021] R`gorithm[독해 알고리즘]
# 72페이지 28번 0 2020/02/17 김찬주

# %% [markdown]
# # MegaStudy (JJS)

# %%
set_driver()
connect_site_with_url(teacher_dic['jjs'], 3)

# %%
rows = driver.find_elements_by_tag_name('tr')

# %%
for row in rows:
    print(row.text)
# Out:
# 번호 분류 제목 이름 등록일 상태
# 공지 ★ 워크북 활용 매뉴얼
# 공지 * [2019-03-14] 자주 올라오는 질문
# 공지 질문시 꼭 지켜주세요.(지켜지지 않으면 답변 없습니다. by 조정식)
# 125569 기타 현강버전이랑 인강버전의 차이점이 뭔가요 전태원 2020-02-17 답변대기
# 125568 강좌 4번 문제 Sport 관련 질문+6번 문제 양을세는 세속적 열망 관련 질문 전예주 2020-02-17 답변대기
# 125567 강좌 질문있습니다. 최혜인 2020-02-17 답변완료
# 125566 기타 괜찮아 어휘편교재 이현지 2020-02-17 답변대기
# 125565 교재 195번 김동진 2020-02-17 답변완료
# 125564 기타 확실해 믿어봐 이현지 2020-02-17 답변대기
# 125563 강좌 193번 김동진 2020-02-17 답변완료
# 125562 강좌 질문 이동현 2020-02-17 답변완료
# 125561 교재 293번 지문 김도연 2020-02-17 답변완료
# 125560 강좌 Of 김민희 2020-02-17 답변대기

# %%
JJS_PAGE = requests.get(teacher_dic['jjs'])

# %%
soup = bs(JJS_PAGE.content, from_encoding='cp949')
table = soup.find('table')
rows = table.find_all('tr')

# %%
soup.find('tr')
# Out:
# <tr>
# <td bgcolor="ffffff" valign="top">
# <!--include virtual="/lecture/quick_menu_inc.asp"-->
# <table border="0" cellpadding="0" cellspacing="0" width="130">
# </table></td>
# </tr>

# %% [markdown]
# # SkyEdu (JHC)

# %%
set_driver()
connect_site_with_url(teacher_dic['jhc'], 3)

# %%
html = requests.get(teacher_dic['jhc'], time.sleep(5))

# %%
soup = bs(html.text, from_encoding = 'CP949')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <!--[if IE 7]> <html class="ie7" lang="ko"> <![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VgcBWFJSChABVFJVBgYCV1E=",licenseKey:"72029d3b1f",applicationID:"103717515"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(21),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(22),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),c.xhrWrappable&&t(10),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(9),s=t(8),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof x&&(this.bstStart=y.now())}),o.on(w,function(t,n){var e=t[0];e instanceof x&&i("bst",[e,n,this.bstStart,y.now()])}),a.on(m,function(t,n,e){this.bstStart=y.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,y.now(),this.bstType])}),s.on(m,function(){this.bstStart=y.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,y.now(),"requestAnimationFrame"])}),o.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),o.on(g+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t("wrap-function")(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[t ...
# <meta content="LlcXl_Ii2iPmWtRa9fDGOUGvWOf4Yx5PpJ3AXpaWIc0" name="google-site-verification"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-132332145-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-132332145-1');
# </script>
# <meta content="d7f59dee931a1a84575775bdfadab5932f7a38c1" name="naver-site-verification"/>
# <meta content="7933dcc9bd9630880eab5e68c352a0ba2944331a" name="naver-site-verification"/>
# <meta content="수능까지 전과목 무제한 수강 스듀패스, 딱 15분 인강, 명문대 선배 멘토링" name="description"/>
# <meta content="수능까지 전과목 무제한 수강 스듀패스, 딱 15분 인강, 명문대 선배 멘토링" name="keywords"/>
# <meta content="커넥츠 스카이에듀" property="og:title"/><!-- 제목표시 -->
# <meta content="수능까지 전과목 무제한 수강 스듀패스, 딱 15분 인강, 명문대 선배 멘토링" property="og:description"/><!-- 본문내용 -->
# <meta content="website" property="og:type"/><!-- 사이트 종류 -->
# <meta content="https://static.conects.com/skyedu_conects/imgs/m/common/skyedu.png?202002181453" property="og:image"/>
# <meta content="http://skyedu.conects.com/" property="og:url"/><!-- 표준 URL -->
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/img/favicon/CONECTS_150x150.png" name="msapplication-square70x70logo"/>
# <meta content="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/img/favicon/CONECTS_150x150.png" name="msapplication-square150x150logo"/>
# <link href="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/img/favicon/CONECTS_32x32.ico" rel="shortcut icon"/>
# <link href="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/img/favicon/CONECTS_180x180.png" rel="apple-touch-icon-precomposed"/>
# <title>커넥츠 스카이에듀</title>
# <script src="https://skyedu.conects.com/js/common/common.js?202002181453" type="text/javascript"></script>
# <!-- conects header -->
# <!-- css 섹션 -->
# <link href="//static.conects.com/common/css/st-comm-v4/st-comm-v4.0.0.css?202002181453" rel="stylesheet" type="text/css"/>
# <!-- js 섹션 -->
# <script src="//static.conects.com/common/js/jquery/jquery.min.js" type="text/javascript"></script>
# <script src="//static.conects.com/common/js/jquery/jquery-ui.min.js" type="text/javascript"></script>
# <script src="//static.conects.com/common/js/bxslider/jquery.bxslider.js" type="text/javascript"></script>
# <script src="//static.conects.com/common/js/greensock/TweenMax.min.js" type="text/javascript"></script>
# <script src="//static.conects.com/common/js/jquery.menu-aim/jquery.menu-aim.js" type="text/javascript"></script>
# <!-- 공통 js  4.0.0 // -->
# <script src="//static.conects.com/common/js/jquery.mCustomScrollbar.concat/jquery.mCustomScrollbar.concat.min.js" type="text/javascript"></script>
# <script src="//static.conects.com/common/js/st-pub-v4/st-pub-v4.0.0.js?202002181453" type="text/javascript"></script>
# <!--// conects header -->
# <link href="https://skyedu.conects.com/css/skyedu_conects/v01/layout.css?202002181453" rel="stylesheet" type="text/css"/>
# <link href="https://skyedu.conects.com/css/skyedu_conects/v01/board.css?202002181453" rel="stylesheet" type="text/css"/>
# <script src="https://skyedu.conects.com/js/v01/lib/jquery.cycle2.js" type="text/javascript"></script>
# <script src="https://skyedu.conects.com/js/v01/lib/jquery.cycle2.carousel.min.js" type="text/javascript"></script>
# <script src="https://skyedu.conects.com/js/v01/lib/jquery.cycle2.scrollVert.min.js" type="text/javascript"></script>
# <script src="https://skyedu.conects.com/js/v01/lib/jquery-scrolltofixed-min.js" type="text/javascript"></script>
# <script src="https://skyedu.conects.com/js/v01/common.js?202002181453" type="text/javascript"></script>
# <script id="onLine" src="//www.conects.com/js/course/online.js" type="text/javascript"></script>
# <link href="https://skyedu.conects.com/css/skyedu_conects/popup/popup.css?2020021802" rel="stylesheet" type="text/css"/>
# </head>
# <body id="wide">
# <span itemscope="" itemtype="http://schema.org/Organization">
# <link href="http://skyedu.conects.com" itemprop="url"/>
# <a href="https://www.facebook.com/superskyedu" itemprop="sameAs"></a>
# <a href="http://blog.naver.com/skyedu1st" itemprop="sameAs"></a>
# <a href="https://kin.naver.com/profile/index.nhn?u=bhxRCAFf8gIWLadRnJbEhGOmJVO%2FRtioJnZCg8i1PdM%3D" itemprop="sameAs"></a>
# <a href="http://tv.naver.com/skyedu" itemprop="sameAs"></a>
# <a href="https://www.instagram.com/conects.skyedu/" itemprop="sameAs"></a>
# <a href="https://www.youtube.com/c/skyedu1st" itemprop="sameAs"></a>
# </span>
# <!-- wrap -->
# <div id="wrap">
# <!-- S:Header -->
# <div id="header">
# <style type="text/css">
#         #wrap{min-width:1200px;}
#         .st-conects-snb .nav-gnb-depth-02 dt{color:#BA1425;}
#
# 	        </style>
# <script src="//static.conects.com/static/js/common/st-track.production.js" type="text/javascript"></script>
# <!-- notification js -->
# <script src="//my.conects.com/js/mydangi/notification.js" type="text/javascript"></script>
# <!-- PlayD TERA Log Definition Script Start -->
# <script>
#     window['_LA'] = window['_LA'] || function () {
#         (window['_LA'].q = window['_LA'].q || []).push(arguments)
#     }
# </script>
# <script src="//static.conects.com/static/js/conects_gnb/gnb.js" type="text/javascript"></script>
# <!-- 공통 CSS 선언부 :: 사이트 전체 반영 -->
# <link href="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/css/st_conects.css?202002181453" rel="stylesheet" type="text/css"/>
# <!-- 공통 CSS 선언부 :: 사이트 전체 반영 종료-->
# <script src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/js/st_conects-gnb.js?202002181453"></script>
# <script>
#     var _GNB_SEARCH_ = function () {
#         var gnbCategoryId = ($('#current-interest').data('interest')) ? '&category_id=' + $('#current-interest')
#             .data('interest') : '';
#         window.location.href = '//www.conects.com/common/template/search?keyword=' + encodeURIComponent($(
#             '#gnb_conects_search_text').val()) + gnbCategoryId;
#     };
#     var _GNB_SEARCH_ENTER_ = function (event) {
#         if (event.keyCode === 13) {
#             event.preventDefault();
#             _GNB_SEARCH_();
#         }
#     };
#
#     notification.conectsnotification('');
# </script>
# <div id="hgroup">
# <div class="st_conects-nav">
# <!-- 분기: social, personal -->
# <!-- GNB -->
# <div class="st_conects-gnb">
# <!-- 검색영역 -->
# <div class="st_bi-search">
# <h1 class="bi"><a href="//www.conects.com">CONECTS</a></h1>
# <div class="search-box">
# <input class="inpt-search" id="gnb_conects_search_text" onkeyup="_GNB_SEARCH_ENTER_(event)" placeholder="학원과 독서실을 검색해보세요" type="text" value=""/>
# <button class="btn-search" onclick="_GNB_SEARCH_()" type="button">검색</button>
# </div>
# </div>
# <!-- //검색영역 -->
# <div class="st_personal-service">
# <a class="bi" href="//www.conects.com">Conects</a>
# <dl class="this-service">
# <dt class="depth-01">
# <a class="link-service active" data-interest="38" href="https://skyedu.conects.com/go3/main" id="current-interest" target="_self">
#                             대입·수능                        </a>
# </dt>
# <dd class="depth-02">
# <a class="selected" href="https://skyedu.conects.com/go3/main">스카이에듀</a>
# <ul class="list">
# <li>
# <a href="https://skyedu.conects.com/go3/main" target="_self">스카이에듀</a>
# </li>
# <li>
# <a href="http://www.right-way.co.kr/" target="_blank">수시컨설팅</a>
# </li>
# <li>
# <a href="https://skyedu.conects.com/nondangi/main" target="_blank">논술</a>
# </li>
# <li>
# <a href="https://skyeduac.conects.com/" target="_blank">스카이에듀학원</a>
# </li>
# <li>
# <a href="https://nyjskyedu.conects.com/" target="_blank">남양주 기숙학원</a>
# </li>
# <li>
# <a href="https://swskyedu.conects.com/" target="_blank">수원 학원</a>
# </li>
# <li>
# <a href="https://swdskyedu.conects.com/" target="_blank">수원 학원(단과)</a>
# </li>
# <li>
# <a href="https://gdskyedu.conects.com/" target="_blank">강동학원</a>
# </li>
# <li>
# <a href="https://nrjskyedu.conects.com/" target="_blank">노량진 학원(독학/단과)</a>
# </li>
# <li>
# <a href="https://artskyedu.conects.com/" target="_blank">선릉 예체능관</a>
# </li>
# <li>
# <a href="https://skyeduac.conects.com/public-edu" target="_blank">스카이에듀 공교육</a>
# </li>
# </ul>
# </dd>
# </dl>
# <div class="interesting-service">
# <div class="interestings">
# <div>
# <ul id="gnb-interests-list">
# <li data-interest-code="165" style="display:none">
# <a class="link-service" href="https://kr.tutor.com/elementary">
#                                         유·초등                                    </a>
# </li>
# <li data-interest-code="157" style="display:none">
# <a class="link-service" href="https://www.conects.com/common/template/feed?category_id=157">
#                                         중등·특목                                    </a>
# </li>
# <li data-interest-code="38" style="display:none">
# <a class="link-service" href="https://skyedu.conects.com/go3/main">
#                                         대입·수능                                    </a>
# </li>
# <li data-interest-code="85" style="display:none">
# <a class="link-service" href="https://public.conects.com/">
#                                         대학생·취업                                    </a>
# </li>
# <li data-interest-code="69" style="display:none">
# <a class="link-service" href="https://gong.conects.com/">
#                                         공무원·임용                                    </a>
# </li>
# <li data-interest-code="55" style="display:none">
# <a class="link-service" href="https://eng.conects.com/">
#                                         어학·회화                                    </a>
# </li>
# <li data-interest-code="175" style="display:none">
# <a class="link-service" href="https://imyong.conects.com/">
#                                         임용고시                                    </a>
# </li>
# <li data-interest-code="169" style="display:none">
# <a class="link-service" href="https://www.schole.ac/">
#                                         직무·스타트업                                    </a>
# </li>
# <li data-interest-code="158" style="display:none">
# <a class="link-service" href="https://peet.conects.com/">
#                                         전문직                                    </a>
# </li>
# <li data-interest-code="160" style="display:none">
# <a class="link-service" href="https://gongin.conects.com/">
#                                         공인중개사                                    </a>
# </li>
# <li data-interest-code="177" style="display:none">
# <a class="link-service" href="https://ja.conects.com/">
#                                         자격증                                    </a>
# </li>
# <li data-interest-code="179" style="display:none">
# <a class="link-service" href="https://nomu.conects.com/">
#                                         노무사                                    </a>
# </li>
# <li data-interest-code="181" style="display:none">
# <a class="link-service" href="https://bupmu.conects.com/">
#                                         법무사                                    </a>
# </li>
# <li data-interest-code="183" style="display:none">
# <a class="link-service" href="https://customs.conects.com/">
#                                         관세사                                    </a>
# </li>
# <li data-interest-code="185" style="display:none">
# <a class="link-service" href="https://ca.conects.com/">
#                                         감평사                                    </a>
# </li>
# <li data-interest-code="187" style="display:none">
# <a class="link-service" href="https://beauty.conects.com/">
#                                         뷰티아카데미                                    </a>
# </li>
# <li data-interest-code="128" style="display:none">
# <a class="link-service" href="https://hobby.conects.com/">
#                                         라이프·취미                                    </a>
# </li>
# <li data-interest-code="136" style="display:none">
# <a class="link-service" href="">
#                                         독서                                    </a>
# </li>
# <li data-interest-code="171" style="display:none">
# <a class="link-service" href="">
#                                         반려동물                                    </a>
# </li>
# <li data-interest-code="173" style="display:none">
# <a class="link-service" href="">
#                                         뷰티                                    </a>
# </li>
# </ul>
# <a class="btn-add-interesting" href="#st_conects-interesting-popup">관심사를 추가해보세요</a>
# </div>
# </div>
# <div class="wrap-btn">
# <button class="btn-prev" type="button">이전</button>
# <button class="btn-next" type="button">다음</button>
# </div>
# </div>
# </div>
# <div class="st_social-service">
# <ul class="tab">
# <li><a>SCHOOL</a></li>
# <li><a>UNIVERSITY</a></li>
# <li><a>CAREER</a></li>
# <li><a>LIFE</a></li>
# </ul>
# <div class="list">
# <dl>
# <dt>School</dt>
# <dd><a href="https://kr.tutor.com/elementary">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/60cb696bdf9a445b9c410423a63df040.png"/>
#                                 유·초등                            </a></dd>
# <dd><a href="https://www.conects.com/common/template/feed?category_id=157">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/ad81885a252c8d5d3fb0268f813a9417.png"/>
#                                 중등·특목                            </a></dd>
# <dd><a href="https://skyedu.conects.com/go3/main">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/3d31e116ccf2a953e6759526df5ec396.png"/>
#                                 대입·수능                            </a></dd>
# </dl>
# <dl>
# <dt>University</dt>
# <dd><a href="https://public.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/193591ba5366aac68066e4487f9a46bb.png"/>
#                                 대학생·취업                            </a></dd>
# <dd><a href="https://gong.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/a2671caf40b924e85d061cd898d18e05.png"/>
#                                 공무원·임용                            </a></dd>
# <dd><a href="https://eng.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/24c049f7f2ac747a5dc80b8c336e17db.png"/>
#                                 어학·회화                            </a></dd>
# <dd><a href="https://imyong.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/e61cb275368d8f127850b7eaa8ed3e8a.png"/>
#                                 임용고시                            </a></dd>
# </dl>
# <dl>
# <dt>Career</dt>
# <dd><a href="https://www.schole.ac/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/fc7b85d4532237f7b9f0f5ef3aeee8ef.png"/>
#                                 직무·스타트업                            </a></dd>
# <dd><a href="https://peet.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/5403eb816aa42fbe78e0cb16debad451.png"/>
#                                 전문직                            </a></dd>
# <dd><a href="https://gongin.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/0e5a898aa23b1af4a209158fbd10d19a.png"/>
#                                 공인중개사                            </a></dd>
# <dd><a href="https://ja.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/baa458f24b73d70b61e969a630769f0e.png"/>
#                                 자격증                            </a></dd>
# <dd><a href="https://nomu.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/9542e5e111264faf00b4a7ef25b36833.png"/>
#                                 노무사                            </a></dd>
# <dd><a href="https://bupmu.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/3cc8229ca08549b1032c3a70511e28ff.png"/>
#                                 법무사                            </a></dd>
# <dd><a href="https://customs.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/b65e0d2fdc2dfb33822f20dd440b4fb0.png"/>
#                                 관세사                            </a></dd>
# <dd><a href="https://ca.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/6ba114b6f128da83304822b77ea37047.png"/>
#                                 감평사                            </a></dd>
# <dd><a href="https://beauty.conects.com/">
# <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/873c70b2b9e0eb086867f690efcabf88.png"/>
#                                 뷰티아카데미                            </a></dd>
# </dl>
# <dl>
# <dt>Life</dt>
# <dd><a href="https://hobby.conects.com/">
# <img alt="" src=""/>
#                                 라이프·취미                            </a></dd>
# <dd><a href="">
# <img alt="" src=""/>
#                                 독서                            </a></dd>
# <dd><a href="">
# <img alt="" src=""/>
#                                 반려동물                            </a></dd>
# <dd><a href="">
# <img alt="" src=""/>
#                                 뷰티                            </a></dd>
# </dl>
# </div>
# </div>
# <div class="st_conects-util">
# <ul>
# <li>
# <a href="https://member.conects.com/member/login?redirect_url=http%3A%2F%2Fskyedu.conects.com%2Fteachers%2Fteacher_qna%2F%3Ft_id%3Djhc01%26cat1%3D1%26page%3D1">로그인</a>
# </li>
# <li>
# <a href="https://member.conects.com/member/join?redirect_url=http%3A%2F%2Fskyedu.conects.com%2Fteachers%2Fteacher_qna%2F%3Ft_id%3Djhc01%26cat1%3D1%26page%3D1">회원가입</a>
# </li>
# <li>
# <a href="https://my.conects.com/cart/cart">장바구니</a>
# </li>
# <li>
# <a class="link-cs" href="//www.conects.com/support">고객섬김센터</a>
# </li>
# <li><a href="https://my.conects.com">내보관함</a></li>
# </ul>
# </div>
# </div>
# <!-- //GNB -->
# <!-- LNB -->
# <div class="st_business-nav">
# <iframe frameborder="0" height="130" scrolling="no" src="//www.conects.com/common/st_lnb_banner" style="overflow:hidden;vertical-align:top;" width="166"></iframe>
# <a class="link-home" href="https://skyedu.conects.com/go3/main">스카이에듀<br/>메인가기</a>
# <dl class="wrap">
# <dt><span>
#                         함께해요
#
#                     </span></dt>
# <dd><a class="new" href="https://www.conects.com/archives/together/study?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/b7f3a2fdca8e90fe3a5d04315ebde259.png"/>
#                         스터디 / 모임                    </a></dd>
# <dd><a class="new" href="https://www.conects.com/archives/together/winner?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/e429074c7334e6f0d810da7a87ca7884.png"/>
#                         합격선배                    </a></dd>
# <dd><a class="new" href="https://www.conects.com/archives/together/diary/type/card?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/73297669789ac1fdb12504dead275609.png"/>
#                         공부일기                    </a></dd>
# </dl>
# <dl class="wrap">
# <dt><span>
#                         물어봐요
#
#                     </span></dt>
# <dd><a class="new" href="https://www.conects.com/archives/ask/qna?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/cc89f150b5849d0b9005ec69e79e9b7b.png"/>
#                         Q&amp;A                    </a></dd>
# <dd><a class="new" href="https://www.conects.com/archives/ask/anonymous?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/1b3c3a133c1d7927c6d32a412c5d9662.png"/>
#                         대나무숲                    </a></dd>
# <dd><a class="new" href="https://www.conects.com/archives/together/future?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/1a097fa7fb326ea2ae91dea49f8fa2b1.png"/>
#                         미래예측                    </a></dd>
# </dl>
# <dl class="wrap">
# <dt><span>
#                         배워봐요
#
#                     </span></dt>
# <dd><a class="new" href="https://www.conects.com/archives/study/academy?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/cd570f1592ff64b4c4e8bbe153d4ff89.png"/>
#                         학원                    </a></dd>
# <dd><a class="new" href="https://www.conects.com/archives/study/room?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/cb2edb12fb89ebdc136589fac1af6379.png"/>
#                         독서실                    </a></dd>
# </dl>
# <dl class="wrap">
# <dt><span>
#                         비밀이에요
#                                                 <span class="ico-tag">event</span>
# </span></dt>
# <dd><a class="new" href="https://www.conects.com/archives/secret/group?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/45526df1a13bdebe351de4296b6c7812.png"/>
#                         비밀모임                    </a></dd>
# <dd><a class="new" href="https://www.conects.com/archives/secret/pds?category_id=38" target="_self">
# <!-- 새글 등록 시 class="new" -->
# <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/a439af97493ba120e48aab2b940114c6.png"/>
#                         비밀자료                    </a></dd>
# </dl>
# <dl class="wrap">
# <dt><a href="//www.conects.com/archives/best">
#                         베스트
#                     </a></dt>
# </dl>
# <dl class="add">
# <dt><span>
#                         FAMILY SITE
#                     </span></dt>
# <dd><a href="//book.conects.com">커넥츠북</a></dd>
# <dd><a href="//studycenter.conects.com">공부장소</a></dd>
# <dd><a href="//device.conects.com">커넥츠 디바이스</a></dd>
# <dd><a href="//tutor.conects.com">커넥츠튜터</a></dd>
# <dd><a href="//kr.tutor.com">튜터닷컴</a></dd>
# </dl>
# <div class="ban">
# <a href="//www.conects.com/support/toceo" target="_blank"><img alt="회원님의 목소리를 들려주세요." src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/img/banner/ban_ceo.gif"/></a>
# </div>
# </div>
# <!-- //LNB -->
# <!-- popup -->
# <div class="st_conects-interesting-popup mfp-hide" id="st_conects-interesting-popup">
# <p class="txt-state">
# <strong class="num"></strong>어떤
#                 분야에 관심 있으신가요?<br/>
# <strong>관심사를 선택</strong>하고, 맨 아래의 <strong>관심사 저장하기</strong>를 눌러보세요!
#             </p>
# <dl class="list-interesting" id="interest-selection-area">
# <dt>
# <strong class="tit">School</strong>
# <!-- <em class="num">(1,003,427)</em> -->
# </dt>
# <dd>
# <input id="gnb_interest_check_165" type="checkbox" value="165"/>
# <label for="gnb_interest_check_165">유·초등</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_157" type="checkbox" value="157"/>
# <label for="gnb_interest_check_157">중등·특목</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_38" type="checkbox" value="38"/>
# <label for="gnb_interest_check_38">대입·수능</label>
# </dd>
# <dt>
# <strong class="tit">University</strong>
# <!-- <em class="num">(1,003,427)</em> -->
# </dt>
# <dd>
# <input id="gnb_interest_check_85" type="checkbox" value="85"/>
# <label for="gnb_interest_check_85">대학생·취업</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_69" type="checkbox" value="69"/>
# <label for="gnb_interest_check_69">공무원·임용</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_55" type="checkbox" value="55"/>
# <label for="gnb_interest_check_55">어학·회화</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_175" type="checkbox" value="175"/>
# <label for="gnb_interest_check_175">임용고시</label>
# </dd>
# <dt>
# <strong class="tit">Career</strong>
# <!-- <em class="num">(1,003,427)</em> -->
# </dt>
# <dd>
# <input id="gnb_interest_check_169" type="checkbox" value="169"/>
# <label for="gnb_interest_check_169">직무·스타트업</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_158" type="checkbox" value="158"/>
# <label for="gnb_interest_check_158">전문직</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_160" type="checkbox" value="160"/>
# <label for="gnb_interest_check_160">공인중개사</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_177" type="checkbox" value="177"/>
# <label for="gnb_interest_check_177">자격증</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_179" type="checkbox" value="179"/>
# <label for="gnb_interest_check_179">노무사</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_181" type="checkbox" value="181"/>
# <label for="gnb_interest_check_181">법무사</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_183" type="checkbox" value="183"/>
# <label for="gnb_interest_check_183">관세사</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_185" type="checkbox" value="185"/>
# <label for="gnb_interest_check_185">감평사</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_187" type="checkbox" value="187"/>
# <label for="gnb_interest_check_187">뷰티아카데미</label>
# </dd>
# <dt>
# <strong class="tit">Life</strong>
# <!-- <em class="num">(1,003,427)</em> -->
# </dt>
# <dd>
# <input id="gnb_interest_check_128" type="checkbox" value="128"/>
# <label for="gnb_interest_check_128">라이프·취미</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_136" type="checkbox" value="136"/>
# <label for="gnb_interest_check_136">독서</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_171" type="checkbox" value="171"/>
# <label for="gnb_interest_check_171">반려동물</label>
# </dd>
# <dd>
# <input id="gnb_interest_check_173" type="checkbox" value="173"/>
# <label for="gnb_interest_check_173">뷰티</label>
# </dd>
# </dl>
# <button class="btn-confirm" onclick="if(_CONECTS_GNB_.setInterests($('#interest-selection-area input[type=checkbox]:checked').map(function(){return $(this).val()*1}).get()))$.magnificPopup.instance.close()" type="button">관심사
#                 저장하기</button>
# <button class="btn-close-popup mfp-close" type="button">닫기</button>
# </div>
# <!-- //popup -->
# </div>
# </div>
# <script>
#     var COMM_CONECTS_GNB = new StConectsGNB;
#     _CONECTS_GNB_.init(38)
# </script>
# <!-- //conects -->
# <!-- GNB타입 -->
# <!-- //GNB타입 --> <!-- 강좌리스트 바로재생  -->
# <script src="/js/common/common_player.js?20200218145319" type="text/javascript"></script>
# <script type="text/javascript">
#             //- 강좌리스트 셋팅하기
#             _CONECTS_COMMON_PLAYER_.init();
#
#
#             // CONECTS GNB 인스턴스
#             COMM_CONECTS_GNB.init('personal',true);
#             COMM_CONECTS_GNB.site({
#                 biz_code: 'SKYEDUNEW',
#                 active: 'SKYEDUNEW'
#             });
#
#                             COMM_CONECTS_GNB.menu(['wrap-data-00', '/teachers/main/info_mainTeacherOrder']);
#
#
#                             COMM_CONECTS_GNB.on("menu-00");
#                         // conects, learning, book, tutor / biz_code / cs
#         </script>
# <style>
#         #hgroup .st-conects-myclass{font-size:0;}
#         #hgroup .st-conects-myclass a.myclass{ display:inline-block;float:none; }
#         #hgroup .st-conects-myclass .gnb-banner{ display:inline-block;float:none;vertical-align:top;width:230px;height:60px;text-align:left;font-size:0;}
#         #hgroup .st-conects-myclass .gnb-banner .slide:first-child{display:block;}
#         #hgroup .st-conects-myclass .gnb-banner .slide{width:230px;height:60px;margin-left:0;}
#         #hgroup .st-conects-myclass .gnb-banner em{position:absolute;top:0;right:0;z-index:500;cursor:pointer;}
#         </style>
# <script type="text/javascript">
#         $(function(){
#             // var f_html = $('#hgroup .st-conects-myclass').html();
#             // $('#hgroup .st-conects-myclass').html('<div class="relative"></div>');
#             // $('#hgroup .st-conects-myclass').find('.relative').append('<a class="gnb-banner" href="https://skyedu.conects.com/event/presentation/2018/120501/event"><img src="http://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/00bceaee332f80ba951cd87bbf8774c4.png" /></a>');
#             // $('#hgroup .st-conects-myclass').find('.relative').append(f_html);
#
#             //fn_gnb_banner();
#             //fn_right_top_banner();
#         });
#
#         $(window).load(function() {
#             fn_right_top_banner();
#             //  fn_right_top_banner();
#         });
#
#     function fn_right_top_banner() {
# 		var f_obj = jQuery('#hgroup .st-gnb-banner');
# 		f_obj.css({'margin-right':'-160px','top':'-19px'});
# 		var f_html  = '';
#             f_html += '<div class="gnb-banner">';
#
#             //- 교재이벤트
#
#                             //f_html += '<a href="//st-event-skyedu.dangi.co.kr/event/cc/class_delivery/201911/event" target="_blank" ><img src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/db95247de4a86c0d4e02f9b4665add4f.gif" alt="이벤트"></a>';
#
#             //선착순 2020-01-31
#             f_html += '<a href="//st-event-skyedu.dangi.co.kr/event/cc/2020/020301/event" target="_blank" ><img src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/4cd72b970221876539d06c6ec294279c.png" alt="이벤트"></a>';
#
#
#
#             f_html += '</div>';
#
#             f_obj.append(f_html);
# 	}
#         </script>
# <style type="text/css">
#     .sub-gnb{ background-color:#f9f9f9; border-bottom:1px solid #ccc; }
#     .sub-gnb > ul{ width:1100px; margin:0 auto; z-index:2; }
#     .sub-gnb > ul.teacher-menu{ width:1045px; padding-left:55px; background-position:0 50%; background-repeat:no-repeat; background-size:55px 55px; }
#     .sub-gnb > ul > li{ height:56px; margin:0 1px; float:left; position:relative; }
#     .sub-gnb > ul > li:first-child{ margin:0 1px 0 0; }
#     .sub-gnb > ul > li > a{ padding:18px 10px; display:block; position:relative; font-size:14px; color:#111; }
#
#     .sub-gnb .gnb-2depth{ width:230px; padding:15px 0; display:none; position:absolute; top:56px; left:0; background-color:#fff; border:1px solid #ccc; z-index:9999; }
#     .sub-gnb .gnb-2depth ul li a{ padding:10px 0 10px 20px; display:block; font-size:14px; color:#888; text-align:left; }
#     .sub-gnb .over .gnb-2depth ul li a{ animation:Ani-2depth .2s linear; animation-fill-mode:both; }
#     .sub-gnb .gnb-2depth ul li a:hover{ color:#d90000; }
#
#     .sub-gnb > ul > li > a:hover,
#     .sub-gnb > ul > li:hover > a{ padding:18px 10px 14px; border-bottom:5px solid #f9f9f9; border-color:#ccc \0/IE9; animation:Ani-1depth .3s linear; animation-fill-mode:both; }
#     .sub-gnb > ul > li:hover > a.selected{ border-color:#f9f9f9 \0/IE9; animation:none; }
#     .sub-gnb > ul > li > a.selected{ padding:18px 10px 14px; border-bottom:5px solid #e90000; }
#     .sub-gnb > ul > li > a.selected:hover{ border-color:#e90000 \0/IE9; animation:none; }
#     .sub-gnb > ul > li:hover > .gnb-1depth + .gnb-2depth{display: block;}
#
# 	.sub-gnb > ul > li > a.sub-style-list > i{margin-left:5px;display:inline-block;width:10px;height:6px;background:url('//static.conects.com/skyedu_conects/imgs/web/utuber/sub_gnb_arrow.png') 0 0 no-repeat;}
# 	.sub-gnb > ul > li > a.sub-style-list:hover{ border-color:#e90000 \0/IE9;animation:Ani-1depth-red .3s linear; animation-fill-mode:both;}
# 	.sub-gnb > ul > li:hover > a.sub-style-list{border-bottom:5px solid #e90000;animation:none;}
# 	.sub-gnb > ul > li:hover > a.sub-style-list > i{background-position:100% 0;}
#
#
#
# 	.gnb-2depth.sub-gnb-list{padding:0 0 20px;top:57px;left:0;right:0;background-color:#fff;border:none;border-bottom:1px solid #ccc;width:100%;}
# 	.sub-gnb-list > .float-area{ width:1100px; margin:0 auto;position:relative;}
# 	.sub-gnb-list > .float-area > div{float:left;width:220px;}
# 	.sub-gnb-list hr{display:block;position:absolute;top:20px;bottom:0;margin:0;border:0 none; width:1px;height:calc(100% - 20px);background-color:#e8e8e8;}
# 	.sub-gnb-list hr.line00{left:205px;}
# 	.sub-gnb-list hr.line01{left:425px;}
# 	.sub-gnb-list hr.line02{left:645px;}
# 	.sub-gnb-list hr.line03{left:865px;}
# 	.sub-gnb-list dl{margin-top:20px;}
# 	.sub-gnb-list dt{margin-bottom:10px;font-size:14px;line-height:1.2;vertical-align:top;color:#000;font-weight:bold;}
# 	.sub-gnb-list dd{font-size:0;padding-top:10px;}
# 	.sub-gnb-list dd a{display:block;height:35px;line-height:34px;width:170px;}
# 	.sub-gnb-list dd .ico-thumb{margin-right:10px;display:inline-block;vertical-align:top;width:35px;height:35px;border-radius:50%;}
# 	.sub-gnb-list dd span{vertical-align:top;color:#999;font-size:13px;max-width:125px;}
# 	.sub-gnb-list dd a:hover span{color:#000;text-decoration:underline #000;}
#
#     @keyframes Ani-1depth{
#         from{ border-color:#f9f9f9; }
#         to{ border-color:#ccc; }
#     }
#     @keyframes Ani-1depth-red{
#         from{ border-color:#f9f9f9; }
#         to{ border-color:#e90000; }
#     }
#     @keyframes Ani-2depth{
#         from{ display:block; transform:translate3d(0, -10%, 0); }
#         to{ display:block; transform:none; }
#     }
# </style>
# <div class="sub-gnb">
# <!-- S:선생님 서브메뉴 진입 시 :  teacher-menu" style="background-image:url('http://img.skyedu.com/teacher/photo/55_55/jhc01.jpg'); 추가-->
# <ul class="float-area teacher-menu" style="background-image:url('//static.conects.com/skyedu_conects/imgs/teacher/photo/55_55/jhc01.jpg');">
# <li>
# <a class="" href="/teachers/home/?t_id=jhc01&amp;cat1=1">선생님 홈</a>
# </li>
# <li>
# <a class="" href="/teachers/lecList/?t_id=jhc01&amp;cat1=1">개설강좌</a>
# </li>
# <li>
# <a class="" href="/teachers/notice/?t_id=jhc01&amp;cat1=1">공지사항</a>
# </li>
# <li>
# <a class="selected" href="/teachers/teacher_qna/?t_id=jhc01&amp;cat1=1">학습질문/답변</a>
# </li>
# <li>
# <a class="" href="/teachers/best_review/?t_id=jhc01&amp;cat1=1">수강후기</a>
# </li>
# <li>
# <a class="" href="/teachers/tcc/?t_id=jhc01&amp;cat1=1">선생님 TV</a>
# </li>
# <li>
# <a class="" href="/teachers/board_data_list/?t_id=jhc01&amp;cat1=1">학습자료실</a>
# </li>
# <li>
# <a class="" href="/teachers/explain_lecture/?t_id=jhc01">해설강의</a>
# </li>
# </ul>
# <!-- E:선생님 서브메뉴 진입 시-->
# </div>
# <!-- 매일인증 이벤트 -->
# <style>
# 				@-webkit-keyframes hvr-icon-up {
# 				0%, 50%, 100% {
# 					-webkit-transform: translateY(0);
# 					transform: translateY(0);
# 				}
# 				25%, 75% {
# 					-webkit-transform: translateY(-4px);
# 					transform: translateY(-4px);
# 				}
# 				}
# 				@keyframes hvr-icon-up {
# 				0%, 50%, 100% {
# 					-webkit-transform: translateY(0);
# 					transform: translateY(0);
# 				}
# 				25%, 75% {
# 					-webkit-transform: translateY(-4px);
# 					transform: translateY(-4px);
# 				}
# 				}
#
# 				.hvr-icon-up {
# 				-webkit-transform: translateZ(0);
# 				transform: translateZ(0);
# 				}
#
# 				.hvr-icon-up{
# 					animation:hvr-icon-up 1s ease-out infinite;
# 				}
#
# 				.hvr-icon-up:hover{
# 					animation:none;
# 				}
# 			</style>
# <!-- S:학년선택 -->
# <script type="text/javascript">
# 			$(window).load(function() {
#
# 				//$('.st-conects-snb .bi a').html('<img src="//static.conects.com/skyedu_conects/imgs/web/main/v06/logo_191112.gif" alt="스듀" />');
#
# 				// 학년선택 추가
# 				var strMenuHtml = '' +
# 				'<div class="btn-set-year" style="float:left;margin:11px 20px 0 -10px;">' +
# 				'<a href="javascript:void(0);" onclick="$(\'.layer-set-year\').show();" style="border:1px solid #29b6f6;padding:0 4px;font-size:12px;height:22px;line-height:22px;border-radius:4px;color:#29b6f6;">학년설정</a>' +
# 				'</div>';
# 				//$( strMenuHtml ).insertAfter( $('.artc-toggle-depth') );
#
# 				//$('.st-conects-snb .nav-gnb').append('<li><a href="https://st-event-skyedu.dangi.co.kr/event/cc/2019/070801/event" class="depth-01 " style="color:#f45f89;"><span style="position:absolute;top:-18px;left:-8px;"><img src="https://static.conects.com/skyedu_conects/imgs/web/banner/201906/gnb.jpg" alt="D-100"></span></a></li>');
# 							});
#
# 			function fn_next(){
#
# 				var NEXTHOME=jQuery(":input:radio[name=NEXTHOME]:checked").val();
#
# 				if(NEXTHOME=="" || NEXTHOME==undefined){
# 					alert("바로 접속할 학년을 선택해주세요.");
# 				}else if(NEXTHOME=="go3"){
# 					var ob = confirm('[SKYEDU 예비 고3] 로 바로 접속할\n학년 사이트를 설정하시겠습니까?');
# 					if(ob){
# 						setCookie('NEXTHOME','go3',365);
# 					};
# 					jQuery('.layer-set-year').hide();
# 				}else if(NEXTHOME=="go2"){
# 					var ob = confirm('[SKYEDU 예비 고2] 로 바로 접속할 학년 사이트를 설정하시겠습니까?');
# 					if(ob){
# 						setCookie('NEXTHOME','go2',365);
# 					};
# 					jQuery('.layer-set-year').hide();
# 				}else if(NEXTHOME=="go1"){
# 					var ob = confirm('[SKYEDU 예비 고1] 로 바로 접속할 학년 사이트를 설정하시겠습니까?');
# 					if(ob){
# 						setCookie('NEXTHOME','go1',365);
# 					};
# 					jQuery('.layer-set-year').hide();
# 				}
# 			}
#
#
# 			</script>
# <div class="layer-set-year" style="display:none;position:absolute;top:181px;left:50%;margin-left:-390px; border:1px solid #535353;background-color:#fff;padding:30px;z-index:3;">
# <div class="relative" style="width:324px;">
# <a href="javascript:void(0);" onclick="$(this).parents('.layer-set-year').hide();" style="position:absolute;top:-20px;right:-20px;"><img alt="닫기" src="//static.conects.com/skyedu_conects/imgs/web/event/common/popup_btn_close.png"/></a>
# <div class="layer-ttl" style="font-size:20px;color:#000;text-align:left;line-height:30px;">
# <b>바로 접속할 학년을 설정해주세요.<br/>
# 						SKYEDU에 접속 시 선택하신 학년<br/>
# 						사이트로 바로 이동합니다.</b>
# </div>
# <div class="layer-cont" style="padding:24px 0;">
# <form action="">
# <label class="radio"><input name="NEXTHOME" type="radio" value="go3"/> 예비 고3</label>
# <label class="radio" style="margin-left:30px;"><input name="NEXTHOME" type="radio" value="go2"/> 예비 고2</label>
# <label class="radio" style="margin-left:30px;"><input name="NEXTHOME" type="radio" value="go1"/> 예비 고1</label>
# </form>
# </div>
# <div class="btn-wrap">
# <a class="btn-style btn-big" href="javascript:fn_next();">설정하기</a>
# </div>
# <div class="mt10" style="color:#a0a0a0;font-size:13px;letter-spacing:-0.03em;text-align:left;">
# 						이후 다른 학년으로 기본 사이트 설정을 변경하시려면<br/>
# 						사용하는 컴퓨터의 쿠키를 삭제 후 재설정하실 수 있습니다.
# 					</div>
# </div>
# </div>
# <!-- E:학년선택 -->
# </div>
# <!-- E:Header -->
# <!-- container -->
# <div id="container">
# <div class="layout-contents-container layout-padding">
# <div class="wrap-column">
# <h3 class="ttl">
#             학습 질문/답변
#             <small class="color-grey">학습에 대한 질문을 남겨 주시면 빠르게 답변드리겠습니다.</small>
# </h3>
# <!-- S: 정렬만 단독 사용 -->
# <div class="box-select-area"> <!-- 우측 정렬일 땐  txt-right 추가 -->
# <div class="select-tab">
# <a class="selected" href="/teachers/teacher_qna/?t_id=jhc01&amp;cat1=1">전체</a>
# <span class="bar">|</span>
# <a href="javascript:void(0);" onclick="board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','18692101','')">강좌</a>
# <span class="bar">|</span>
# <a href="javascript:void(0);" onclick="board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','18692102','')">학습</a>
# <span class="bar">|</span>
# <a href="javascript:void(0);" onclick="board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','18692104','')">기타</a>
# </div>
# </div>
# <!-- E: 정렬만 단독 사용 -->
# </div>
# <input id="temp_search" type="hidden"/>
# <input id="temp_search_option" type="hidden"/>
# <input id="temp_cat1" name="temp_cat1" type="hidden" value="1"/>
# <!-- 학습QNA -->
# <div class="wrap-column board-data-list">
# <!-- 리스트 -->
# <div class="board-list" id="bbs_content"></div>
# <div class="float-area mt20"></div>
# <!--// 리스트 -->
# </div>
# <div class="layout-aside-quick">
# <div class="aside-container">
# <div class="artc-banner">
# <ul class="banner-list">
# <li>
# <a href="https://www.youtube.com/embed/JnSYHef4lM0" target="_blank">
# <img alt="[퀵] 전홍철T - 개념은 전홍철" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/b95e0759dca5cb41e5ff16ebd8c2c892.jpg"/>
# </a>
# </li>
# <li>
# <a href="https://www.conects.com/course/detail/intro/268076" target="">
# <img alt="[영어] 전홍철T 스피드리딩 - 퀵" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/d905e763bd21eb39f52ba9d7155971cb.jpg"/>
# </a>
# </li>
# <li>
# <a href="https://www.conects.com/course/detail/intro/268077" target="">
# <img alt="[영어] 전홍철T 스피드어법 - 퀵" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/6da54a345eebb4f90624a41545ab9cda.jpg"/>
# </a>
# </li>
# <li>
# <a href="https://skyedu.conects.com/event/page/list/4121" target="">
# <img alt="[영어]전홍철T 퀵배너" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/d0988b8e79156fe0917909e6f1ed8e10.jpg"/>
# </a>
# </li>
# <li>
# <a href="https://www.conects.com/course/detail/intro/237477" target="">
# <img alt="[선생님홈퀵] 전홍철T 스피드 보카" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/3092d8f92f3d330e591b51570a63475e.png"/>
# </a>
# </li>
# <li>
# <a href="https://skyedu.conects.com/teachers/tcc?t_id=jhc01&amp;tccIdx=9245" target="">
# <img alt="[영어]전홍철 퀵배너" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/6a776c62166826543dfbfbf9f44375aa.png"/>
# </a>
# </li>
# <li>
# <a href="https://skyedu.conects.com/teachers/notice/board_view?t_id=jhc01&amp;cat1=1&amp;document_srl=24825165" target="">
# <img alt="[영어]전홍철T 적중 퀵" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/2dec9244f0ed2bc6d6cd06e94e030712.png"/>
# </a>
# </li>
# <li>
# <a href="http://nrjdan.skyedu.com/introduce/academyInfo.asp" target="_blank">
# <img alt="[선생님퀵]노량진스듀 리얼패스" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/bb967b518eaa643503fe6203769a75f2.png"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	$(document).ready( function(){
#
#             board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','','');
#
#
#         jQuery(".select-tab a").click(function(){
#
#             jQuery(".select-tab a").removeClass("selected");
#             jQuery(this).addClass("selected");
#
#         });
#
# 	});
#
#
# </script>
# <script type="text/javascript">
#
#     var teacher_id;
#     var cat1;
#
#
#     // 리스트
#     function board_list(page, type, mid,sort_index,search_word,teacher_id,search_etc,category_srl,extra_category){
#
#         this.teacher_id = teacher_id;
#         this.cat1 = $("#temp_cat1").val() ;
#
#
#         // 검색어
#         var search = "";
#         // 검색 옵션
#         var search_option = "";
#
#         if(search_word == 'search'){
#             search = $("#search").val();
#             search_option = $("#search_option").val();
#
#             $("#search_option").val(search_option);
#             /*
#             if(search.length <= 0){
#                 if(search_option != 'all'){
#                     alert('검색어를 입력해주세요');
#                     return preventDefaultAction(false);
#                 }
#             }
#             */
#
#             $("#temp_search").val(search);
#             $("#temp_search_option").val(search_option);
#
#         }else{
#             if($("#temp_search").val().length > 0){
#                 search = $("#temp_search").val();
#             }
#             if($("#temp_search_option").val().length > 0){
#                 search_option = $("#temp_search_option").val();
#             }
#         }
#
#         // $('html,body').animate({ scrollTop: $('.board-data-list').offset().top }, 500);
#
#
#         $.ajax({
#             url: "/teachers/teacher_qna/board_list/"+page,
#             type: "POST",
#             data: {
#                 type : type
#                 ,mid : mid
#                 ,sort_index : sort_index
#                 ,search :search
#                 ,search_etc:search_etc
#                 ,search_option : search_option
#                 ,teacher_id : this.teacher_id
#                 ,cat1:this.cat1
#                 ,category_srl:category_srl
#                 ,extra_category:extra_category
#             },
#             error:function(e){
#     //							   alert("데이터를 가져오지 못하였습니다.");
#             },
#             beforeSend:function(){
#             },
#             success:function ( response ){
#                 jQuery("#bbs_content").html(response);
#
#             },
#             complete:function(){
#             }
#
#         });
#     }
#
#
#
#     function version_check(){
#         var _ua = navigator.userAgent;
#         var rv = -1;
#
#         //IE 11,10,9,8
#         var trident = _ua.match(/Trident\/(\d.\d)/i);
#         if(trident != null ){
#             if(trident[1] == "7.0" ) return false;
#             if(trident[1] == "6.0" ) return false;
#             if(trident[1] == "5.0" ) return true;
#             if(trident[1] == "4.0" ) return true;
#         }
#
#         //IE 7...
#         if( navigator.appName == 'Microsoft Internet Explorer'){
#             return true;
#         }
#
#         var agt = _ua.toLowerCase();
#         if (agt.indexOf("chrome") != -1) return false;
#         if (agt.indexOf("opera") != -1) return false;
#         if (agt.indexOf("staroffice") != -1) return false;
#         if (agt.indexOf("webtv") != -1) return false;
#         if (agt.indexOf("beonex") != -1) return false;
#         if (agt.indexOf("chimera") != -1) return false;
#         if (agt.indexOf("netpositive") != -1) return false;
#         if (agt.indexOf("phoenix") != -1) return false;
#         if (agt.indexOf("firefox") != -1) return false;
#         if (agt.indexOf("safari") != -1) return false;
#         if (agt.indexOf("skipstone") != -1) return false;
#         if (agt.indexOf("netscape") != -1) return false;
#         if (agt.indexOf("mozilla/5.0") != -1) return false;
#
#     }
#
#
# </script> <!-- select box 이벤트 적용 -->
# <script>
#     $(document).on("click", ".select_box>div", function(){
#         var ul_display = $(this).next("ul").css("display");
#
#
#         $(this).on("selectstart", function(event){ return false; });
#
#         //oepn select box close
#         $(".select_box>div").css("background-image","url(https://skyedu.conects.com/img//myclass/support_contents/selectbox_arrow.gif)");
#         $(".select_box>div").parent().css('z-index', 0);
#         $(".select_box>div").next("ul").hide();
#
#         if(ul_display!="block"){
#
#             $(this).parent().css('z-index', 5);
#             $(this).next("ul").show();
#
#             $(this).css("background-image","url(https://skyedu.conects.com/img//myclass/support_contents/selectbox_arrow_up.gif)");
#         }else{
#             $(this).parent().css('z-index', 0);
#             $(this).next("ul").hide();
#             $(this).css("background-image","url(https://skyedu.conects.com/img//myclass/support_contents/selectbox_arrow.gif)");
#         }
#     });
# </script>
# </div>
# <!-- container -->
# <!-- 레이어 메뉴 더보기 -->
# <div class="layer-menu" id="popup_layer_menu"></div>
# <!--// 레이어 메뉴 더보기 -->
# <!-- [s] 2019.04.09 장바구니 레이어 팝업 추가 -->
# <div class="class-combine_layerpop-cart hide">
# <a class="btn-cart" href="javascript: void(0);" onclick="cart_products_bytag();">장바구니 담기</a>
# <a class="btn-cart" href="javascript: void(0);" onclick="order_products_bytag();">바로 구매하기</a>
# </div>
# <!-- FOOTER -->
# <div id="footer-container">
# <!-- FOOTER -->
# <div class="st-conects-footer-v3-2">
# <div class="wrap-bi">
# <img alt="" class="bi" src="//static.conects.com/common/img/st-comm-v3/img-bi-conects-footer-01.png"/>
# <p class="txt">전 국민 필수 공부앱</p>
# <div class="conects-sns">
# <a class="icon ico-facebook" href="http://facebook.com/myconects">커넥츠 페이스북</a>
# <a class="icon ico-naver-post" href="https://post.naver.com/conects">커넥츠 네이버 포스트</a>
# <a class="icon ico-naver-blog" href="http://blog.naver.com/conects">커넥츠 네이버 블로그</a>
# <a class="icon ico-youtube" href="https://www.youtube.com/channel/UCq6gcyfvYSAJuEQvVZYzklw">커넥츠 유튜브</a>
# <a class="icon ico-naver-tv" href="http://tv.naver.com/conects">커넥츠 네이버 TV</a>
# <a class="icon ico-instagram" href="http://instagram.com/conects.office">커넥츠 인스타그램</a>
# </div>
# </div>
# <div class="link-info">
# <ul>
# <li><a href="http://www.stunitas.com/" target="_blank">회사소개</a></li>
# <li><a href="http://www.conects.com/intro" target="_blank">커넥츠소개</a></li>
# <li><a href="#x" onclick="window.open('/popup/userule/userule', 'popup_notice1', 'width=880,height=900,scrollbars=yes,top=0,left=0,location=0,resizable=no,status=no,directories=no');return false;">이용약관</a></li>
# <li><a class="odd" href="#x" onclick="window.open('/popup/skyprivate/', 'popup_notice1', 'width=880,height=900,scrollbars=yes,top=0,left=0,location=0,resizable=no,status=no,directories=no');return false;">개인정보처리방침</a></li>
# <li><a href="/help_center/main">고객섬김센터</a></li>
# </ul>
# <div class="link-isms">
# <a class="ico-isms" href="#isms-conects" onclick="jQuery(this).next('.isms-conects').show();"><img alt="ISMS" src="//static.conects.com/common/img/st-comm-v3/ISMS.png"/></a>
# <div class="isms-conects" id="isms-conects">
# <a href="javascript:;" onclick="jQuery(this).parents('.isms-conects').fadeOut(200);" style="position: absolute;top:5px; right:5px;"><img alt="창닫기" src="//static.conects.com/skyedu_conects/imgs/ico/btn_close_circle.png"/></a>
# <img alt="정보보호 관리체계 인증서" src="//static.conects.com/skyedu_conects/imgs/ico/isms_popup.png"/>
# </div>
# </div>
# </div>
# <div class="address">
# <div class="wrap">
# <span class="company">(주)현현교육</span>
# <span>대표이사 : 김석배 </span>
# <span class="address-txt">서울특별시 서초구 반포대로30길 81. 6.7.8층(서초동)</span>
# </div>
# <div class="wrap">
# <span>고객센터 : 02-540-5252<!--em class="cs"><a href="https://api.happytalk.io/api/kakao/chat_open?yid=%40skyedu&site_id=6000000088&category_id=78762&division_id=78763&site_uid=<%If session_userid <> "" Then Response.write session_userid Else Response.write "{user_id}" End If %>" class="btn-kakao" target="_blank">카카오 상담톡</a></em--></span>
# <span>윤리경영 : <a href="https://pito.co.kr/hot_line/index.php?scode=1JTIVW" target="_blank">[제보하기]</a></span>
# </div>
# <div class="wrap">
# <span>사업자등록번호 : <em class="licensee-txt">215-86-79670</em></span>
# <span>통신판매업신고 : <em class="licensee-txt">2015-서울서초-1080호</em> <a class="link-seller" href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2158679670" target="_blank">사용자 정보확인</a></span>
# </div>
# </div>
# <div class="address">
# <div class="wrap">
# <span>ⓒ ST Unitas.</span>
# </div>
# </div>
# </div>
# <!-- //FOOTER -->
# </div>
# <!-- //FOOTER -->
# </div>
# <!--// wrap -->
# <script type="text/javascript">
# 		(function(w,d,l,r,c,s) {
# 		w[r]=w[r]||function(a){ (w[r].q=w[r].q||[]).push(arguments);}; w[r].d=1*new Date();
# 		var _gt_cookieDay=30;
# 		var _gt_debug = false; // true 설정시 값이 실제 전달되지는 않고 크롬의 개발자도구에서 Console 창에 전송 메세지 표시
# 		var _gt_OnlyAD = true; // 광고키값이 있을때만 유입체크
# 		var _f_gt_PageView, _f_gt_Convert, _f_gt_ButtonClick, _lt=10, _LinkDelayTime=300;
# 		var C=function(a){ C[a].apply(C,[].slice.call(arguments))};
# 		C.aCode="";C.domain="tr.itiscreation.co.kr";
# 		try{
# 		C.setAccount=function(a){var args=[].slice.call(arguments); C.aCode=args[1]; if(args.length>=3)try{ _gt_cookieDay=args[2]; }catch(e){};};
# 		C.setCookie=function(n,v){if(typeof(localStorage)!='undefined')try{localStorage.setItem(n,v);}catch(e){if(e==QUOTA_EXCEEDED_ERR){localStorage.clear();localStorage.setItem(n,v);};};};
# 		C.getCookie=function(n){if(typeof(localStorage)!='undefined'){ var v=localStorage.getItem(n);if(v!=null) return v;};return null;};
# 		C.getParameter=function(n){var rv='',ad=unescape(l.href),p=(ad.slice(ad.indexOf('?')+1,ad.length)).split('&');for(var i=0;i<p.length;i++){var vn=p[i].split('=')[0];if(vn.toUpperCase()==n.toUpperCase()){rv=p[i].split('=')[1];break;};};return rv;};
# 		C.imageURL=function(a){
# 		var cid=this.getParameter('_itsid'),args=[].slice.call(arguments),v={},guid=this.getCookie("_gt_GUID"),t=this.getTime(),_cid="";
# 		v.aid=this.aCode;v.ctime=_gt_cookieDay;if(guid==null){guid=this.uuid();this.setCookie("_gt_GUID",guid);this.setCookie("_gt_FirstTime",t);};
# 		if(cid.length>0 && args[0]=="pageview"){_cid="&cid="+cid;this.setCookie('_gt_cid',cid);this.setCookie('_gt_aid',C.aCode);this.setCookie('_gt_ctime',t);this.setCookie("_gt_LastTime",t);args[args.length]="Landing";this.setCookie('_gt_buttonClick','');};v.cid=this.getCookie("_gt_cid");v.guid=guid;v.firstTime=this.getCookie("_gt_FirstTime");v.lastTime=this.getCookie("_gt_LastTime");v.forward=args;v.referer=(d.referrer.length>100)?d.referrer.substr(0,100):d.referrer;v.buttonClick=this.getCookie("_gt_buttonClick");
# 		var _href = l.protocol+"//"+C.domain+"/an/sv.php?v="+encodeURIComponent(JSON.stringify(v))+_cid+"&t="+(new Date().getTime());
# 		if(_gt_debug)console.log(JSON.stringify(v)+"\n"+_href);
# 		else setTimeout(function(){new Image().src=_href;},_lt);};
# 		C.send=C.event=function(a){var args=[].slice.call(arguments);C.imageURL.apply(C,args);};
# 		C.pageview=function(a){var args=[].slice.call(arguments);var cid=this.getParameter('_itsid');if( _gt_OnlyAD && cid.length==0 ) return;C.imageURL.apply(C,args);	if(_f_gt_PageView && typeof _f_gt_PageView == "function")_f_gt_PageView();
# 		if(args.length>=2)setTimeout(function(){l.href=args[1];},_LinkDelayTime);};
# 		C.convert=function(a){var args=[].slice.call(arguments);C.imageURL.apply(C,args);
# 		if(_f_gt_Convert && typeof _f_gt_Convert == "function") _f_gt_Convert();};
# 		C.buttonClick=function(a){var args=[].slice.call(arguments); this.setCookie('_gt_buttonClick',args[1]); C.imageURL.apply(C,args);
# 		if(_f_gt_ButtonClick && typeof _f_gt_ButtonClick == "function") _f_gt_ButtonClick();
# 		if(args.length>=3)setTimeout(function(){l.href=args[2];},_LinkDelayTime);};
# 		C.C=function(){var b=w[r]=C;};
# 		C.uuid=function(){var chars='0123456789abcdef'.split('');var uuid=[],rnd=Math.random,r;uuid[8]=uuid[13]=uuid[18]=uuid[23]='-';uuid[14]='4';
# 		for(var i=0;i<36;i++){if(!uuid[i]){r=0|rnd()*16;uuid[i]=chars[(i==19)?(r&0x3)|0x8:r&0xf];}};return uuid.join('');};
# 		C.ip2long=function(ip){var d=ip.split('.');return d[0]*Math.pow(256,3)+d[1]*Math.pow(256,2)+d[2]*256+d[3];};
# 		C.getTime=function(){return Math.floor(new Date().getTime()/1000);};
# 		(function(){var pv=w[r].q;w[r]=C;var a=C.C;a();return!0})();
# 		} catch (e) {if(_gt_debug)console.log('{"error":"LOAD","extra":{"name":"'+e.name+'","line":"'+(e.lineNumber||e.line)+'","script":"'+(e.fileName||e.sourceURL||e.script)+'","stack":"'+(e.stackTrace||e.stack)+'","message":"'+e.message+'"}}');
# 		else new Image().src="//"+C.domain+"/an/se.php?c=error&m="+encodeURIComponent('{"error":"LOAD","accountCode","'+C.aCode+'","extra":{"name":"'+e.name+'","line":"'+(e.lineNumber||e.line)+'","script":"'+(e.fileName||e.sourceURL||e.script)+'","stack":"'+(e.stackTrace||e.stack)+'","message":"'+e.message+'"}}');};
# 		})(window,document,location,'gTracking');
# 		gTracking('setAccount', '20', 30);
# 		gTracking('pageview');  // 페이지 뷰
# 	</script>
# <!-- Facebook Pixel Code -->
# <script>
# 		!function(f,b,e,v,n,t,s)
# 		{if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 		n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 		if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 		n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];
# 		s.parentNode.insertBefore(t,s)}(window, document,'script',
# 		'https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '695270460588395');
# 		fbq('track', 'PageView');
# 	  </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=695270460588395&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!--  mobon code -->
# <!-- Enliple Common Tracker v3.5 [공용] start -->
# <script type="text/javascript">
# function mobRf(){
#     var rf = new EN();
#     rf.setData("userid", "skymid");
#     rf.setSSL(true);
#     rf.sendRf();
# }
# </script>
# <script defer="defer" onload="mobRf()" src="https://cdn.megadata.co.kr/js/en_script/3.5/enliple_min3.5.js"></script><!-- Enliple Common Tracker v3.5 [공용] end -->
# <!-- mobon code end -->
# <!--  KAKAO code -->
# <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
# <script type="text/javascript">
#     kakaoPixel('958550063245052220').pageView();
#     kakaoPixel('958550063245052220').search({
#         keyword: '검색키워드입력'
#     });
# </script>
# <!--  KAKAO code end -->
# <!--  Criteo code -->
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <script type="text/javascript">
# window.criteo_q = window.criteo_q || [];
# window.criteo_q.push(
#         { event: "setAccount", account: 8333 },
#         { event: "setHashedEmail", email: "MD5-hashed email address" },
#         { event: "setSiteType", type: "d"},
#         { event: "viewHome" }
# );
# </script>
# <!--  Criteo code end -->
# <!-- Global site tag (gtag.js) - Google Ads: 999354950 -->
# <!-- <script async src="https://www.googletagmanager.com/gtag/js?id=AW-999354950"></script>
# <script>
#  window.dataLayer = window.dataLayer || [];
#  function gtag(){dataLayer.push(arguments);}
#  gtag('js', new Date());
#  gtag('config', 'AW-999354950');
# </script> -->
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"72029d3b1f","applicationID":"103717515","transactionName":"MQcBbRECXBBWBkJRWAhNIloXCl0NGDFTWVQOBxFmEg1TTF4LUl1P","queueTime":0,"applicationTime":628,"atts":"HUACG1kYTx4=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
soup.find('table')

# %%
rows = driver.find_elements_by_tag_name('tr')

# %%
for row in rows:
    print(row.text)
# Out:
# NO 분류 제목 답변 작성자 등록일
# 115205 강좌 질문 답변대기 이*현 2020-02-17
# 115204 학습 막장 공부흔적 day8 답변대기 최*진 2020-02-17
# 115203 강좌 막장구원 6강 질문 답변완료 김*준 2020-02-17
# 115202 강좌 문의 답변대기 이*영 2020-02-17
# 115201 학습 <독학관리 클래스 신청합니다> 답변완료 장*이 2020-02-17
# 115200 강좌 스피드 어법 day 10 관련 질문입니다 답변완료 박*원 2020-02-17
# 115199 강좌 막장 공흔 22쪽 24번 25번 답변완료 박*연 2020-02-17
# 115198 학습 막장 공부흔적8강 답변완료 최*진 2020-02-17
# 115197 학습 막장 답변완료 최*진 2020-02-17
# 115196 학습 커리 질문드려요 답변완료 이*라 2020-02-17

# %%
soup = bs(JHC_PAGE.text, 'lxml',from_encoding='cp949')
table = soup.find('table')
rows = table.find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-907aca2accf2> in <module>
#       1 soup = bs(JHC_PAGE.text, 'lxml',from_encoding='cp949')
#       2 table = soup.find('table')
# ----> 3 rows = table.find_all('tr')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
body = soup.select('body')

# %%
body
# Out:
# [<body id="wide">
#  <span itemscope="" itemtype="http://schema.org/Organization">
#  <link href="http://skyedu.conects.com" itemprop="url"/>
#  <a href="https://www.facebook.com/superskyedu" itemprop="sameAs"></a>
#  <a href="http://blog.naver.com/skyedu1st" itemprop="sameAs"></a>
#  <a href="https://kin.naver.com/profile/index.nhn?u=bhxRCAFf8gIWLadRnJbEhGOmJVO%2FRtioJnZCg8i1PdM%3D" itemprop="sameAs"></a>
#  <a href="http://tv.naver.com/skyedu" itemprop="sameAs"></a>
#  <a href="https://www.instagram.com/conects.skyedu/" itemprop="sameAs"></a>
#  <a href="https://www.youtube.com/c/skyedu1st" itemprop="sameAs"></a>
#  </span>
#  <!-- wrap -->
#  <div id="wrap">
#  <!-- S:Header -->
#  <div id="header">
#  <style type="text/css">
#          #wrap{min-width:1200px;}
#          .st-conects-snb .nav-gnb-depth-02 dt{color:#BA1425;}
#
#  	        </style>
#  <script src="//static.conects.com/static/js/common/st-track.production.js" type="text/javascript"></script>
#  <!-- notification js -->
#  <script src="//my.conects.com/js/mydangi/notification.js" type="text/javascript"></script>
#  <!-- PlayD TERA Log Definition Script Start -->
#  <script>
#      window['_LA'] = window['_LA'] || function () {
#          (window['_LA'].q = window['_LA'].q || []).push(arguments)
#      }
#  </script>
#  <script src="//static.conects.com/static/js/conects_gnb/gnb.js" type="text/javascript"></script>
#  <!-- 공통 CSS 선언부 :: 사이트 전체 반영 -->
#  <link href="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/css/st_conects.css?202002171118" rel="stylesheet" type="text/css"/>
#  <!-- 공통 CSS 선언부 :: 사이트 전체 반영 종료-->
#  <script src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/js/st_conects-gnb.js?202002171118"></script>
#  <script>
#      var _GNB_SEARCH_ = function () {
#          var gnbCategoryId = ($('#current-interest').data('interest')) ? '&category_id=' + $('#current-interest')
#              .data('interest') : '';
#          window.location.href = '//www.conects.com/common/template/search?keyword=' + encodeURIComponent($(
#              '#gnb_conects_search_text').val()) + gnbCategoryId;
#      };
#      var _GNB_SEARCH_ENTER_ = function (event) {
#          if (event.keyCode === 13) {
#              event.preventDefault();
#              _GNB_SEARCH_();
#          }
#      };
#
#      notification.conectsnotification('');
#  </script>
#  <div id="hgroup">
#  <div class="st_conects-nav">
#  <!-- 분기: social, personal -->
#  <!-- GNB -->
#  <div class="st_conects-gnb">
#  <!-- 검색영역 -->
#  <div class="st_bi-search">
#  <h1 class="bi"><a href="//www.conects.com">CONECTS</a></h1>
#  <div class="search-box">
#  <input class="inpt-search" id="gnb_conects_search_text" onkeyup="_GNB_SEARCH_ENTER_(event)" placeholder="학원과 독서실을 검색해보세요" type="text" value=""/>
#  <button class="btn-search" onclick="_GNB_SEARCH_()" type="button">검색</button>
#  </div>
#  </div>
#  <!-- //검색영역 -->
#  <div class="st_personal-service">
#  <a class="bi" href="//www.conects.com">Conects</a>
#  <dl class="this-service">
#  <dt class="depth-01">
#  <a class="link-service active" data-interest="38" href="https://skyedu.conects.com/go3/main" id="current-interest" target="_self">
#                              대입·수능                        </a>
#  </dt>
#  <dd class="depth-02">
#  <a class="selected" href="https://skyedu.conects.com/go3/main">스카이에듀</a>
#  <ul class="list">
#  <li>
#  <a href="https://skyedu.conects.com/go3/main" target="_self">스카이에듀</a>
#  </li>
#  <li>
#  <a href="http://www.right-way.co.kr/" target="_blank">수시컨설팅</a>
#  </li>
#  <li>
#  <a href="https://skyedu.conects.com/nondangi/main" target="_blank">논술</a>
#  </li>
#  <li>
#  <a href="https://skyeduac.conects.com/" target="_blank">스카이에듀학원</a>
#  </li>
#  <li>
#  <a href="https://nyjskyedu.conects.com/" target="_blank">남양주 기숙학원</a>
#  </li>
#  <li>
#  <a href="https://swskyedu.conects.com/" target="_blank">수원 학원</a>
#  </li>
#  <li>
#  <a href="https://swdskyedu.conects.com/" target="_blank">수원 학원(단과)</a>
#  </li>
#  <li>
#  <a href="https://gdskyedu.conects.com/" target="_blank">강동학원</a>
#  </li>
#  <li>
#  <a href="https://nrjskyedu.conects.com/" target="_blank">노량진 학원(독학/단과)</a>
#  </li>
#  <li>
#  <a href="https://artskyedu.conects.com/" target="_blank">선릉 예체능관</a>
#  </li>
#  <li>
#  <a href="https://skyeduac.conects.com/public-edu" target="_blank">스카이에듀 공교육</a>
#  </li>
#  </ul>
#  </dd>
#  </dl>
#  <div class="interesting-service">
#  <div class="interestings">
#  <div>
#  <ul id="gnb-interests-list">
#  <li data-interest-code="165" style="display:none">
#  <a class="link-service" href="https://kr.tutor.com/elementary">
#                                          유·초등                                    </a>
#  </li>
#  <li data-interest-code="157" style="display:none">
#  <a class="link-service" href="https://www.conects.com/common/template/feed?category_id=157">
#                                          중등·특목                                    </a>
#  </li>
#  <li data-interest-code="38" style="display:none">
#  <a class="link-service" href="https://skyedu.conects.com/go3/main">
#                                          대입·수능                                    </a>
#  </li>
#  <li data-interest-code="85" style="display:none">
#  <a class="link-service" href="https://public.conects.com/">
#                                          대학생·취업                                    </a>
#  </li>
#  <li data-interest-code="69" style="display:none">
#  <a class="link-service" href="https://gong.conects.com/">
#                                          공무원·임용                                    </a>
#  </li>
#  <li data-interest-code="55" style="display:none">
#  <a class="link-service" href="https://eng.conects.com/">
#                                          어학·회화                                    </a>
#  </li>
#  <li data-interest-code="175" style="display:none">
#  <a class="link-service" href="https://imyong.conects.com/">
#                                          임용고시                                    </a>
#  </li>
#  <li data-interest-code="169" style="display:none">
#  <a class="link-service" href="https://www.schole.ac/">
#                                          직무·스타트업                                    </a>
#  </li>
#  <li data-interest-code="158" style="display:none">
#  <a class="link-service" href="https://peet.conects.com/">
#                                          전문직                                    </a>
#  </li>
#  <li data-interest-code="160" style="display:none">
#  <a class="link-service" href="https://gongin.conects.com/">
#                                          공인중개사                                    </a>
#  </li>
#  <li data-interest-code="177" style="display:none">
#  <a class="link-service" href="https://ja.conects.com/">
#                                          자격증                                    </a>
#  </li>
#  <li data-interest-code="179" style="display:none">
#  <a class="link-service" href="https://nomu.conects.com/">
#                                          노무사                                    </a>
#  </li>
#  <li data-interest-code="181" style="display:none">
#  <a class="link-service" href="https://bupmu.conects.com/">
#                                          법무사                                    </a>
#  </li>
#  <li data-interest-code="183" style="display:none">
#  <a class="link-service" href="https://customs.conects.com/">
#                                          관세사                                    </a>
#  </li>
#  <li data-interest-code="185" style="display:none">
#  <a class="link-service" href="https://ca.conects.com/">
#                                          감평사                                    </a>
#  </li>
#  <li data-interest-code="187" style="display:none">
#  <a class="link-service" href="https://beauty.conects.com/">
#                                          뷰티아카데미                                    </a>
#  </li>
#  <li data-interest-code="128" style="display:none">
#  <a class="link-service" href="https://hobby.conects.com/">
#                                          라이프·취미                                    </a>
#  </li>
#  <li data-interest-code="136" style="display:none">
#  <a class="link-service" href="">
#                                          독서                                    </a>
#  </li>
#  <li data-interest-code="171" style="display:none">
#  <a class="link-service" href="">
#                                          반려동물                                    </a>
#  </li>
#  <li data-interest-code="173" style="display:none">
#  <a class="link-service" href="">
#                                          뷰티                                    </a>
#  </li>
#  </ul>
#  <a class="btn-add-interesting" href="#st_conects-interesting-popup">관심사를 추가해보세요</a>
#  </div>
#  </div>
#  <div class="wrap-btn">
#  <button class="btn-prev" type="button">이전</button>
#  <button class="btn-next" type="button">다음</button>
#  </div>
#  </div>
#  </div>
#  <div class="st_social-service">
#  <ul class="tab">
#  <li><a>SCHOOL</a></li>
#  <li><a>UNIVERSITY</a></li>
#  <li><a>CAREER</a></li>
#  <li><a>LIFE</a></li>
#  </ul>
#  <div class="list">
#  <dl>
#  <dt>School</dt>
#  <dd><a href="https://kr.tutor.com/elementary">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/60cb696bdf9a445b9c410423a63df040.png"/>
#                                  유·초등                            </a></dd>
#  <dd><a href="https://www.conects.com/common/template/feed?category_id=157">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/ad81885a252c8d5d3fb0268f813a9417.png"/>
#                                  중등·특목                            </a></dd>
#  <dd><a href="https://skyedu.conects.com/go3/main">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/3d31e116ccf2a953e6759526df5ec396.png"/>
#                                  대입·수능                            </a></dd>
#  </dl>
#  <dl>
#  <dt>University</dt>
#  <dd><a href="https://public.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/193591ba5366aac68066e4487f9a46bb.png"/>
#                                  대학생·취업                            </a></dd>
#  <dd><a href="https://gong.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/a2671caf40b924e85d061cd898d18e05.png"/>
#                                  공무원·임용                            </a></dd>
#  <dd><a href="https://eng.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/24c049f7f2ac747a5dc80b8c336e17db.png"/>
#                                  어학·회화                            </a></dd>
#  <dd><a href="https://imyong.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/e61cb275368d8f127850b7eaa8ed3e8a.png"/>
#                                  임용고시                            </a></dd>
#  </dl>
#  <dl>
#  <dt>Career</dt>
#  <dd><a href="https://www.schole.ac/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/fc7b85d4532237f7b9f0f5ef3aeee8ef.png"/>
#                                  직무·스타트업                            </a></dd>
#  <dd><a href="https://peet.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/5403eb816aa42fbe78e0cb16debad451.png"/>
#                                  전문직                            </a></dd>
#  <dd><a href="https://gongin.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/0e5a898aa23b1af4a209158fbd10d19a.png"/>
#                                  공인중개사                            </a></dd>
#  <dd><a href="https://ja.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/baa458f24b73d70b61e969a630769f0e.png"/>
#                                  자격증                            </a></dd>
#  <dd><a href="https://nomu.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/9542e5e111264faf00b4a7ef25b36833.png"/>
#                                  노무사                            </a></dd>
#  <dd><a href="https://bupmu.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/3cc8229ca08549b1032c3a70511e28ff.png"/>
#                                  법무사                            </a></dd>
#  <dd><a href="https://customs.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/b65e0d2fdc2dfb33822f20dd440b4fb0.png"/>
#                                  관세사                            </a></dd>
#  <dd><a href="https://ca.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/6ba114b6f128da83304822b77ea37047.png"/>
#                                  감평사                            </a></dd>
#  <dd><a href="https://beauty.conects.com/">
#  <img alt="" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/category_banner/dev/873c70b2b9e0eb086867f690efcabf88.png"/>
#                                  뷰티아카데미                            </a></dd>
#  </dl>
#  <dl>
#  <dt>Life</dt>
#  <dd><a href="https://hobby.conects.com/">
#  <img alt="" src=""/>
#                                  라이프·취미                            </a></dd>
#  <dd><a href="">
#  <img alt="" src=""/>
#                                  독서                            </a></dd>
#  <dd><a href="">
#  <img alt="" src=""/>
#                                  반려동물                            </a></dd>
#  <dd><a href="">
#  <img alt="" src=""/>
#                                  뷰티                            </a></dd>
#  </dl>
#  </div>
#  </div>
#  <div class="st_conects-util">
#  <ul>
#  <li>
#  <a href="https://member.conects.com/member/login?redirect_url=http%3A%2F%2Fskyedu.conects.com%2Fteachers%2Fteacher_qna%2F%3Ft_id%3Djhc01%26cat1%3D1">로그인</a>
#  </li>
#  <li>
#  <a href="https://member.conects.com/member/join?redirect_url=http%3A%2F%2Fskyedu.conects.com%2Fteachers%2Fteacher_qna%2F%3Ft_id%3Djhc01%26cat1%3D1">회원가입</a>
#  </li>
#  <li>
#  <a href="https://my.conects.com/cart/cart">장바구니</a>
#  </li>
#  <li>
#  <a class="link-cs" href="//www.conects.com/support">고객섬김센터</a>
#  </li>
#  <li><a href="https://my.conects.com">내보관함</a></li>
#  </ul>
#  </div>
#  </div>
#  <!-- //GNB -->
#  <!-- LNB -->
#  <div class="st_business-nav">
#  <iframe frameborder="0" height="130" scrolling="no" src="//www.conects.com/common/st_lnb_banner" style="overflow:hidden;vertical-align:top;" width="166"></iframe>
#  <a class="link-home" href="https://skyedu.conects.com/go3/main">스카이에듀<br/>메인가기</a>
#  <dl class="wrap">
#  <dt><span>
#                          함께해요
#
#                      </span></dt>
#  <dd><a class="new" href="https://www.conects.com/archives/together/study?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/b7f3a2fdca8e90fe3a5d04315ebde259.png"/>
#                          스터디 / 모임                    </a></dd>
#  <dd><a class="new" href="https://www.conects.com/archives/together/winner?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/e429074c7334e6f0d810da7a87ca7884.png"/>
#                          합격선배                    </a></dd>
#  <dd><a class="new" href="https://www.conects.com/archives/together/diary/type/card?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/73297669789ac1fdb12504dead275609.png"/>
#                          공부일기                    </a></dd>
#  </dl>
#  <dl class="wrap">
#  <dt><span>
#                          물어봐요
#
#                      </span></dt>
#  <dd><a class="new" href="https://www.conects.com/archives/ask/qna?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/cc89f150b5849d0b9005ec69e79e9b7b.png"/>
#                          Q&amp;A                    </a></dd>
#  <dd><a class="new" href="https://www.conects.com/archives/ask/anonymous?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/1b3c3a133c1d7927c6d32a412c5d9662.png"/>
#                          대나무숲                    </a></dd>
#  <dd><a class="new" href="https://www.conects.com/archives/together/future?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/1a097fa7fb326ea2ae91dea49f8fa2b1.png"/>
#                          미래예측                    </a></dd>
#  </dl>
#  <dl class="wrap">
#  <dt><span>
#                          배워봐요
#
#                      </span></dt>
#  <dd><a class="new" href="https://www.conects.com/archives/study/academy?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/cd570f1592ff64b4c4e8bbe153d4ff89.png"/>
#                          학원                    </a></dd>
#  <dd><a class="new" href="https://www.conects.com/archives/study/room?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/cb2edb12fb89ebdc136589fac1af6379.png"/>
#                          독서실                    </a></dd>
#  </dl>
#  <dl class="wrap">
#  <dt><span>
#                          비밀이에요
#                                                  <span class="ico-tag">event</span>
#  </span></dt>
#  <dd><a class="new" href="https://www.conects.com/archives/secret/group?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/45526df1a13bdebe351de4296b6c7812.png"/>
#                          비밀모임                    </a></dd>
#  <dd><a class="new" href="https://www.conects.com/archives/secret/pds?category_id=38" target="_self">
#  <!-- 새글 등록 시 class="new" -->
#  <img alt="" class="ico" src="//s3.ap-northeast-2.amazonaws.com/st.conects/myconects/img/lnb_icon/a439af97493ba120e48aab2b940114c6.png"/>
#                          비밀자료                    </a></dd>
#  </dl>
#  <dl class="wrap">
#  <dt><a href="//www.conects.com/archives/best">
#                          베스트
#                      </a></dt>
#  </dl>
#  <dl class="add">
#  <dt><span>
#                          FAMILY SITE
#                      </span></dt>
#  <dd><a href="//book.conects.com">커넥츠북</a></dd>
#  <dd><a href="//studycenter.conects.com">공부장소</a></dd>
#  <dd><a href="//device.conects.com">커넥츠 디바이스</a></dd>
#  <dd><a href="//tutor.conects.com">커넥츠튜터</a></dd>
#  <dd><a href="//kr.tutor.com">튜터닷컴</a></dd>
#  </dl>
#  <div class="ban">
#  <a href="//www.conects.com/support/toceo" target="_blank"><img alt="회원님의 목소리를 들려주세요." src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/static_conects/public/img/banner/ban_ceo.gif"/></a>
#  </div>
#  </div>
#  <!-- //LNB -->
#  <!-- popup -->
#  <div class="st_conects-interesting-popup mfp-hide" id="st_conects-interesting-popup">
#  <p class="txt-state">
#  <strong class="num"></strong>어떤
#                  분야에 관심 있으신가요?<br/>
#  <strong>관심사를 선택</strong>하고, 맨 아래의 <strong>관심사 저장하기</strong>를 눌러보세요!
#              </p>
#  <dl class="list-interesting" id="interest-selection-area">
#  <dt>
#  <strong class="tit">School</strong>
#  <!-- <em class="num">(1,003,427)</em> -->
#  </dt>
#  <dd>
#  <input id="gnb_interest_check_165" type="checkbox" value="165"/>
#  <label for="gnb_interest_check_165">유·초등</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_157" type="checkbox" value="157"/>
#  <label for="gnb_interest_check_157">중등·특목</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_38" type="checkbox" value="38"/>
#  <label for="gnb_interest_check_38">대입·수능</label>
#  </dd>
#  <dt>
#  <strong class="tit">University</strong>
#  <!-- <em class="num">(1,003,427)</em> -->
#  </dt>
#  <dd>
#  <input id="gnb_interest_check_85" type="checkbox" value="85"/>
#  <label for="gnb_interest_check_85">대학생·취업</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_69" type="checkbox" value="69"/>
#  <label for="gnb_interest_check_69">공무원·임용</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_55" type="checkbox" value="55"/>
#  <label for="gnb_interest_check_55">어학·회화</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_175" type="checkbox" value="175"/>
#  <label for="gnb_interest_check_175">임용고시</label>
#  </dd>
#  <dt>
#  <strong class="tit">Career</strong>
#  <!-- <em class="num">(1,003,427)</em> -->
#  </dt>
#  <dd>
#  <input id="gnb_interest_check_169" type="checkbox" value="169"/>
#  <label for="gnb_interest_check_169">직무·스타트업</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_158" type="checkbox" value="158"/>
#  <label for="gnb_interest_check_158">전문직</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_160" type="checkbox" value="160"/>
#  <label for="gnb_interest_check_160">공인중개사</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_177" type="checkbox" value="177"/>
#  <label for="gnb_interest_check_177">자격증</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_179" type="checkbox" value="179"/>
#  <label for="gnb_interest_check_179">노무사</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_181" type="checkbox" value="181"/>
#  <label for="gnb_interest_check_181">법무사</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_183" type="checkbox" value="183"/>
#  <label for="gnb_interest_check_183">관세사</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_185" type="checkbox" value="185"/>
#  <label for="gnb_interest_check_185">감평사</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_187" type="checkbox" value="187"/>
#  <label for="gnb_interest_check_187">뷰티아카데미</label>
#  </dd>
#  <dt>
#  <strong class="tit">Life</strong>
#  <!-- <em class="num">(1,003,427)</em> -->
#  </dt>
#  <dd>
#  <input id="gnb_interest_check_128" type="checkbox" value="128"/>
#  <label for="gnb_interest_check_128">라이프·취미</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_136" type="checkbox" value="136"/>
#  <label for="gnb_interest_check_136">독서</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_171" type="checkbox" value="171"/>
#  <label for="gnb_interest_check_171">반려동물</label>
#  </dd>
#  <dd>
#  <input id="gnb_interest_check_173" type="checkbox" value="173"/>
#  <label for="gnb_interest_check_173">뷰티</label>
#  </dd>
#  </dl>
#  <button class="btn-confirm" onclick="if(_CONECTS_GNB_.setInterests($('#interest-selection-area input[type=checkbox]:checked').map(function(){return $(this).val()*1}).get()))$.magnificPopup.instance.close()" type="button">관심사
#                  저장하기</button>
#  <button class="btn-close-popup mfp-close" type="button">닫기</button>
#  </div>
#  <!-- //popup -->
#  </div>
#  </div>
#  <script>
#      var COMM_CONECTS_GNB = new StConectsGNB;
#      _CONECTS_GNB_.init(38)
#  </script>
#  <!-- //conects -->
#  <!-- GNB타입 -->
#  <!-- //GNB타입 --> <!-- 강좌리스트 바로재생  -->
#  <script src="/js/common/common_player.js?20200217111858" type="text/javascript"></script>
#  <script type="text/javascript">
#              //- 강좌리스트 셋팅하기
#              _CONECTS_COMMON_PLAYER_.init();
#
#
#              // CONECTS GNB 인스턴스
#              COMM_CONECTS_GNB.init('personal',true);
#              COMM_CONECTS_GNB.site({
#                  biz_code: 'SKYEDUNEW',
#                  active: 'SKYEDUNEW'
#              });
#
#                              COMM_CONECTS_GNB.menu(['wrap-data-00', '/teachers/main/info_mainTeacherOrder']);
#
#
#                              COMM_CONECTS_GNB.on("menu-00");
#                          // conects, learning, book, tutor / biz_code / cs
#          </script>
#  <style>
#          #hgroup .st-conects-myclass{font-size:0;}
#          #hgroup .st-conects-myclass a.myclass{ display:inline-block;float:none; }
#          #hgroup .st-conects-myclass .gnb-banner{ display:inline-block;float:none;vertical-align:top;width:230px;height:60px;text-align:left;font-size:0;}
#          #hgroup .st-conects-myclass .gnb-banner .slide:first-child{display:block;}
#          #hgroup .st-conects-myclass .gnb-banner .slide{width:230px;height:60px;margin-left:0;}
#          #hgroup .st-conects-myclass .gnb-banner em{position:absolute;top:0;right:0;z-index:500;cursor:pointer;}
#          </style>
#  <script type="text/javascript">
#          $(function(){
#              // var f_html = $('#hgroup .st-conects-myclass').html();
#              // $('#hgroup .st-conects-myclass').html('<div class="relative"></div>');
#              // $('#hgroup .st-conects-myclass').find('.relative').append('<a class="gnb-banner" href="https://skyedu.conects.com/event/presentation/2018/120501/event"><img src="http://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/00bceaee332f80ba951cd87bbf8774c4.png" /></a>');
#              // $('#hgroup .st-conects-myclass').find('.relative').append(f_html);
#
#              //fn_gnb_banner();
#              //fn_right_top_banner();
#          });
#
#          $(window).load(function() {
#              fn_right_top_banner();
#              //  fn_right_top_banner();
#          });
#
#      function fn_right_top_banner() {
#  		var f_obj = jQuery('#hgroup .st-gnb-banner');
#  		f_obj.css({'margin-right':'-160px','top':'-19px'});
#  		var f_html  = '';
#              f_html += '<div class="gnb-banner">';
#
#              //- 교재이벤트
#
#                              //f_html += '<a href="//st-event-skyedu.dangi.co.kr/event/cc/class_delivery/201911/event" target="_blank" ><img src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/db95247de4a86c0d4e02f9b4665add4f.gif" alt="이벤트"></a>';
#
#              //선착순 2020-01-31
#              // f_html += '<a href="//st-event-skyedu.dangi.co.kr/event/cc/2020/020301/event" target="_blank" ><img src="//s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/4cd72b970221876539d06c6ec294279c.png" alt="이벤트"></a>';
#
#
#
#              f_html += '</div>';
#
#              f_obj.append(f_html);
#  	}
#          </script>
#  <style type="text/css">
#      .sub-gnb{ background-color:#f9f9f9; border-bottom:1px solid #ccc; }
#      .sub-gnb > ul{ width:1100px; margin:0 auto; z-index:2; }
#      .sub-gnb > ul.teacher-menu{ width:1045px; padding-left:55px; background-position:0 50%; background-repeat:no-repeat; background-size:55px 55px; }
#      .sub-gnb > ul > li{ height:56px; margin:0 1px; float:left; position:relative; }
#      .sub-gnb > ul > li:first-child{ margin:0 1px 0 0; }
#      .sub-gnb > ul > li > a{ padding:18px 10px; display:block; position:relative; font-size:14px; color:#111; }
#
#      .sub-gnb .gnb-2depth{ width:230px; padding:15px 0; display:none; position:absolute; top:56px; left:0; background-color:#fff; border:1px solid #ccc; z-index:9999; }
#      .sub-gnb .gnb-2depth ul li a{ padding:10px 0 10px 20px; display:block; font-size:14px; color:#888; text-align:left; }
#      .sub-gnb .over .gnb-2depth ul li a{ animation:Ani-2depth .2s linear; animation-fill-mode:both; }
#      .sub-gnb .gnb-2depth ul li a:hover{ color:#d90000; }
#
#      .sub-gnb > ul > li > a:hover,
#      .sub-gnb > ul > li:hover > a{ padding:18px 10px 14px; border-bottom:5px solid #f9f9f9; border-color:#ccc \0/IE9; animation:Ani-1depth .3s linear; animation-fill-mode:both; }
#      .sub-gnb > ul > li:hover > a.selected{ border-color:#f9f9f9 \0/IE9; animation:none; }
#      .sub-gnb > ul > li > a.selected{ padding:18px 10px 14px; border-bottom:5px solid #e90000; }
#      .sub-gnb > ul > li > a.selected:hover{ border-color:#e90000 \0/IE9; animation:none; }
#      .sub-gnb > ul > li:hover > .gnb-1depth + .gnb-2depth{display: block;}
#
#  	.sub-gnb > ul > li > a.sub-style-list > i{margin-left:5px;display:inline-block;width:10px;height:6px;background:url('//static.conects.com/skyedu_conects/imgs/web/utuber/sub_gnb_arrow.png') 0 0 no-repeat;}
#  	.sub-gnb > ul > li > a.sub-style-list:hover{ border-color:#e90000 \0/IE9;animation:Ani-1depth-red .3s linear; animation-fill-mode:both;}
#  	.sub-gnb > ul > li:hover > a.sub-style-list{border-bottom:5px solid #e90000;animation:none;}
#  	.sub-gnb > ul > li:hover > a.sub-style-list > i{background-position:100% 0;}
#
#
#
#  	.gnb-2depth.sub-gnb-list{padding:0 0 20px;top:57px;left:0;right:0;background-color:#fff;border:none;border-bottom:1px solid #ccc;width:100%;}
#  	.sub-gnb-list > .float-area{ width:1100px; margin:0 auto;position:relative;}
#  	.sub-gnb-list > .float-area > div{float:left;width:220px;}
#  	.sub-gnb-list hr{display:block;position:absolute;top:20px;bottom:0;margin:0;border:0 none; width:1px;height:calc(100% - 20px);background-color:#e8e8e8;}
#  	.sub-gnb-list hr.line00{left:205px;}
#  	.sub-gnb-list hr.line01{left:425px;}
#  	.sub-gnb-list hr.line02{left:645px;}
#  	.sub-gnb-list hr.line03{left:865px;}
#  	.sub-gnb-list dl{margin-top:20px;}
#  	.sub-gnb-list dt{margin-bottom:10px;font-size:14px;line-height:1.2;vertical-align:top;color:#000;font-weight:bold;}
#  	.sub-gnb-list dd{font-size:0;padding-top:10px;}
#  	.sub-gnb-list dd a{display:block;height:35px;line-height:34px;width:170px;}
#  	.sub-gnb-list dd .ico-thumb{margin-right:10px;display:inline-block;vertical-align:top;width:35px;height:35px;border-radius:50%;}
#  	.sub-gnb-list dd span{vertical-align:top;color:#999;font-size:13px;max-width:125px;}
#  	.sub-gnb-list dd a:hover span{color:#000;text-decoration:underline #000;}
#
#      @keyframes Ani-1depth{
#          from{ border-color:#f9f9f9; }
#          to{ border-color:#ccc; }
#      }
#      @keyframes Ani-1depth-red{
#          from{ border-color:#f9f9f9; }
#          to{ border-color:#e90000; }
#      }
#      @keyframes Ani-2depth{
#          from{ display:block; transform:translate3d(0, -10%, 0); }
#          to{ display:block; transform:none; }
#      }
#  </style>
#  <div class="sub-gnb">
#  <!-- S:선생님 서브메뉴 진입 시 :  teacher-menu" style="background-image:url('http://img.skyedu.com/teacher/photo/55_55/jhc01.jpg'); 추가-->
#  <ul class="float-area teacher-menu" style="background-image:url('//static.conects.com/skyedu_conects/imgs/teacher/photo/55_55/jhc01.jpg');">
#  <li>
#  <a class="" href="/teachers/home/?t_id=jhc01&amp;cat1=1">선생님 홈</a>
#  </li>
#  <li>
#  <a class="" href="/teachers/lecList/?t_id=jhc01&amp;cat1=1">개설강좌</a>
#  </li>
#  <li>
#  <a class="" href="/teachers/notice/?t_id=jhc01&amp;cat1=1">공지사항</a>
#  </li>
#  <li>
#  <a class="selected" href="/teachers/teacher_qna/?t_id=jhc01&amp;cat1=1">학습질문/답변</a>
#  </li>
#  <li>
#  <a class="" href="/teachers/best_review/?t_id=jhc01&amp;cat1=1">수강후기</a>
#  </li>
#  <li>
#  <a class="" href="/teachers/tcc/?t_id=jhc01&amp;cat1=1">선생님 TV</a>
#  </li>
#  <li>
#  <a class="" href="/teachers/board_data_list/?t_id=jhc01&amp;cat1=1">학습자료실</a>
#  </li>
#  <li>
#  <a class="" href="/teachers/explain_lecture/?t_id=jhc01">해설강의</a>
#  </li>
#  </ul>
#  <!-- E:선생님 서브메뉴 진입 시-->
#  </div>
#  <!-- 매일인증 이벤트 -->
#  <style>
#  				@-webkit-keyframes hvr-icon-up {
#  				0%, 50%, 100% {
#  					-webkit-transform: translateY(0);
#  					transform: translateY(0);
#  				}
#  				25%, 75% {
#  					-webkit-transform: translateY(-4px);
#  					transform: translateY(-4px);
#  				}
#  				}
#  				@keyframes hvr-icon-up {
#  				0%, 50%, 100% {
#  					-webkit-transform: translateY(0);
#  					transform: translateY(0);
#  				}
#  				25%, 75% {
#  					-webkit-transform: translateY(-4px);
#  					transform: translateY(-4px);
#  				}
#  				}
#
#  				.hvr-icon-up {
#  				-webkit-transform: translateZ(0);
#  				transform: translateZ(0);
#  				}
#
#  				.hvr-icon-up{
#  					animation:hvr-icon-up 1s ease-out infinite;
#  				}
#
#  				.hvr-icon-up:hover{
#  					animation:none;
#  				}
#  			</style>
#  <!-- S:학년선택 -->
#  <script type="text/javascript">
#  			$(window).load(function() {
#
#  				//$('.st-conects-snb .bi a').html('<img src="//static.conects.com/skyedu_conects/imgs/web/main/v06/logo_191112.gif" alt="스듀" />');
#
#  				// 학년선택 추가
#  				var strMenuHtml = '' +
#  				'<div class="btn-set-year" style="float:left;margin:11px 20px 0 -10px;">' +
#  				'<a href="javascript:void(0);" onclick="$(\'.layer-set-year\').show();" style="border:1px solid #29b6f6;padding:0 4px;font-size:12px;height:22px;line-height:22px;border-radius:4px;color:#29b6f6;">학년설정</a>' +
#  				'</div>';
#  				//$( strMenuHtml ).insertAfter( $('.artc-toggle-depth') );
#
#  				//$('.st-conects-snb .nav-gnb').append('<li><a href="https://st-event-skyedu.dangi.co.kr/event/cc/2019/070801/event" class="depth-01 " style="color:#f45f89;"><span style="position:absolute;top:-18px;left:-8px;"><img src="https://static.conects.com/skyedu_conects/imgs/web/banner/201906/gnb.jpg" alt="D-100"></span></a></li>');
#  							});
#
#  			function fn_next(){
#
#  				var NEXTHOME=jQuery(":input:radio[name=NEXTHOME]:checked").val();
#
#  				if(NEXTHOME=="" || NEXTHOME==undefined){
#  					alert("바로 접속할 학년을 선택해주세요.");
#  				}else if(NEXTHOME=="go3"){
#  					var ob = confirm('[SKYEDU 예비 고3] 로 바로 접속할\n학년 사이트를 설정하시겠습니까?');
#  					if(ob){
#  						setCookie('NEXTHOME','go3',365);
#  					};
#  					jQuery('.layer-set-year').hide();
#  				}else if(NEXTHOME=="go2"){
#  					var ob = confirm('[SKYEDU 예비 고2] 로 바로 접속할 학년 사이트를 설정하시겠습니까?');
#  					if(ob){
#  						setCookie('NEXTHOME','go2',365);
#  					};
#  					jQuery('.layer-set-year').hide();
#  				}else if(NEXTHOME=="go1"){
#  					var ob = confirm('[SKYEDU 예비 고1] 로 바로 접속할 학년 사이트를 설정하시겠습니까?');
#  					if(ob){
#  						setCookie('NEXTHOME','go1',365);
#  					};
#  					jQuery('.layer-set-year').hide();
#  				}
#  			}
#
#
#  			</script>
#  <div class="layer-set-year" style="display:none;position:absolute;top:181px;left:50%;margin-left:-390px; border:1px solid #535353;background-color:#fff;padding:30px;z-index:3;">
#  <div class="relative" style="width:324px;">
#  <a href="javascript:void(0);" onclick="$(this).parents('.layer-set-year').hide();" style="position:absolute;top:-20px;right:-20px;"><img alt="닫기" src="//static.conects.com/skyedu_conects/imgs/web/event/common/popup_btn_close.png"/></a>
#  <div class="layer-ttl" style="font-size:20px;color:#000;text-align:left;line-height:30px;">
#  <b>바로 접속할 학년을 설정해주세요.<br/>
#  						SKYEDU에 접속 시 선택하신 학년<br/>
#  						사이트로 바로 이동합니다.</b>
#  </div>
#  <div class="layer-cont" style="padding:24px 0;">
#  <form action="">
#  <label class="radio"><input name="NEXTHOME" type="radio" value="go3"/> 예비 고3</label>
#  <label class="radio" style="margin-left:30px;"><input name="NEXTHOME" type="radio" value="go2"/> 예비 고2</label>
#  <label class="radio" style="margin-left:30px;"><input name="NEXTHOME" type="radio" value="go1"/> 예비 고1</label>
#  </form>
#  </div>
#  <div class="btn-wrap">
#  <a class="btn-style btn-big" href="javascript:fn_next();">설정하기</a>
#  </div>
#  <div class="mt10" style="color:#a0a0a0;font-size:13px;letter-spacing:-0.03em;text-align:left;">
#  						이후 다른 학년으로 기본 사이트 설정을 변경하시려면<br/>
#  						사용하는 컴퓨터의 쿠키를 삭제 후 재설정하실 수 있습니다.
#  					</div>
#  </div>
#  </div>
#  <!-- E:학년선택 -->
#  </div>
#  <!-- E:Header -->
#  <!-- container -->
#  <div id="container">
#  <div class="layout-contents-container layout-padding">
#  <div class="wrap-column">
#  <h3 class="ttl">
#              학습 질문/답변
#              <small class="color-grey">학습에 대한 질문을 남겨 주시면 빠르게 답변드리겠습니다.</small>
#  </h3>
#  <!-- S: 정렬만 단독 사용 -->
#  <div class="box-select-area"> <!-- 우측 정렬일 땐  txt-right 추가 -->
#  <div class="select-tab">
#  <a class="selected" href="/teachers/teacher_qna/?t_id=jhc01&amp;cat1=1">전체</a>
#  <span class="bar">|</span>
#  <a href="javascript:void(0);" onclick="board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','18692101','')">강좌</a>
#  <span class="bar">|</span>
#  <a href="javascript:void(0);" onclick="board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','18692102','')">학습</a>
#  <span class="bar">|</span>
#  <a href="javascript:void(0);" onclick="board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','18692104','')">기타</a>
#  </div>
#  </div>
#  <!-- E: 정렬만 단독 사용 -->
#  </div>
#  <input id="temp_search" type="hidden"/>
#  <input id="temp_search_option" type="hidden"/>
#  <input id="temp_cat1" name="temp_cat1" type="hidden" value="1"/>
#  <!-- 학습QNA -->
#  <div class="wrap-column board-data-list">
#  <!-- 리스트 -->
#  <div class="board-list" id="bbs_content"></div>
#  <div class="float-area mt20"></div>
#  <!--// 리스트 -->
#  </div>
#  <div class="layout-aside-quick">
#  <div class="aside-container">
#  <div class="artc-banner">
#  <ul class="banner-list">
#  <li>
#  <a href="https://www.youtube.com/embed/JnSYHef4lM0" target="_blank">
#  <img alt="[퀵] 전홍철T - 개념은 전홍철" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/b95e0759dca5cb41e5ff16ebd8c2c892.jpg"/>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.conects.com/course/detail/intro/268076" target="">
#  <img alt="[영어] 전홍철T 스피드리딩 - 퀵" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/d905e763bd21eb39f52ba9d7155971cb.jpg"/>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.conects.com/course/detail/intro/268077" target="">
#  <img alt="[영어] 전홍철T 스피드어법 - 퀵" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/6da54a345eebb4f90624a41545ab9cda.jpg"/>
#  </a>
#  </li>
#  <li>
#  <a href="https://skyedu.conects.com/event/page/list/4121" target="">
#  <img alt="[영어]전홍철T 퀵배너" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/d0988b8e79156fe0917909e6f1ed8e10.jpg"/>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.conects.com/course/detail/intro/237477" target="">
#  <img alt="[선생님홈퀵] 전홍철T 스피드 보카" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/3092d8f92f3d330e591b51570a63475e.png"/>
#  </a>
#  </li>
#  <li>
#  <a href="https://skyedu.conects.com/teachers/tcc?t_id=jhc01&amp;tccIdx=9245" target="">
#  <img alt="[영어]전홍철 퀵배너" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/6a776c62166826543dfbfbf9f44375aa.png"/>
#  </a>
#  </li>
#  <li>
#  <a href="https://skyedu.conects.com/teachers/notice/board_view?t_id=jhc01&amp;cat1=1&amp;document_srl=24825165" target="">
#  <img alt="[영어]전홍철T 적중 퀵" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/2dec9244f0ed2bc6d6cd06e94e030712.png"/>
#  </a>
#  </li>
#  <li>
#  <a href="http://nrjdan.skyedu.com/introduce/academyInfo.asp" target="_blank">
#  <img alt="[선생님퀵]노량진스듀 리얼패스" src="https://s3.ap-northeast-2.amazonaws.com/st.dangidata/skyedu_conects/data/banner/bb967b518eaa643503fe6203769a75f2.png"/>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  <script type="text/javascript">
#  	$(document).ready( function(){
#
#              board_list('1', 'list' ,'skyedu_teacher_qna','regdate', '', '999','','','');
#
#
#          jQuery(".select-tab a").click(function(){
#
#              jQuery(".select-tab a").removeClass("selected");
#              jQuery(this).addClass("selected");
#
#          });
#
#  	});
#
#
#  </script>
#  <script type="text/javascript">
#
#      var teacher_id;
#      var cat1;
#
#
#      // 리스트
#      function board_list(page, type, mid,sort_index,search_word,teacher_id,search_etc,category_srl,extra_category){
#
#          this.teacher_id = teacher_id;
#          this.cat1 = $("#temp_cat1").val() ;
#
#
#          // 검색어
#          var search = "";
#          // 검색 옵션
#          var search_option = "";
#
#          if(search_word == 'search'){
#              search = $("#search").val();
#              search_option = $("#search_option").val();
#
#              $("#search_option").val(search_option);
#              /*
#              if(search.length <= 0){
#                  if(search_option != 'all'){
#                      alert('검색어를 입력해주세요');
#                      return preventDefaultAction(false);
#                  }
#              }
#              */
#
#              $("#temp_search").val(search);
#              $("#temp_search_option").val(search_option);
#
#          }else{
#              if($("#temp_search").val().length > 0){
#                  search = $("#temp_search").val();
#              }
#              if($("#temp_search_option").val().length > 0){
#                  search_option = $("#temp_search_option").val();
#              }
#          }
#
#          // $('html,body').animate({ scrollTop: $('.board-data-list').offset().top }, 500);
#
#
#          $.ajax({
#              url: "/teachers/teacher_qna/board_list/"+page,
#              type: "POST",
#              data: {
#                  type : type
#                  ,mid : mid
#                  ,sort_index : sort_index
#                  ,search :search
#                  ,search_etc:search_etc
#                  ,search_option : search_option
#                  ,teacher_id : this.teacher_id
#                  ,cat1:this.cat1
#                  ,category_srl:category_srl
#                  ,extra_category:extra_category
#              },
#              error:function(e){
#      //							   alert("데이터를 가져오지 못하였습니다.");
#              },
#              beforeSend:function(){
#              },
#              success:function ( response ){
#                  jQuery("#bbs_content").html(response);
#
#              },
#              complete:function(){
#              }
#
#          });
#      }
#
#
#
#      function version_check(){
#          var _ua = navigator.userAgent;
#          var rv = -1;
#
#          //IE 11,10,9,8
#          var trident = _ua.match(/Trident\/(\d.\d)/i);
#          if(trident != null ){
#              if(trident[1] == "7.0" ) return false;
#              if(trident[1] == "6.0" ) return false;
#              if(trident[1] == "5.0" ) return true;
#              if(trident[1] == "4.0" ) return true;
#          }
#
#          //IE 7...
#          if( navigator.appName == 'Microsoft Internet Explorer'){
#              return true;
#          }
#
#          var agt = _ua.toLowerCase();
#          if (agt.indexOf("chrome") != -1) return false;
#          if (agt.indexOf("opera") != -1) return false;
#          if (agt.indexOf("staroffice") != -1) return false;
#          if (agt.indexOf("webtv") != -1) return false;
#          if (agt.indexOf("beonex") != -1) return false;
#          if (agt.indexOf("chimera") != -1) return false;
#          if (agt.indexOf("netpositive") != -1) return false;
#          if (agt.indexOf("phoenix") != -1) return false;
#          if (agt.indexOf("firefox") != -1) return false;
#          if (agt.indexOf("safari") != -1) return false;
#          if (agt.indexOf("skipstone") != -1) return false;
#          if (agt.indexOf("netscape") != -1) return false;
#          if (agt.indexOf("mozilla/5.0") != -1) return false;
#
#      }
#
#
#  </script> <!-- select box 이벤트 적용 -->
#  <script>
#      $(document).on("click", ".select_box>div", function(){
#          var ul_display = $(this).next("ul").css("display");
#
#
#          $(this).on("selectstart", function(event){ return false; });
#
#          //oepn select box close
#          $(".select_box>div").css("background-image","url(https://skyedu.conects.com/img//myclass/support_contents/selectbox_arrow.gif)");
#          $(".select_box>div").parent().css('z-index', 0);
#          $(".select_box>div").next("ul").hide();
#
#          if(ul_display!="block"){
#
#              $(this).parent().css('z-index', 5);
#              $(this).next("ul").show();
#
#              $(this).css("background-image","url(https://skyedu.conects.com/img//myclass/support_contents/selectbox_arrow_up.gif)");
#          }else{
#              $(this).parent().css('z-index', 0);
#              $(this).next("ul").hide();
#              $(this).css("background-image","url(https://skyedu.conects.com/img//myclass/support_contents/selectbox_arrow.gif)");
#          }
#      });
#  </script>
#  </div>
#  <!-- container -->
#  <!-- 레이어 메뉴 더보기 -->
#  <div class="layer-menu" id="popup_layer_menu"></div>
#  <!--// 레이어 메뉴 더보기 -->
#  <!-- [s] 2019.04.09 장바구니 레이어 팝업 추가 -->
#  <div class="class-combine_layerpop-cart hide">
#  <a class="btn-cart" href="javascript: void(0);" onclick="cart_products_bytag();">장바구니 담기</a>
#  <a class="btn-cart" href="javascript: void(0);" onclick="order_products_bytag();">바로 구매하기</a>
#  </div>
#  <!-- FOOTER -->
#  <div id="footer-container">
#  <!-- FOOTER -->
#  <div class="st-conects-footer-v3-2">
#  <div class="wrap-bi">
#  <img alt="" class="bi" src="//static.conects.com/common/img/st-comm-v3/img-bi-conects-footer-01.png"/>
#  <p class="txt">전 국민 필수 공부앱</p>
#  <div class="conects-sns">
#  <a class="icon ico-facebook" href="http://facebook.com/myconects">커넥츠 페이스북</a>
#  <a class="icon ico-naver-post" href="https://post.naver.com/conects">커넥츠 네이버 포스트</a>
#  <a class="icon ico-naver-blog" href="http://blog.naver.com/conects">커넥츠 네이버 블로그</a>
#  <a class="icon ico-youtube" href="https://www.youtube.com/channel/UCq6gcyfvYSAJuEQvVZYzklw">커넥츠 유튜브</a>
#  <a class="icon ico-naver-tv" href="http://tv.naver.com/conects">커넥츠 네이버 TV</a>
#  <a class="icon ico-instagram" href="http://instagram.com/conects.office">커넥츠 인스타그램</a>
#  </div>
#  </div>
#  <div class="link-info">
#  <ul>
#  <li><a href="http://www.stunitas.com/" target="_blank">회사소개</a></li>
#  <li><a href="http://www.conects.com/intro" target="_blank">커넥츠소개</a></li>
#  <li><a href="#x" onclick="window.open('/popup/userule/userule', 'popup_notice1', 'width=880,height=900,scrollbars=yes,top=0,left=0,location=0,resizable=no,status=no,directories=no');return false;">이용약관</a></li>
#  <li><a class="odd" href="#x" onclick="window.open('/popup/skyprivate/', 'popup_notice1', 'width=880,height=900,scrollbars=yes,top=0,left=0,location=0,resizable=no,status=no,directories=no');return false;">개인정보처리방침</a></li>
#  <li><a href="/help_center/main">고객섬김센터</a></li>
#  </ul>
#  <div class="link-isms">
#  <a class="ico-isms" href="#isms-conects" onclick="jQuery(this).next('.isms-conects').show();"><img alt="ISMS" src="//static.conects.com/common/img/st-comm-v3/ISMS.png"/></a>
#  <div class="isms-conects" id="isms-conects">
#  <a href="javascript:;" onclick="jQuery(this).parents('.isms-conects').fadeOut(200);" style="position: absolute;top:5px; right:5px;"><img alt="창닫기" src="//static.conects.com/skyedu_conects/imgs/ico/btn_close_circle.png"/></a>
#  <img alt="정보보호 관리체계 인증서" src="//static.conects.com/skyedu_conects/imgs/ico/isms_popup.png"/>
#  </div>
#  </div>
#  </div>
#  <div class="address">
#  <div class="wrap">
#  <span class="company">(주)현현교육</span>
#  <span>대표이사 : 김석배 </span>
#  <span class="address-txt">서울특별시 서초구 반포대로30길 81. 6.7.8층(서초동)</span>
#  </div>
#  <div class="wrap">
#  <span>고객센터 : 02-540-5252<!--em class="cs"><a href="https://api.happytalk.io/api/kakao/chat_open?yid=%40skyedu&site_id=6000000088&category_id=78762&division_id=78763&site_uid=<%If session_userid <> "" Then Response.write session_userid Else Response.write "{user_id}" End If %>" class="btn-kakao" target="_blank">카카오 상담톡</a></em--></span>
#  <span>윤리경영 : <a href="https://pito.co.kr/hot_line/index.php?scode=1JTIVW" target="_blank">[제보하기]</a></span>
#  </div>
#  <div class="wrap">
#  <span>사업자등록번호 : <em class="licensee-txt">215-86-79670</em></span>
#  <span>통신판매업신고 : <em class="licensee-txt">2015-서울서초-1080호</em> <a class="link-seller" href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2158679670" target="_blank">사용자 정보확인</a></span>
#  </div>
#  </div>
#  <div class="address">
#  <div class="wrap">
#  <span>ⓒ ST Unitas.</span>
#  </div>
#  </div>
#  </div>
#  <!-- //FOOTER -->
#  </div>
#  <!-- //FOOTER -->
#  </div>
#  <!--// wrap -->
#  <script type="text/javascript">
#  		(function(w,d,l,r,c,s) {
#  		w[r]=w[r]||function(a){ (w[r].q=w[r].q||[]).push(arguments);}; w[r].d=1*new Date();
#  		var _gt_cookieDay=30;
#  		var _gt_debug = false; // true 설정시 값이 실제 전달되지는 않고 크롬의 개발자도구에서 Console 창에 전송 메세지 표시
#  		var _gt_OnlyAD = true; // 광고키값이 있을때만 유입체크
#  		var _f_gt_PageView, _f_gt_Convert, _f_gt_ButtonClick, _lt=10, _LinkDelayTime=300;
#  		var C=function(a){ C[a].apply(C,[].slice.call(arguments))};
#  		C.aCode="";C.domain="tr.itiscreation.co.kr";
#  		try{
#  		C.setAccount=function(a){var args=[].slice.call(arguments); C.aCode=args[1]; if(args.length>=3)try{ _gt_cookieDay=args[2]; }catch(e){};};
#  		C.setCookie=function(n,v){if(typeof(localStorage)!='undefined')try{localStorage.setItem(n,v);}catch(e){if(e==QUOTA_EXCEEDED_ERR){localStorage.clear();localStorage.setItem(n,v);};};};
#  		C.getCookie=function(n){if(typeof(localStorage)!='undefined'){ var v=localStorage.getItem(n);if(v!=null) return v;};return null;};
#  		C.getParameter=function(n){var rv='',ad=unescape(l.href),p=(ad.slice(ad.indexOf('?')+1,ad.length)).split('&');for(var i=0;i<p.length;i++){var vn=p[i].split('=')[0];if(vn.toUpperCase()==n.toUpperCase()){rv=p[i].split('=')[1];break;};};return rv;};
#  		C.imageURL=function(a){
#  		var cid=this.getParameter('_itsid'),args=[].slice.call(arguments),v={},guid=this.getCookie("_gt_GUID"),t=this.getTime(),_cid="";
#  		v.aid=this.aCode;v.ctime=_gt_cookieDay;if(guid==null){guid=this.uuid();this.setCookie("_gt_GUID",guid);this.setCookie("_gt_FirstTime",t);};
#  		if(cid.length>0 && args[0]=="pageview"){_cid="&cid="+cid;this.setCookie('_gt_cid',cid);this.setCookie('_gt_aid',C.aCode);this.setCookie('_gt_ctime',t);this.setCookie("_gt_LastTime",t);args[args.length]="Landing";this.setCookie('_gt_buttonClick','');};v.cid=this.getCookie("_gt_cid");v.guid=guid;v.firstTime=this.getCookie("_gt_FirstTime");v.lastTime=this.getCookie("_gt_LastTime");v.forward=args;v.referer=(d.referrer.length>100)?d.referrer.substr(0,100):d.referrer;v.buttonClick=this.getCookie("_gt_buttonClick");
#  		var _href = l.protocol+"//"+C.domain+"/an/sv.php?v="+encodeURIComponent(JSON.stringify(v))+_cid+"&t="+(new Date().getTime());
#  		if(_gt_debug)console.log(JSON.stringify(v)+"\n"+_href);
#  		else setTimeout(function(){new Image().src=_href;},_lt);};
#  		C.send=C.event=function(a){var args=[].slice.call(arguments);C.imageURL.apply(C,args);};
#  		C.pageview=function(a){var args=[].slice.call(arguments);var cid=this.getParameter('_itsid');if( _gt_OnlyAD && cid.length==0 ) return;C.imageURL.apply(C,args);	if(_f_gt_PageView && typeof _f_gt_PageView == "function")_f_gt_PageView();
#  		if(args.length>=2)setTimeout(function(){l.href=args[1];},_LinkDelayTime);};
#  		C.convert=function(a){var args=[].slice.call(arguments);C.imageURL.apply(C,args);
#  		if(_f_gt_Convert && typeof _f_gt_Convert == "function") _f_gt_Convert();};
#  		C.buttonClick=function(a){var args=[].slice.call(arguments); this.setCookie('_gt_buttonClick',args[1]); C.imageURL.apply(C,args);
#  		if(_f_gt_ButtonClick && typeof _f_gt_ButtonClick == "function") _f_gt_ButtonClick();
#  		if(args.length>=3)setTimeout(function(){l.href=args[2];},_LinkDelayTime);};
#  		C.C=function(){var b=w[r]=C;};
#  		C.uuid=function(){var chars='0123456789abcdef'.split('');var uuid=[],rnd=Math.random,r;uuid[8]=uuid[13]=uuid[18]=uuid[23]='-';uuid[14]='4';
#  		for(var i=0;i<36;i++){if(!uuid[i]){r=0|rnd()*16;uuid[i]=chars[(i==19)?(r&0x3)|0x8:r&0xf];}};return uuid.join('');};
#  		C.ip2long=function(ip){var d=ip.split('.');return d[0]*Math.pow(256,3)+d[1]*Math.pow(256,2)+d[2]*256+d[3];};
#  		C.getTime=function(){return Math.floor(new Date().getTime()/1000);};
#  		(function(){var pv=w[r].q;w[r]=C;var a=C.C;a();return!0})();
#  		} catch (e) {if(_gt_debug)console.log('{"error":"LOAD","extra":{"name":"'+e.name+'","line":"'+(e.lineNumber||e.line)+'","script":"'+(e.fileName||e.sourceURL||e.script)+'","stack":"'+(e.stackTrace||e.stack)+'","message":"'+e.message+'"}}');
#  		else new Image().src="//"+C.domain+"/an/se.php?c=error&m="+encodeURIComponent('{"error":"LOAD","accountCode","'+C.aCode+'","extra":{"name":"'+e.name+'","line":"'+(e.lineNumber||e.line)+'","script":"'+(e.fileName||e.sourceURL||e.script)+'","stack":"'+(e.stackTrace||e.stack)+'","message":"'+e.message+'"}}');};
#  		})(window,document,location,'gTracking');
#  		gTracking('setAccount', '20', 30);
#  		gTracking('pageview');  // 페이지 뷰
#  	</script>
#  <!-- Facebook Pixel Code -->
#  <script>
#  		!function(f,b,e,v,n,t,s)
#  		{if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#  		n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#  		if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#  		n.queue=[];t=b.createElement(e);t.async=!0;
#  		t.src=v;s=b.getElementsByTagName(e)[0];
#  		s.parentNode.insertBefore(t,s)}(window, document,'script',
#  		'https://connect.facebook.net/en_US/fbevents.js');
#  		fbq('init', '695270460588395');
#  		fbq('track', 'PageView');
#  	  </script>
#  <noscript><img height="1" src="https://www.facebook.com/tr?id=695270460588395&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
#  <!-- End Facebook Pixel Code -->
#  <!--  mobon code -->
#  <!-- Enliple Common Tracker v3.5 [공용] start -->
#  <script type="text/javascript">
#  function mobRf(){
#      var rf = new EN();
#      rf.setData("userid", "skymid");
#      rf.setSSL(true);
#      rf.sendRf();
#  }
#  </script>
#  <script defer="defer" onload="mobRf()" src="https://cdn.megadata.co.kr/js/en_script/3.5/enliple_min3.5.js"></script><!-- Enliple Common Tracker v3.5 [공용] end -->
#  <!-- mobon code end -->
#  <!--  KAKAO code -->
#  <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
#  <script type="text/javascript">
#      kakaoPixel('958550063245052220').pageView();
#      kakaoPixel('958550063245052220').search({
#          keyword: '검색키워드입력'
#      });
#  </script>
#  <!--  KAKAO code end -->
#  <!--  Criteo code -->
#  <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
#  <script type="text/javascript">
#  window.criteo_q = window.criteo_q || [];
#  window.criteo_q.push(
#          { event: "setAccount", account: 8333 },
#          { event: "setHashedEmail", email: "MD5-hashed email address" },
#          { event: "setSiteType", type: "d"},
#          { event: "viewHome" }
#  );
#  </script>
#  <!--  Criteo code end -->
#  <!-- Global site tag (gtag.js) - Google Ads: 999354950 -->
#  <!-- <script async src="https://www.googletagmanager.com/gtag/js?id=AW-999354950"></script>
#  <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-999354950');
#  </script> -->
#  <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"72029d3b1f","applicationID":"103717515","transactionName":"MQcBbRECXBBWBkJRWAhNIloXCl0NGDFTWVQOBxFmEg1TTF4LUl1P","queueTime":0,"applicationTime":721,"atts":"HUACG1kYTx4=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>]

# %%
div_bbs_content = body[0].select('div#bbs_content')

# %%
div_bbs_content[0].find('tr')

# %%
div_bbs_content[0].select('tr')
# Out:
# []

# %%
def set_driver():
    global driver, actionChains
    driver = webdriver.Chrome()
    actionChains = ActionChains(driver)
    
def connect_site_with_url(site_url, time):
    driver.get(site_url)
    implicit_wait(time)
    
def username_password_insert(username, password):
    user = driver.find_element_by_id("username")
    pw = driver.find_element_by_id("password")
    user.send_keys(username)
    pw.send_keys(password)

    driver.find_element_by_id("signin_button").click()
    
def implicit_wait(time):
    driver.implicitly_wait(time)

def scroll_very_bottom(very_bottom_element, time):
    driver.execute_script('arguments[0].scrollIntoView(true);', very_bottom_element)
    implicit_wait(time)
    
def actual_performance(plausible_name):
    driver.get(division_dic['division_1'])
    implicit_wait(5)
    try:
        to_element = driver.find_element_by_css_selector("upload-modal.ng-scope")
        scroll_very_bottom(to_element, 5)
        implicit_wait(5)

        if driver.find_elements_by_xpath(f"//*[contains(text(), '{plausible_name}')]") != []:
#           print(driver.find_elements_by_xpath(f"//*[contains(text(), '{plausible_name}')]"))
            actionChains = ActionChains(driver)
            button = driver.find_elements_by_xpath(f"//*[contains(text(), '{plausible_name}')]")[0]
            actionChains.move_to_element(button).context_click(button).perform()

            implicit_wait(5)

            content = driver.find_element_by_css_selector('td.link > a.ng-binding')
            text = content.text
            
            #Some-how updating cell function's index doesn't start from 0
            #test_sheet.update_cell(row, 12, text)
            
    except Exception as e:
        print(e)
        
def download_image_with_url(url, name):   
    os.system(f'wget --output-document={name}{Path(url).suffix} {url}')
    
    def determine_s3_component(url):
        logo_url_prefix_ver1 = 'https://s3.amazonaws.com/footballpedia/logo/'
        logo_url_prefix_ver2 = 'https://footballpedia.s3.amazonaws.com/logo/'
        if (logo_url_prefix_ver1 in url) or (logo_url_prefix_ver2 in url):
            return True
        else:
            return False

# %%
set_driver()

# %%
connect_site_with_url(teacher_dic['jhc'], 1)

# %%
driver.find_element_by_tag_name('table').text
# Out:
# 'NO 분류 제목 답변 작성자 등록일\n115189 학습 스피드 리딩 공부흔적 질문있어요!! 답변완료 서*영 2020-02-17\n115188 막장 공부흔적 17쪽 36번 답변완료 이*은 2020-02-17\n115187 강좌 막장 189p 선행사&관계대명사의 종류와 격의 변화 답변완료 최*주 2020-02-17\n115186 안햇다 못햇다 답변완료 안*빈 2020-02-17\n115185 막장구원 14쪽 답변완료 박*리 2020-02-17\n115184 강좌 스피드 어법 답변완료 임*규 2020-02-17\n115183 전명구 구분 답변완료 임*상 2020-02-17\n115182 강좌 2021 스피드어법 답변완료 천*준 2020-02-16\n115181 how해석 답변완료 최*빈 2020-02-16\n115180 학습 중학20day 답변완료 엘* 2020-02-16'

# %%
import matplotlib.pylab as plt
import pandas as pd

# %%
panda = pd.read_excel("result.xlsx", sep = ',',encoding='CP949')

# %%
panda.date = pd.to_datetime(panda.date)

# %%
panda.head(10)
# Out:
#         date  qna_count
# 0 2020-02-18         29
# 1 2020-02-17         64
# 2 2020-02-16         22
# 3 2020-02-15         82
# 4 2020-02-14         70
# 5 2020-02-13        117
# 6 2020-02-12        197
# 7 2020-02-11        130
# 8 2020-02-10         28
# 9 2020-02-09         21

# %%
panda = panda.sort_values(by='date')

# %%
panda = panda.reset_index(drop = True)

# %%
panda.set_index('date', inplace = True)

# %%
qna_day = panda['qna_count'].plot(title='QNA')
?

# %%
panda.plot(figsize = (15,6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1426     def __call__(self):
#    1427         'Return the locations of the ticks'
# -> 1428         self.refresh()
#    1429         return self._locator()
#    1430
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1446     def refresh(self):
#    1447         'Refresh internal information based on current limits.'
# -> 1448         dmin, dmax = self.viewlim_to_dt()
#    1449         self._locator = self.get_locator(dmin, dmax)
#    1450
#
# ~/Desktop/internet_lecture/scrape_lecture/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1197                              'often happens if you pass a non-datetime '
#    1198                              'value to an axis that has datetime units'
# -> 1199                              .format(vmin))
#    1200         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1201
#
# ValueError: view limit minimum -36868.4 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
