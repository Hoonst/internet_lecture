# %%
import pandas as pd
from konlpy.tag import Twitter
from collections import Counter
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
twitter = Twitter()
# Out:
# /home/hoonst/anaconda3/lib/python3.7/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
data = pd.read_csv("qna.csv")
morphs = []

# %%
morphs_answer = []

# %%
for sentence in data['질문 내용']:
    morphs.append(twitter.pos(sentence))

# %%
for sentence in data['답변 내용']:
    morphs_answer.append(twitter.pos(sentence))

# %%
morphs
# Out:
# [[('challenge', 'Alpha'),
#   ('2', 'Number'),
#   ('번', 'Noun'),
#   ('에서', 'Josa'),
#   ('~', 'Punctuation'),
#   ('했다', 'Verb'),
#   ('~', 'Punctuation'),
#   ('를', 'Noun'),
#   ('.', 'Punctuation'),
#   ('식', 'Noun'),
#   ('의', 'Josa'),
#   ('문장', 'Noun'),
#   ('해석', 'Noun'),
#   ('은', 'Josa'),
#   ('한', 'Verb'),
#   ('번', 'Noun'),
#   ('머릿속', 'Noun'),
#   ('에서', 'Josa'),
#   ('끊기는', 'Verb'),
#   ('느낌', 'Noun'),
#   ('이', 'Josa'),
#   ('있어서', 'Adjective'),
#   ('틀린', 'Verb'),
#   ('해석', 'Noun'),
#   ('이라고', 'Josa'),
#   ('알', 'Noun'),
#   ('아', 'Josa'),
#   ('들었는데', 'Verb'),
#   ('5', 'Number'),
#   ('형식', 'Noun'),
#   ('지각', 'Noun'),
#   ('동사', 'Noun'),
#   ('나오는', 'Verb'),
#   ('부분', 'Noun'),
#   ('에서', 'Josa'),
#   ('(', 'Punctuation'),
#   ('27.28', 'Number'),
#   ('.', 'Punctuation'),
#   ('29.30', 'Number'),
#   (')', 'Punctuation'),
#   ('s', 'Alpha'),
#   ('가', 'Verb'),
#   ('v', 'Alpha'),
#   ('한', 'Verb'),
#   ('것', 'Noun'),
#   ('은', 'Josa'),
#   ('s', 'Alpha'),
# ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs_answer: 
    for word, tag in sentence: 
        if tag in ['Noun'] and len(word) > 1: 
            noun_adj_adv_list.append(word) 
            
print(noun_adj_adv_list)
# Out:
# ['채연', '학생', '채연', '학생', '질문', '해석', '느낌', '기본', '동사', '다른', '의미', '연결', '느낌', '일단', '목적어', '부분', '처리', '심화', '이야기', '그녀', '운전', '해석', '만약', '목적어', '그녀', '운전', '그녀', '부분', '해석', '자연', '일단', '교재', '제시', '일반', '해석', '그녀', '운전', '그녀', '차라', '뒤쪽', '추가', '지금', '기본', '기본', '심화', '부분', '부분', '추가', '분석', '공부', '스스로', '납득', '위해', '공부', '공부', '걱정', '반드시', '왼쪽', '오른쪽', '강의', '추가', '언제', '영창', '학생', '윤훈관입니', '이전', '교재', '질문', '내용', '질문', '반드시', '질문', '전치사', '기본', '의미', '학생', '정도', '사이', '해석', '자연', '해당', '부분', '처리', '그것', '전치사', '인지', '따라서', '영창', '학생', '기존', '해석', '전치사', '미리', '바로', '원어민', '이해', '방식', '접근', '수가', '분석', '공부', '방향', '잡고', '한결', '학생', '윤훈관입니', '질문', '내내', '마음', '누군가', '강사', '로써', '연대책임', '마음', '한결', '학생', '여태껏', '공감', '마음', '한결', '학생', '공부', '공부', '불구', '영어', '외국어', '그것', '본질', '제대로', '이해', '접근', '과목', '이기', '여태껏', '빙빙', '고민', '흔적', '언제', '질문', '여태껏', '한결', '학생', '스스로', '해결', '요구', '한결', '학생', '개념', '최대한', '이해', '수준', '눈높이', '설명', '항상', '노력', '혼자', '생각', '수험', '생활', '생각', '혼자', '기
# ...

# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common(100))

# %%
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', 
                      background_color='white',
                      colormap = "Accent_r", 
                      width=1500, height=1000).generate_from_frequencies(words) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
